# %%
import os
import numpy as np
import cv2
from PIL import Image
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# %%
# Define the path to the train and test folders
train_path = 'C:/A/code/VSC/python/test/cropped_DevanagariHandwrittenCharacterDataset/Train/'
test_path = 'C:/A/code/VSC/python/test/cropped_DevanagariHandwrittenCharacterDataset/Test/'

# Define a function to load and preprocess the images
def load_images(path):
    # Create empty lists to store the images and labels
    images = []
    labels = []

    # Loop through each folder (which represents a class) in the path
    for folder in os.listdir(path):
        # Get the path to the folder
        folder_path = os.path.join(path, folder)
        # Loop through each image in the folder
        for file in os.listdir(folder_path):
            # Get the path to the image file
            img_path = os.path.join(folder_path, file)
            # Load the image using OpenCV
            img = cv2.imread(img_path)
            # Convert the image to grayscale
            img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            # Normalize the pixel values of the images
            img = img.astype('float32') / 255.0
            # Append the image to the images list
            images.append(img)
            # Append the label to the labels list
            labels.append(folder)

    # Convert the images and labels lists to NumPy arrays
    images = np.array(images)
    labels = np.array(labels)
    
    # Return the images and labels arrays
    return images, labels

# Load the train images and labels
train_images, train_labels = load_images(train_path)

# Load the test images and labels
test_images, test_labels = load_images(test_path)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.utils import to_categorical

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

# Convert the string labels to integer labels
label_encoder = LabelEncoder()
train_labels_int = label_encoder.fit_transform(train_labels)

# %%
# Convert the integer labels to one-hot encoding
train_labels_onehot = to_categorical(train_labels_int, num_classes=46)

# Split the data into the five quadrants
x_train_tl = train_images[:,:14,:14].reshape(-1, 14, 14, 1)
x_train_tr = train_images[:,:14,14:].reshape(-1, 14, 14, 1)
x_train_bl = train_images[:,14:,:14].reshape(-1, 14, 14, 1)
x_train_br = train_images[:,14:,14:].reshape(-1, 14, 14, 1)
x_train_c = train_images[:,7:21,7:21].reshape(-1, 14, 14, 1)

# %%
# CNN for top left quadrant

# Define the input shape for each quadrant
input_shape = (14, 14, 1)

# Create a sequential model for the top left quadrant
model_tl = Sequential()

# Add a convolutional layer with 16 filters, 3x3 kernel size, and sigmoid activation
model_tl.add(Conv2D(16, kernel_size=(3, 3), activation='sigmoid', input_shape=input_shape))

# Add a max pooling layer with 2x2 pool size
model_tl.add(MaxPooling2D(pool_size=(2, 2)))

# Add a convolutional layer with 32 filters, 3x3 kernel size, and sigmoid activation
model_tl.add(Conv2D(32, kernel_size=(3, 3), activation='sigmoid'))

# Add a max pooling layer with 2x2 pool size
model_tl.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output of the previous layer
model_tl.add(Flatten())

# Add a dense layer with 512 units and relu activation
model_tl.add(Dense(512, activation='relu'))

# Add the output layer with 46 units and softmax activation
model_tl.add(Dense(46, activation='softmax'))

# Compile the model with categorical crossentropy loss and Adam optimizer
model_tl.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model_tl.summary()

# Train the model on the top left quadrant dataset
model_tl.fit(x_train_tl, train_labels_onehot, batch_size=32, epochs=50)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 12, 12, 16)        160
#
#  max_pooling2d (MaxPooling2D  (None, 6, 6, 16)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 4, 4, 32)          4640
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 512)               66048
#
#  dense_1 (Dense)             (None, 46)                23598
#
# =================================================================
# Total params: 94,446
# Trainable params: 94,446
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2444/2444 [==============================] - 16s 6ms/step - loss: 2.9425 - accuracy: 0.1978
# Epoch 2/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 2.1536 - accuracy: 0.3683
# Epoch 3/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 1.9068 - accuracy: 0.4299
# Epoch 4/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 1.7536 - accuracy: 0.4709
# Epoch 5/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 1.6376 - accuracy: 0.5008
# Epoch 6/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 1.5441 - accuracy: 0.5265
# Epoch 7/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 1.4647 - accuracy: 0.5489
# Epoch 8/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 1.4049 - accuracy: 0.5656
# Epoch 9/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 1.3521 - accuracy: 0.5787
# Epoch 10/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 1.3080 - accuracy: 0.5900
# Epoch 11/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 1.2671 - accuracy: 0.6034
# Epoch 12/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 1.2357 - accuracy: 0.6116
# Epoch 13/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 1.2040 - accuracy: 0.6209
# Epoch 14/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 1.1753 - accuracy: 0.6274
# Epoch 15/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 1.1502 - accuracy: 0.6348
# Epoch 16/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 1.1308 - accuracy: 0.6411
# Epoch 17/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.1084 - accuracy: 0.6480
# Epoch 18/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.0892 - accuracy: 0.6528
# Epoch 19/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 1.0706 - accuracy: 0.6588
# Epoch 20/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 1.0535 - accuracy: 0.6644
# Epoch 21/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 1.0391 - accuracy: 0.6689
# Epoch 22/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 1.0235 - accuracy: 0.6722
# Epoch 23/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 1.0078 - accuracy: 0.6769
# Epoch 24/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.9956 - accuracy: 0.6822
# Epoch 25/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.9806 - accuracy: 0.6854
# Epoch 26/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.9701 - accuracy: 0.6875
# Epoch 27/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9598 - accuracy: 0.6916
# Epoch 28/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9487 - accuracy: 0.6940
# Epoch 29/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.9399 - accuracy: 0.6967
# Epoch 30/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.9269 - accuracy: 0.7004
# Epoch 31/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.9175 - accuracy: 0.7041
# Epoch 32/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.9085 - accuracy: 0.7058
# Epoch 33/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.8991 - accuracy: 0.7100
# Epoch 34/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.8900 - accuracy: 0.7123
# Epoch 35/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.8824 - accuracy: 0.7155
# Epoch 36/50
# 2444/2444 [==============================] - 16s 6ms/step - loss: 0.8732 - accuracy: 0.7176
# Epoch 37/50
# 2444/2444 [==============================] - 16s 6ms/step - loss: 0.8664 - accuracy: 0.7211
# Epoch 38/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.8581 - accuracy: 0.7211
# Epoch 39/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.8510 - accuracy: 0.7243
# Epoch 40/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.8447 - accuracy: 0.7259
# Epoch 41/50
# 2444/2444 [==============================] - 16s 6ms/step - loss: 0.8368 - accuracy: 0.7270
# Epoch 42/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.8316 - accuracy: 0.7285
# Epoch 43/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.8248 - accuracy: 0.7315
# Epoch 44/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.8172 - accuracy: 0.7338
# Epoch 45/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.8118 - accuracy: 0.7359
# Epoch 46/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.8039 - accuracy: 0.7388
# Epoch 47/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.7987 - accuracy: 0.7385
# Epoch 48/50
# 2444/2444 [==============================] - 16s 6ms/step - loss: 0.7934 - accuracy: 0.7410
# Epoch 49/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.7885 - accuracy: 0.7421
# Epoch 50/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.7832 - accuracy: 0.7436

# %%
# CNN for top right quadrant

# Define the input shape for each quadrant
input_shape = (14, 14, 1)

# Create a sequential model for the top left quadrant
model_tr = Sequential()

# Add a convolutional layer with 16 filters, 3x3 kernel size, and sigmoid activation
model_tr.add(Conv2D(16, kernel_size=(3, 3), activation='sigmoid', input_shape=input_shape))

# Add a max pooling layer with 2x2 pool size
model_tr.add(MaxPooling2D(pool_size=(2, 2)))

# Add a convolutional layer with 32 filters, 3x3 kernel size, and sigmoid activation
model_tr.add(Conv2D(32, kernel_size=(3, 3), activation='sigmoid'))

# Add a max pooling layer with 2x2 pool size
model_tr.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output of the previous layer
model_tr.add(Flatten())

# Add a dense layer with 512 units and relu activation
model_tr.add(Dense(512, activation='relu'))

# Add the output layer with 46 units and softmax activation
model_tr.add(Dense(46, activation='softmax'))

# Compile the model with categorical crossentropy loss and Adam optimizer
model_tr.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model_tr.summary()

# Train the model on the top left quadrant dataset
model_tr.fit(x_train_tr, train_labels_onehot, batch_size=32, epochs=50)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 12, 12, 16)        160
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 16)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 32)          4640
#
#  max_pooling2d_3 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 512)               66048
#
#  dense_3 (Dense)             (None, 46)                23598
#
# =================================================================
# Total params: 94,446
# Trainable params: 94,446
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2444/2444 [==============================] - 14s 5ms/step - loss: 3.3244 - accuracy: 0.1250
# Epoch 2/50
# 2444/2444 [==============================] - 16s 7ms/step - loss: 2.5662 - accuracy: 0.2715
# Epoch 3/50
# 2444/2444 [==============================] - 16s 7ms/step - loss: 2.3012 - accuracy: 0.3373
# Epoch 4/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 2.1258 - accuracy: 0.3822
# Epoch 5/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.9967 - accuracy: 0.4149
# Epoch 6/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.9032 - accuracy: 0.4399
# Epoch 7/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.8301 - accuracy: 0.4594
# Epoch 8/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.7704 - accuracy: 0.4745
# Epoch 9/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.7230 - accuracy: 0.4863
# Epoch 10/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.6839 - accuracy: 0.4983
# Epoch 11/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.6477 - accuracy: 0.5059
# Epoch 12/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.6177 - accuracy: 0.5142
# Epoch 13/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 1.5867 - accuracy: 0.5218
# Epoch 14/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 1.5614 - accuracy: 0.5287
# Epoch 15/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.5389 - accuracy: 0.5347
# Epoch 16/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.5173 - accuracy: 0.5429
# Epoch 17/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 1.4947 - accuracy: 0.5476
# Epoch 18/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 1.4777 - accuracy: 0.5519
# Epoch 19/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.4610 - accuracy: 0.5567
# Epoch 20/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.4442 - accuracy: 0.5600
# Epoch 21/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.4275 - accuracy: 0.5658
# Epoch 22/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.4144 - accuracy: 0.5702
# Epoch 23/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.3996 - accuracy: 0.5742
# Epoch 24/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.3865 - accuracy: 0.5766
# Epoch 25/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.3753 - accuracy: 0.5796
# Epoch 26/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.3621 - accuracy: 0.5838
# Epoch 27/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.3528 - accuracy: 0.5856
# Epoch 28/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.3403 - accuracy: 0.5904
# Epoch 29/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 1.3319 - accuracy: 0.5925
# Epoch 30/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.3198 - accuracy: 0.5963
# Epoch 31/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.3109 - accuracy: 0.5981
# Epoch 32/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.3023 - accuracy: 0.6016
# Epoch 33/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.2938 - accuracy: 0.6032
# Epoch 34/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.2846 - accuracy: 0.6051
# Epoch 35/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.2763 - accuracy: 0.6077
# Epoch 36/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.2675 - accuracy: 0.6091
# Epoch 37/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.2596 - accuracy: 0.6127
# Epoch 38/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.2545 - accuracy: 0.6124
# Epoch 39/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.2453 - accuracy: 0.6177
# Epoch 40/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.2390 - accuracy: 0.6178
# Epoch 41/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.2325 - accuracy: 0.6199
# Epoch 42/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.2248 - accuracy: 0.6218
# Epoch 43/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.2180 - accuracy: 0.6222
# Epoch 44/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.2126 - accuracy: 0.6242
# Epoch 45/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.2055 - accuracy: 0.6274
# Epoch 46/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.2003 - accuracy: 0.6310
# Epoch 47/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.1941 - accuracy: 0.6294
# Epoch 48/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.1889 - accuracy: 0.6322
# Epoch 49/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.1829 - accuracy: 0.6337
# Epoch 50/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.1771 - accuracy: 0.6353

# %%
# CNN for bottom left quadrant

# Define the input shape for each quadrant
input_shape = (14, 14, 1)

# Create a sequential model for the top left quadrant
model_bl = Sequential()

# Add a convolutional layer with 16 filters, 3x3 kernel size, and sigmoid activation
model_bl.add(Conv2D(16, kernel_size=(3, 3), activation='sigmoid', input_shape=input_shape))

# Add a max pooling layer with 2x2 pool size
model_bl.add(MaxPooling2D(pool_size=(2, 2)))

# Add a convolutional layer with 32 filters, 3x3 kernel size, and sigmoid activation
model_bl.add(Conv2D(32, kernel_size=(3, 3), activation='sigmoid'))

# Add a max pooling layer with 2x2 pool size
model_bl.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output of the previous layer
model_bl.add(Flatten())

# Add a dense layer with 512 units and relu activation
model_bl.add(Dense(512, activation='relu'))

# Add the output layer with 46 units and softmax activation
model_bl.add(Dense(46, activation='softmax'))

# Compile the model with categorical crossentropy loss and Adam optimizer
model_bl.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model_bl.summary()

# Train the model on the top left quadrant dataset
model_bl.fit(x_train_bl, train_labels_onehot, batch_size=32, epochs=50)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 12, 12, 16)        160
#
#  max_pooling2d_4 (MaxPooling  (None, 6, 6, 16)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 32)          4640
#
#  max_pooling2d_5 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 512)               66048
#
#  dense_5 (Dense)             (None, 46)                23598
#
# =================================================================
# Total params: 94,446
# Trainable params: 94,446
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2444/2444 [==============================] - 9s 3ms/step - loss: 2.9510 - accuracy: 0.2026
# Epoch 2/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.9096 - accuracy: 0.4353
# Epoch 3/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 1.6225 - accuracy: 0.5087
# Epoch 4/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 1.4542 - accuracy: 0.5521
# Epoch 5/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 1.3386 - accuracy: 0.5838
# Epoch 6/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.2555 - accuracy: 0.6079
# Epoch 7/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.1892 - accuracy: 0.6255
# Epoch 8/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.1334 - accuracy: 0.6419
# Epoch 9/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 1.0893 - accuracy: 0.6545
# Epoch 10/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.0481 - accuracy: 0.6643
# Epoch 11/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.0117 - accuracy: 0.6762
# Epoch 12/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9833 - accuracy: 0.6849
# Epoch 13/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9546 - accuracy: 0.6941
# Epoch 14/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9310 - accuracy: 0.6998
# Epoch 15/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9088 - accuracy: 0.7066
# Epoch 16/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.8875 - accuracy: 0.7119
# Epoch 17/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.8700 - accuracy: 0.7167
# Epoch 18/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.8495 - accuracy: 0.7238
# Epoch 19/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.8342 - accuracy: 0.7261
# Epoch 20/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.8190 - accuracy: 0.7317
# Epoch 21/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.8038 - accuracy: 0.7381
# Epoch 22/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.7904 - accuracy: 0.7387
# Epoch 23/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.7763 - accuracy: 0.7452
# Epoch 24/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.7658 - accuracy: 0.7483
# Epoch 25/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 0.7552 - accuracy: 0.7494
# Epoch 26/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.7445 - accuracy: 0.7551
# Epoch 27/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.7352 - accuracy: 0.7564
# Epoch 28/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.7254 - accuracy: 0.7597
# Epoch 29/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.7172 - accuracy: 0.7628
# Epoch 30/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 0.7086 - accuracy: 0.7658
# Epoch 31/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.6992 - accuracy: 0.7693
# Epoch 32/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.6905 - accuracy: 0.7706
# Epoch 33/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.6834 - accuracy: 0.7727
# Epoch 34/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.6760 - accuracy: 0.7760
# Epoch 35/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.6699 - accuracy: 0.7752
# Epoch 36/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.6631 - accuracy: 0.7794
# Epoch 37/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.6574 - accuracy: 0.7806
# Epoch 38/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 0.6505 - accuracy: 0.7817
# Epoch 39/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 0.6437 - accuracy: 0.7853
# Epoch 40/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.6401 - accuracy: 0.7858
# Epoch 41/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.6347 - accuracy: 0.7858
# Epoch 42/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.6279 - accuracy: 0.7898
# Epoch 43/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.6231 - accuracy: 0.7909
# Epoch 44/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.6177 - accuracy: 0.7921
# Epoch 45/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.6152 - accuracy: 0.7929
# Epoch 46/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.6091 - accuracy: 0.7951
# Epoch 47/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.6026 - accuracy: 0.7979
# Epoch 48/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.5994 - accuracy: 0.7974
# Epoch 49/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.5941 - accuracy: 0.7999
# Epoch 50/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 0.5911 - accuracy: 0.7999

# %%
# CNN for bottom right quadrant

# Define the input shape for each quadrant
input_shape = (14, 14, 1)

# Create a sequential model for the top left quadrant
model_br = Sequential()

# Add a convolutional layer with 16 filters, 3x3 kernel size, and sigmoid activation
model_br.add(Conv2D(16, kernel_size=(3, 3), activation='sigmoid', input_shape=input_shape))

# Add a max pooling layer with 2x2 pool size
model_br.add(MaxPooling2D(pool_size=(2, 2)))

# Add a convolutional layer with 32 filters, 3x3 kernel size, and sigmoid activation
model_br.add(Conv2D(32, kernel_size=(3, 3), activation='sigmoid'))

# Add a max pooling layer with 2x2 pool size
model_br.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output of the previous layer
model_br.add(Flatten())

# Add a dense layer with 512 units and relu activation
model_br.add(Dense(512, activation='relu'))

# Add the output layer with 46 units and softmax activation
model_br.add(Dense(46, activation='softmax'))

# Compile the model with categorical crossentropy loss and Adam optimizer
model_br.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model_br.summary()

# Train the model on the top left quadrant dataset
model_br.fit(x_train_br, train_labels_onehot, batch_size=32, epochs=50)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 12, 12, 16)        160
#
#  max_pooling2d_6 (MaxPooling  (None, 6, 6, 16)         0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 4, 4, 32)          4640
#
#  max_pooling2d_7 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  flatten_3 (Flatten)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 512)               66048
#
#  dense_7 (Dense)             (None, 46)                23598
#
# =================================================================
# Total params: 94,446
# Trainable params: 94,446
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2444/2444 [==============================] - 9s 3ms/step - loss: 3.0343 - accuracy: 0.1762
# Epoch 2/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 2.2126 - accuracy: 0.3386
# Epoch 3/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.9782 - accuracy: 0.3975
# Epoch 4/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.8371 - accuracy: 0.4332
# Epoch 5/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.7399 - accuracy: 0.4624
# Epoch 6/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 1.6636 - accuracy: 0.4810
# Epoch 7/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.6012 - accuracy: 0.4995
# Epoch 8/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.5498 - accuracy: 0.5121
# Epoch 9/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.5025 - accuracy: 0.5268
# Epoch 10/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.4628 - accuracy: 0.5369
# Epoch 11/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 1.4280 - accuracy: 0.5480
# Epoch 12/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.3951 - accuracy: 0.5573
# Epoch 13/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.3675 - accuracy: 0.5650
# Epoch 14/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.3414 - accuracy: 0.5717
# Epoch 15/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.3186 - accuracy: 0.5791
# Epoch 16/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.2964 - accuracy: 0.5850
# Epoch 17/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.2775 - accuracy: 0.5906
# Epoch 18/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.2578 - accuracy: 0.5965
# Epoch 19/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.2423 - accuracy: 0.6004
# Epoch 20/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.2250 - accuracy: 0.6049
# Epoch 21/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.2127 - accuracy: 0.6115
# Epoch 22/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.1971 - accuracy: 0.6152
# Epoch 23/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.1826 - accuracy: 0.6183
# Epoch 24/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.1721 - accuracy: 0.6234
# Epoch 25/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.1598 - accuracy: 0.6265
# Epoch 26/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.1493 - accuracy: 0.6312
# Epoch 27/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 1.1392 - accuracy: 0.6325
# Epoch 28/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.1300 - accuracy: 0.6351
# Epoch 29/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.1190 - accuracy: 0.6382
# Epoch 30/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.1103 - accuracy: 0.6418
# Epoch 31/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.1008 - accuracy: 0.6444
# Epoch 32/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 1.0936 - accuracy: 0.6463
# Epoch 33/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.0856 - accuracy: 0.6490
# Epoch 34/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.0755 - accuracy: 0.6522
# Epoch 35/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 1.0687 - accuracy: 0.6537
# Epoch 36/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.0622 - accuracy: 0.6561
# Epoch 37/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.0548 - accuracy: 0.6586
# Epoch 38/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.0464 - accuracy: 0.6616
# Epoch 39/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.0425 - accuracy: 0.6618
# Epoch 40/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.0346 - accuracy: 0.6652
# Epoch 41/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.0280 - accuracy: 0.6665
# Epoch 42/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.0233 - accuracy: 0.6678
# Epoch 43/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 1.0165 - accuracy: 0.6693
# Epoch 44/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.0093 - accuracy: 0.6727
# Epoch 45/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 1.0035 - accuracy: 0.6732
# Epoch 46/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.9988 - accuracy: 0.6762
# Epoch 47/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.9943 - accuracy: 0.6753
# Epoch 48/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9871 - accuracy: 0.6791
# Epoch 49/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.9827 - accuracy: 0.6806
# Epoch 50/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9781 - accuracy: 0.6800

# %%
# CNN for center quadrant

# Define the input shape for each quadrant
input_shape = (14, 14, 1)

# Create a sequential model for the top left quadrant
model_c = Sequential()

# Add a convolutional layer with 16 filters, 3x3 kernel size, and sigmoid activation
model_c.add(Conv2D(16, kernel_size=(3, 3), activation='sigmoid', input_shape=input_shape))

# Add a max pooling layer with 2x2 pool size
model_c.add(MaxPooling2D(pool_size=(2, 2)))

# Add a convolutional layer with 32 filters, 3x3 kernel size, and sigmoid activation
model_c.add(Conv2D(32, kernel_size=(3, 3), activation='sigmoid'))

# Add a max pooling layer with 2x2 pool size
model_c.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output of the previous layer
model_c.add(Flatten())

# Add a dense layer with 512 units and relu activation
model_c.add(Dense(512, activation='relu'))

# Add the output layer with 46 units and softmax activation
model_c.add(Dense(46, activation='softmax'))

# Compile the model with categorical crossentropy loss and Adam optimizer
model_c.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model_c.summary()

# Train the model on the top left quadrant dataset
model_c.fit(x_train_c, train_labels_onehot, batch_size=32, epochs=50)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 12, 12, 16)        160
#
#  max_pooling2d_8 (MaxPooling  (None, 6, 6, 16)         0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 4, 4, 32)          4640
#
#  max_pooling2d_9 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  flatten_4 (Flatten)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 512)               66048
#
#  dense_9 (Dense)             (None, 46)                23598
#
# =================================================================
# Total params: 94,446
# Trainable params: 94,446
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2444/2444 [==============================] - 9s 3ms/step - loss: 2.9100 - accuracy: 0.2212
# Epoch 2/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.8878 - accuracy: 0.4516
# Epoch 3/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.5424 - accuracy: 0.5454
# Epoch 4/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.3319 - accuracy: 0.6007
# Epoch 5/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.1852 - accuracy: 0.6408
# Epoch 6/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0790 - accuracy: 0.6693
# Epoch 7/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 0.9972 - accuracy: 0.6924
# Epoch 8/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.9302 - accuracy: 0.7100
# Epoch 9/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.8788 - accuracy: 0.7251
# Epoch 10/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 0.8334 - accuracy: 0.7375
# Epoch 11/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 0.7947 - accuracy: 0.7479
# Epoch 12/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 0.7623 - accuracy: 0.7580
# Epoch 13/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.7327 - accuracy: 0.7660
# Epoch 14/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 0.7044 - accuracy: 0.7750
# Epoch 15/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.6813 - accuracy: 0.7813
# Epoch 16/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.6581 - accuracy: 0.7868
# Epoch 17/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.6389 - accuracy: 0.7920
# Epoch 18/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 0.6194 - accuracy: 0.7993
# Epoch 19/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.6025 - accuracy: 0.8039
# Epoch 20/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.5866 - accuracy: 0.8077
# Epoch 21/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.5725 - accuracy: 0.8119
# Epoch 22/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.5576 - accuracy: 0.8169
# Epoch 23/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.5442 - accuracy: 0.8214
# Epoch 24/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.5316 - accuracy: 0.8252
# Epoch 25/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.5197 - accuracy: 0.8286
# Epoch 26/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.5102 - accuracy: 0.8295
# Epoch 27/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.4993 - accuracy: 0.8350
# Epoch 28/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.4888 - accuracy: 0.8384
# Epoch 29/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.4800 - accuracy: 0.8392
# Epoch 30/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 0.4687 - accuracy: 0.8436
# Epoch 31/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.4592 - accuracy: 0.8466
# Epoch 32/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.4527 - accuracy: 0.8480
# Epoch 33/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.4428 - accuracy: 0.8528
# Epoch 34/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.4362 - accuracy: 0.8535
# Epoch 35/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.4301 - accuracy: 0.8554
# Epoch 36/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.4226 - accuracy: 0.8569
# Epoch 37/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.4145 - accuracy: 0.8584
# Epoch 38/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.4087 - accuracy: 0.8623
# Epoch 39/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.4022 - accuracy: 0.8621
# Epoch 40/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.3933 - accuracy: 0.8660
# Epoch 41/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.3897 - accuracy: 0.8681
# Epoch 42/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.3832 - accuracy: 0.8698
# Epoch 43/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.3760 - accuracy: 0.8713
# Epoch 44/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.3717 - accuracy: 0.8728
# Epoch 45/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.3673 - accuracy: 0.8736
# Epoch 46/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.3604 - accuracy: 0.8756
# Epoch 47/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 0.3557 - accuracy: 0.8776
# Epoch 48/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.3514 - accuracy: 0.8793
# Epoch 49/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.3462 - accuracy: 0.8803
# Epoch 50/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.3415 - accuracy: 0.8823

# %%
from tensorflow.keras.models import Model

# create new models to extract features from the last dense layer
model_tl_features = Model(inputs=model_tl.input, outputs=model_tl.get_layer('dense').output)
model_tr_features = Model(inputs=model_tr.input, outputs=model_tr.get_layer('dense_2').output)
model_bl_features = Model(inputs=model_bl.input, outputs=model_bl.get_layer('dense_4').output)
model_br_features = Model(inputs=model_br.input, outputs=model_br.get_layer('dense_6').output)
model_c_features = Model(inputs=model_c.input, outputs=model_c.get_layer('dense_8').output)

# extract features from the last dense layer for each quadrant
tl_features = model_tl_features.predict(x_train_tl)
tr_features = model_tr_features.predict(x_train_tr)
bl_features = model_bl_features.predict(x_train_bl)
br_features = model_br_features.predict(x_train_br)
center_features = model_c_features.predict(x_train_c)

# concatenate the features from all 5 quadrants into a single input
features = np.concatenate((tl_features, tr_features, bl_features, br_features, center_features), axis=1)
# Out:
# 2444/2444 [==============================] - 3s 1ms/step
# 2444/2444 [==============================] - 3s 1ms/step
# 2444/2444 [==============================] - 3s 1ms/step
# 2444/2444 [==============================] - 5s 2ms/step
# 2444/2444 [==============================] - 5s 2ms/step

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# define the DNN classifier model
classifier = Sequential()
classifier.add(Dense(1000, activation='relu', input_shape=(features.shape[1],)))
classifier.add(Dense(1000, activation='relu'))
classifier.add(Dense(1000, activation='relu'))
classifier.add(Dense(46, activation='softmax'))

# compile the model
classifier.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Print model summary
classifier.summary()

history = classifier.fit(features, train_labels_onehot, batch_size=32, epochs=10)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 1000)              2561000
#
#  dense_11 (Dense)            (None, 1000)              1001000
#
#  dense_12 (Dense)            (None, 1000)              1001000
#
#  dense_13 (Dense)            (None, 46)                46046
#
# =================================================================
# Total params: 4,609,046
# Trainable params: 4,609,046
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2444/2444 [==============================] - 161s 66ms/step - loss: 0.2637 - accuracy: 0.9232
# Epoch 2/10
# 2444/2444 [==============================] - 161s 66ms/step - loss: 0.1141 - accuracy: 0.9691
# Epoch 3/10
# 2444/2444 [==============================] - 160s 65ms/step - loss: 0.0888 - accuracy: 0.9775
# Epoch 4/10
# 2444/2444 [==============================] - 161s 66ms/step - loss: 0.0671 - accuracy: 0.9829
# Epoch 5/10
# 2444/2444 [==============================] - 158s 65ms/step - loss: 0.0637 - accuracy: 0.9856
# Epoch 6/10
# 2444/2444 [==============================] - 157s 64ms/step - loss: 0.0632 - accuracy: 0.9867
# Epoch 7/10
# 2444/2444 [==============================] - 157s 64ms/step - loss: 0.0590 - accuracy: 0.9883
# Epoch 8/10
# 2444/2444 [==============================] - 157s 64ms/step - loss: 0.0532 - accuracy: 0.9895
# Epoch 9/10
# 2444/2444 [==============================] - 156s 64ms/step - loss: 0.0543 - accuracy: 0.9904
# Epoch 10/10
# 2444/2444 [==============================] - 156s 64ms/step - loss: 0.0482 - accuracy: 0.9915

# %% [markdown]
# # Preprocessing the test data for prediction and testing

# %%
test_labels_int = label_encoder.fit_transform(test_labels)

# %%
# Convert the integer labels to one-hot encoding
test_labels_onehot = to_categorical(test_labels_int, num_classes=46)

# Split the data into the five quadrants
x_test_tl = test_images[:,:14,:14].reshape(-1, 14, 14, 1)
x_test_tr = test_images[:,:14,14:].reshape(-1, 14, 14, 1)
x_test_bl = test_images[:,14:,:14].reshape(-1, 14, 14, 1)
x_test_br = test_images[:,14:,14:].reshape(-1, 14, 14, 1)
x_test_c = test_images[:,7:21,7:21].reshape(-1, 14, 14, 1)

# %%
# extract features from the last dense layer for each quadrant
tl_features_test = model_tl_features.predict(x_test_tl)
tr_features_test = model_tr_features.predict(x_test_tr)
bl_features_test = model_bl_features.predict(x_test_bl)
br_features_test = model_br_features.predict(x_test_br)
center_features_test = model_c_features.predict(x_test_c)

# concatenate the features from all 5 quadrants into a single input
features_test = np.concatenate((tl_features_test, tr_features_test, bl_features_test, br_features_test, center_features_test), axis=1)
# Out:
# 432/432 [==============================] - 1s 1ms/step
# 432/432 [==============================] - 1s 1ms/step
# 432/432 [==============================] - 1s 1ms/step
# 432/432 [==============================] - 1s 1ms/step
# 432/432 [==============================] - 1s 2ms/step

# %%
# Save the model to disk
classifier.save("f512x5_b32e50_b32e10_1000-1000-1000-46.h5")

# %%
test_predictions = classifier.predict(features_test)
# Out:
# 432/432 [==============================] - 3s 6ms/step

# %%
# Evaluate the model
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
accuracy = accuracy_score(test_labels_int, test_predictions.argmax(axis=1))
precision = precision_score(test_labels_int, test_predictions.argmax(axis=1), average='weighted')
recall = recall_score(test_labels_int, test_predictions.argmax(axis=1), average='weighted')
f1 = f1_score(test_labels_int, test_predictions.argmax(axis=1), average='weighted')

# %%
print('Accuracy:', accuracy)
print('Precision:', precision)
print('Recall:', recall)
print('F1 Score:', f1)
# Out:
# Accuracy: 0.9697826086956521
# Precision: 0.9704111160455927
# Recall: 0.9697826086956521
# F1 Score: 0.9697410979750053
