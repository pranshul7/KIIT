# %%
import os
import numpy as np
import cv2
from PIL import Image
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# %%
# Define the path to the train and test folders
train_path = 'C:/A/code/VSC/python/test/cropped_DevanagariHandwrittenCharacterDataset/Train/'
test_path = 'C:/A/code/VSC/python/test/cropped_DevanagariHandwrittenCharacterDataset/Test/'

# Define a function to load and preprocess the images
def load_images(path):
    # Create empty lists to store the images and labels
    images = []
    labels = []

    # Loop through each folder (which represents a class) in the path
    for folder in os.listdir(path):
        # Get the path to the folder
        folder_path = os.path.join(path, folder)
        # Loop through each image in the folder
        for file in os.listdir(folder_path):
            # Get the path to the image file
            img_path = os.path.join(folder_path, file)
            # Load the image using OpenCV
            img = cv2.imread(img_path)
            # Convert the image to grayscale
            img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            # Normalize the pixel values of the images
            img = img.astype('float32') / 255.0
            # Append the image to the images list
            images.append(img)
            # Append the label to the labels list
            labels.append(folder)

    # Convert the images and labels lists to NumPy arrays
    images = np.array(images)
    labels = np.array(labels)
    
    # Return the images and labels arrays
    return images, labels

# Load the train images and labels
train_images, train_labels = load_images(train_path)

# Load the test images and labels
test_images, test_labels = load_images(test_path)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.utils import to_categorical

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

# Convert the string labels to integer labels
label_encoder = LabelEncoder()
train_labels_int = label_encoder.fit_transform(train_labels)

# %%
# Convert the integer labels to one-hot encoding
train_labels_onehot = to_categorical(train_labels_int, num_classes=46)

# Split the data into the five quadrants
x_train_tl = train_images[:,:14,:14].reshape(-1, 14, 14, 1)
x_train_tr = train_images[:,:14,14:].reshape(-1, 14, 14, 1)
x_train_bl = train_images[:,14:,:14].reshape(-1, 14, 14, 1)
x_train_br = train_images[:,14:,14:].reshape(-1, 14, 14, 1)
x_train_c = train_images[:,7:21,7:21].reshape(-1, 14, 14, 1)

# %%
# CNN for top left quadrant

# Define the input shape for each quadrant
input_shape = (14, 14, 1)

# Create a sequential model for the top left quadrant
model_tl = Sequential()

# Add a convolutional layer with 16 filters, 3x3 kernel size, and sigmoid activation
model_tl.add(Conv2D(16, kernel_size=(3, 3), activation='sigmoid', input_shape=input_shape))

# Add a max pooling layer with 2x2 pool size
model_tl.add(MaxPooling2D(pool_size=(2, 2)))

# Add a convolutional layer with 32 filters, 3x3 kernel size, and sigmoid activation
model_tl.add(Conv2D(32, kernel_size=(3, 3), activation='sigmoid'))

# Add a max pooling layer with 2x2 pool size
model_tl.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output of the previous layer
model_tl.add(Flatten())

# Add a dense layer with 512 units and relu activation
model_tl.add(Dense(512, activation='relu'))

# Add the output layer with 46 units and softmax activation
model_tl.add(Dense(46, activation='softmax'))

# Compile the model with categorical crossentropy loss and Adam optimizer
model_tl.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model_tl.summary()

# Train the model on the top left quadrant dataset
model_tl.fit(x_train_tl, train_labels_onehot, batch_size=16, epochs=50)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 12, 12, 16)        160
#
#  max_pooling2d (MaxPooling2D  (None, 6, 6, 16)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 4, 4, 32)          4640
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 512)               66048
#
#  dense_1 (Dense)             (None, 46)                23598
#
# =================================================================
# Total params: 94,446
# Trainable params: 94,446
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 4888/4888 [==============================] - 14s 3ms/step - loss: 2.7394 - accuracy: 0.2427
# Epoch 2/50
# 4888/4888 [==============================] - 13s 3ms/step - loss: 1.9975 - accuracy: 0.4092
# Epoch 3/50
# 4888/4888 [==============================] - 14s 3ms/step - loss: 1.7689 - accuracy: 0.4672
# Epoch 4/50
# 4888/4888 [==============================] - 13s 3ms/step - loss: 1.6277 - accuracy: 0.5040
# Epoch 5/50
# 4888/4888 [==============================] - 14s 3ms/step - loss: 1.5277 - accuracy: 0.5304
# Epoch 6/50
# 4888/4888 [==============================] - 14s 3ms/step - loss: 1.4472 - accuracy: 0.5520
# Epoch 7/50
# 4888/4888 [==============================] - 14s 3ms/step - loss: 1.3839 - accuracy: 0.5698
# Epoch 8/50
# 4888/4888 [==============================] - 14s 3ms/step - loss: 1.3266 - accuracy: 0.5862
# Epoch 9/50
# 4888/4888 [==============================] - 14s 3ms/step - loss: 1.2800 - accuracy: 0.5982
# Epoch 10/50
# 4888/4888 [==============================] - 14s 3ms/step - loss: 1.2384 - accuracy: 0.6097
# Epoch 11/50
# 4888/4888 [==============================] - 14s 3ms/step - loss: 1.2007 - accuracy: 0.6196
# Epoch 12/50
# 4888/4888 [==============================] - 14s 3ms/step - loss: 1.1699 - accuracy: 0.6296
# Epoch 13/50
# 4888/4888 [==============================] - 15s 3ms/step - loss: 1.1430 - accuracy: 0.6358
# Epoch 14/50
# 4888/4888 [==============================] - 15s 3ms/step - loss: 1.1169 - accuracy: 0.6458
# Epoch 15/50
# 4888/4888 [==============================] - 15s 3ms/step - loss: 1.0951 - accuracy: 0.6510
# Epoch 16/50
# 4888/4888 [==============================] - 15s 3ms/step - loss: 1.0747 - accuracy: 0.6568
# Epoch 17/50
# 4888/4888 [==============================] - 15s 3ms/step - loss: 1.0534 - accuracy: 0.6624
# Epoch 18/50
# 4888/4888 [==============================] - 16s 3ms/step - loss: 1.0355 - accuracy: 0.6685
# Epoch 19/50
# 4888/4888 [==============================] - 16s 3ms/step - loss: 1.0202 - accuracy: 0.6707
# Epoch 20/50
# 4888/4888 [==============================] - 16s 3ms/step - loss: 1.0039 - accuracy: 0.6767
# Epoch 21/50
# 4888/4888 [==============================] - 16s 3ms/step - loss: 0.9905 - accuracy: 0.6801
# Epoch 22/50
# 4888/4888 [==============================] - 17s 4ms/step - loss: 0.9758 - accuracy: 0.6838
# Epoch 23/50
# 4888/4888 [==============================] - 17s 3ms/step - loss: 0.9638 - accuracy: 0.6877
# Epoch 24/50
# 4888/4888 [==============================] - 17s 3ms/step - loss: 0.9511 - accuracy: 0.6912
# Epoch 25/50
# 4888/4888 [==============================] - 17s 4ms/step - loss: 0.9402 - accuracy: 0.6953
# Epoch 26/50
# 4888/4888 [==============================] - 18s 4ms/step - loss: 0.9285 - accuracy: 0.6989
# Epoch 27/50
# 4888/4888 [==============================] - 18s 4ms/step - loss: 0.9184 - accuracy: 0.7026
# Epoch 28/50
# 4888/4888 [==============================] - 19s 4ms/step - loss: 0.9115 - accuracy: 0.7033
# Epoch 29/50
# 4888/4888 [==============================] - 19s 4ms/step - loss: 0.8999 - accuracy: 0.7070
# Epoch 30/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.8934 - accuracy: 0.7084
# Epoch 31/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.8834 - accuracy: 0.7116
# Epoch 32/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.8753 - accuracy: 0.7143
# Epoch 33/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.8657 - accuracy: 0.7159
# Epoch 34/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.8598 - accuracy: 0.7179
# Epoch 35/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.8528 - accuracy: 0.7203
# Epoch 36/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.8449 - accuracy: 0.7238
# Epoch 37/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.8396 - accuracy: 0.7240
# Epoch 38/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.8298 - accuracy: 0.7289
# Epoch 39/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.8273 - accuracy: 0.7289
# Epoch 40/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.8199 - accuracy: 0.7303
# Epoch 41/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.8147 - accuracy: 0.7320
# Epoch 42/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.8088 - accuracy: 0.7342
# Epoch 43/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.8028 - accuracy: 0.7353
# Epoch 44/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.8006 - accuracy: 0.7354
# Epoch 45/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 0.7941 - accuracy: 0.7380
# Epoch 46/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.7894 - accuracy: 0.7407
# Epoch 47/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.7853 - accuracy: 0.7398
# Epoch 48/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.7808 - accuracy: 0.7423
# Epoch 49/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.7736 - accuracy: 0.7448
# Epoch 50/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.7701 - accuracy: 0.7439

# %%
# CNN for top right quadrant

# Define the input shape for each quadrant
input_shape = (14, 14, 1)

# Create a sequential model for the top left quadrant
model_tr = Sequential()

# Add a convolutional layer with 16 filters, 3x3 kernel size, and sigmoid activation
model_tr.add(Conv2D(16, kernel_size=(3, 3), activation='sigmoid', input_shape=input_shape))

# Add a max pooling layer with 2x2 pool size
model_tr.add(MaxPooling2D(pool_size=(2, 2)))

# Add a convolutional layer with 32 filters, 3x3 kernel size, and sigmoid activation
model_tr.add(Conv2D(32, kernel_size=(3, 3), activation='sigmoid'))

# Add a max pooling layer with 2x2 pool size
model_tr.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output of the previous layer
model_tr.add(Flatten())

# Add a dense layer with 512 units and relu activation
model_tr.add(Dense(512, activation='relu'))

# Add the output layer with 46 units and softmax activation
model_tr.add(Dense(46, activation='softmax'))

# Compile the model with categorical crossentropy loss and Adam optimizer
model_tr.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model_tr.summary()

# Train the model on the top left quadrant dataset
model_tr.fit(x_train_tr, train_labels_onehot, batch_size=16, epochs=50)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 12, 12, 16)        160
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 16)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 32)          4640
#
#  max_pooling2d_3 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 512)               66048
#
#  dense_3 (Dense)             (None, 46)                23598
#
# =================================================================
# Total params: 94,446
# Trainable params: 94,446
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 4888/4888 [==============================] - 14s 3ms/step - loss: 3.0885 - accuracy: 0.1690
# Epoch 2/50
# 4888/4888 [==============================] - 13s 3ms/step - loss: 2.4104 - accuracy: 0.3098
# Epoch 3/50
# 4888/4888 [==============================] - 13s 3ms/step - loss: 2.1625 - accuracy: 0.3707
# Epoch 4/50
# 4888/4888 [==============================] - 13s 3ms/step - loss: 2.0135 - accuracy: 0.4105
# Epoch 5/50
# 4888/4888 [==============================] - 13s 3ms/step - loss: 1.9081 - accuracy: 0.4353
# Epoch 6/50
# 4888/4888 [==============================] - 13s 3ms/step - loss: 1.8281 - accuracy: 0.4576
# Epoch 7/50
# 4888/4888 [==============================] - 14s 3ms/step - loss: 1.7654 - accuracy: 0.4732
# Epoch 8/50
# 4888/4888 [==============================] - 14s 3ms/step - loss: 1.7139 - accuracy: 0.4872
# Epoch 9/50
# 4888/4888 [==============================] - 14s 3ms/step - loss: 1.6686 - accuracy: 0.4987
# Epoch 10/50
# 4888/4888 [==============================] - 14s 3ms/step - loss: 1.6283 - accuracy: 0.5095
# Epoch 11/50
# 4888/4888 [==============================] - 14s 3ms/step - loss: 1.5969 - accuracy: 0.5186
# Epoch 12/50
# 4888/4888 [==============================] - 14s 3ms/step - loss: 1.5624 - accuracy: 0.5268
# Epoch 13/50
# 4888/4888 [==============================] - 14s 3ms/step - loss: 1.5367 - accuracy: 0.5330
# Epoch 14/50
# 4888/4888 [==============================] - 15s 3ms/step - loss: 1.5092 - accuracy: 0.5421
# Epoch 15/50
# 4888/4888 [==============================] - 15s 3ms/step - loss: 1.4844 - accuracy: 0.5497
# Epoch 16/50
# 4888/4888 [==============================] - 15s 3ms/step - loss: 1.4637 - accuracy: 0.5540
# Epoch 17/50
# 4888/4888 [==============================] - 15s 3ms/step - loss: 1.4449 - accuracy: 0.5592
# Epoch 18/50
# 4888/4888 [==============================] - 16s 3ms/step - loss: 1.4255 - accuracy: 0.5635
# Epoch 19/50
# 4888/4888 [==============================] - 15s 3ms/step - loss: 1.4063 - accuracy: 0.5688
# Epoch 20/50
# 4888/4888 [==============================] - 16s 3ms/step - loss: 1.3906 - accuracy: 0.5747
# Epoch 21/50
# 4888/4888 [==============================] - 16s 3ms/step - loss: 1.3742 - accuracy: 0.5789
# Epoch 22/50
# 4888/4888 [==============================] - 16s 3ms/step - loss: 1.3605 - accuracy: 0.5821
# Epoch 23/50
# 4888/4888 [==============================] - 17s 3ms/step - loss: 1.3434 - accuracy: 0.5867
# Epoch 24/50
# 4888/4888 [==============================] - 17s 3ms/step - loss: 1.3325 - accuracy: 0.5909
# Epoch 25/50
# 4888/4888 [==============================] - 17s 4ms/step - loss: 1.3191 - accuracy: 0.5958
# Epoch 26/50
# 4888/4888 [==============================] - 17s 4ms/step - loss: 1.3097 - accuracy: 0.5975
# Epoch 27/50
# 4888/4888 [==============================] - 18s 4ms/step - loss: 1.2957 - accuracy: 0.5996
# Epoch 28/50
# 4888/4888 [==============================] - 18s 4ms/step - loss: 1.2861 - accuracy: 0.6031
# Epoch 29/50
# 4888/4888 [==============================] - 19s 4ms/step - loss: 1.2766 - accuracy: 0.6068
# Epoch 30/50
# 4888/4888 [==============================] - 19s 4ms/step - loss: 1.2662 - accuracy: 0.6088
# Epoch 31/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 1.2570 - accuracy: 0.6116
# Epoch 32/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 1.2488 - accuracy: 0.6141
# Epoch 33/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 1.2381 - accuracy: 0.6162
# Epoch 34/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 1.2323 - accuracy: 0.6175
# Epoch 35/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 1.2219 - accuracy: 0.6204
# Epoch 36/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 1.2160 - accuracy: 0.6239
# Epoch 37/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 1.2076 - accuracy: 0.6256
# Epoch 38/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 1.2002 - accuracy: 0.6273
# Epoch 39/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 1.1941 - accuracy: 0.6286
# Epoch 40/50
# 4888/4888 [==============================] - 19s 4ms/step - loss: 1.1866 - accuracy: 0.6317
# Epoch 41/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 1.1805 - accuracy: 0.6324
# Epoch 42/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 1.1738 - accuracy: 0.6341
# Epoch 43/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 1.1657 - accuracy: 0.6354
# Epoch 44/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 1.1614 - accuracy: 0.6383
# Epoch 45/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 1.1561 - accuracy: 0.6398
# Epoch 46/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 1.1484 - accuracy: 0.6419
# Epoch 47/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 1.1446 - accuracy: 0.6427
# Epoch 48/50
# 4888/4888 [==============================] - 24s 5ms/step - loss: 1.1373 - accuracy: 0.6450
# Epoch 49/50
# 4888/4888 [==============================] - 30s 6ms/step - loss: 1.1350 - accuracy: 0.6453
# Epoch 50/50
# 4888/4888 [==============================] - 29s 6ms/step - loss: 1.1279 - accuracy: 0.6469

# %%
# CNN for bottom left quadrant

# Define the input shape for each quadrant
input_shape = (14, 14, 1)

# Create a sequential model for the top left quadrant
model_bl = Sequential()

# Add a convolutional layer with 16 filters, 3x3 kernel size, and sigmoid activation
model_bl.add(Conv2D(16, kernel_size=(3, 3), activation='sigmoid', input_shape=input_shape))

# Add a max pooling layer with 2x2 pool size
model_bl.add(MaxPooling2D(pool_size=(2, 2)))

# Add a convolutional layer with 32 filters, 3x3 kernel size, and sigmoid activation
model_bl.add(Conv2D(32, kernel_size=(3, 3), activation='sigmoid'))

# Add a max pooling layer with 2x2 pool size
model_bl.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output of the previous layer
model_bl.add(Flatten())

# Add a dense layer with 512 units and relu activation
model_bl.add(Dense(512, activation='relu'))

# Add the output layer with 46 units and softmax activation
model_bl.add(Dense(46, activation='softmax'))

# Compile the model with categorical crossentropy loss and Adam optimizer
model_bl.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model_bl.summary()

# Train the model on the top left quadrant dataset
model_bl.fit(x_train_bl, train_labels_onehot, batch_size=16, epochs=50)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 12, 12, 16)        160
#
#  max_pooling2d_4 (MaxPooling  (None, 6, 6, 16)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 32)          4640
#
#  max_pooling2d_5 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 512)               66048
#
#  dense_5 (Dense)             (None, 46)                23598
#
# =================================================================
# Total params: 94,446
# Trainable params: 94,446
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 4888/4888 [==============================] - 14s 3ms/step - loss: 2.6193 - accuracy: 0.2763
# Epoch 2/50
# 4888/4888 [==============================] - 13s 3ms/step - loss: 1.7211 - accuracy: 0.4790
# Epoch 3/50
# 4888/4888 [==============================] - 15s 3ms/step - loss: 1.4798 - accuracy: 0.5436
# Epoch 4/50
# 4888/4888 [==============================] - 16s 3ms/step - loss: 1.3318 - accuracy: 0.5848
# Epoch 5/50
# 4888/4888 [==============================] - 16s 3ms/step - loss: 1.2298 - accuracy: 0.6110
# Epoch 6/50
# 4888/4888 [==============================] - 16s 3ms/step - loss: 1.1536 - accuracy: 0.6335
# Epoch 7/50
# 4888/4888 [==============================] - 16s 3ms/step - loss: 1.0897 - accuracy: 0.6518
# Epoch 8/50
# 4888/4888 [==============================] - 17s 3ms/step - loss: 1.0361 - accuracy: 0.6667
# Epoch 9/50
# 4888/4888 [==============================] - 17s 4ms/step - loss: 0.9917 - accuracy: 0.6805
# Epoch 10/50
# 4888/4888 [==============================] - 18s 4ms/step - loss: 0.9565 - accuracy: 0.6906
# Epoch 11/50
# 4888/4888 [==============================] - 18s 4ms/step - loss: 0.9220 - accuracy: 0.6993
# Epoch 12/50
# 4888/4888 [==============================] - 19s 4ms/step - loss: 0.8938 - accuracy: 0.7092
# Epoch 13/50
# 4888/4888 [==============================] - 19s 4ms/step - loss: 0.8666 - accuracy: 0.7149
# Epoch 14/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.8421 - accuracy: 0.7247
# Epoch 15/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.8196 - accuracy: 0.7316
# Epoch 16/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.7995 - accuracy: 0.7381
# Epoch 17/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.7794 - accuracy: 0.7426
# Epoch 18/50
# 4888/4888 [==============================] - 22s 4ms/step - loss: 0.7650 - accuracy: 0.7478
# Epoch 19/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.7489 - accuracy: 0.7527
# Epoch 20/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.7338 - accuracy: 0.7558
# Epoch 21/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.7190 - accuracy: 0.7591
# Epoch 22/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.7069 - accuracy: 0.7640
# Epoch 23/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.6935 - accuracy: 0.7686
# Epoch 24/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.6836 - accuracy: 0.7708
# Epoch 25/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 0.6713 - accuracy: 0.7762
# Epoch 26/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.6627 - accuracy: 0.7776
# Epoch 27/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.6529 - accuracy: 0.7811
# Epoch 28/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.6443 - accuracy: 0.7839
# Epoch 29/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.6326 - accuracy: 0.7861
# Epoch 30/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.6267 - accuracy: 0.7896
# Epoch 31/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.6201 - accuracy: 0.7908
# Epoch 32/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.6123 - accuracy: 0.7930
# Epoch 33/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.6020 - accuracy: 0.7966
# Epoch 34/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.5973 - accuracy: 0.7983
# Epoch 35/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.5897 - accuracy: 0.7990
# Epoch 36/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 0.5841 - accuracy: 0.8026
# Epoch 37/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.5766 - accuracy: 0.8042
# Epoch 38/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.5695 - accuracy: 0.8054
# Epoch 39/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.5633 - accuracy: 0.8088
# Epoch 40/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.5606 - accuracy: 0.8084
# Epoch 41/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.5548 - accuracy: 0.8101
# Epoch 42/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 0.5500 - accuracy: 0.8126
# Epoch 43/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.5445 - accuracy: 0.8143
# Epoch 44/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.5410 - accuracy: 0.8157
# Epoch 45/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.5348 - accuracy: 0.8176
# Epoch 46/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 0.5279 - accuracy: 0.8193
# Epoch 47/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.5256 - accuracy: 0.8205
# Epoch 48/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 0.5231 - accuracy: 0.8205
# Epoch 49/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.5166 - accuracy: 0.8221
# Epoch 50/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.5131 - accuracy: 0.8244

# %%
# CNN for bottom right quadrant

# Define the input shape for each quadrant
input_shape = (14, 14, 1)

# Create a sequential model for the top left quadrant
model_br = Sequential()

# Add a convolutional layer with 16 filters, 3x3 kernel size, and sigmoid activation
model_br.add(Conv2D(16, kernel_size=(3, 3), activation='sigmoid', input_shape=input_shape))

# Add a max pooling layer with 2x2 pool size
model_br.add(MaxPooling2D(pool_size=(2, 2)))

# Add a convolutional layer with 32 filters, 3x3 kernel size, and sigmoid activation
model_br.add(Conv2D(32, kernel_size=(3, 3), activation='sigmoid'))

# Add a max pooling layer with 2x2 pool size
model_br.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output of the previous layer
model_br.add(Flatten())

# Add a dense layer with 512 units and relu activation
model_br.add(Dense(512, activation='relu'))

# Add the output layer with 46 units and softmax activation
model_br.add(Dense(46, activation='softmax'))

# Compile the model with categorical crossentropy loss and Adam optimizer
model_br.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model_br.summary()

# Train the model on the top left quadrant dataset
model_br.fit(x_train_br, train_labels_onehot, batch_size=16, epochs=50)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 12, 12, 16)        160
#
#  max_pooling2d_6 (MaxPooling  (None, 6, 6, 16)         0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 4, 4, 32)          4640
#
#  max_pooling2d_7 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  flatten_3 (Flatten)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 512)               66048
#
#  dense_7 (Dense)             (None, 46)                23598
#
# =================================================================
# Total params: 94,446
# Trainable params: 94,446
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 4888/4888 [==============================] - 14s 3ms/step - loss: 3.0452 - accuracy: 0.1714
# Epoch 2/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 2.1419 - accuracy: 0.3567
# Epoch 3/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 1.8932 - accuracy: 0.4187
# Epoch 4/50
# 4888/4888 [==============================] - 22s 5ms/step - loss: 1.7549 - accuracy: 0.4531
# Epoch 5/50
# 4888/4888 [==============================] - 22s 4ms/step - loss: 1.6585 - accuracy: 0.4788
# Epoch 6/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 1.5865 - accuracy: 0.4984
# Epoch 7/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 1.5275 - accuracy: 0.5175
# Epoch 8/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 1.4811 - accuracy: 0.5292
# Epoch 9/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 1.4405 - accuracy: 0.5424
# Epoch 10/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 1.4063 - accuracy: 0.5527
# Epoch 11/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 1.3765 - accuracy: 0.5607
# Epoch 12/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 1.3498 - accuracy: 0.5680
# Epoch 13/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 1.3236 - accuracy: 0.5782
# Epoch 14/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 1.3032 - accuracy: 0.5838
# Epoch 15/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 1.2829 - accuracy: 0.5890
# Epoch 16/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 1.2652 - accuracy: 0.5930
# Epoch 17/50
# 4888/4888 [==============================] - 22s 4ms/step - loss: 1.2486 - accuracy: 0.5990
# Epoch 18/50
# 4888/4888 [==============================] - 22s 4ms/step - loss: 1.2345 - accuracy: 0.6034
# Epoch 19/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 1.2198 - accuracy: 0.6089
# Epoch 20/50
# 4888/4888 [==============================] - 22s 4ms/step - loss: 1.2061 - accuracy: 0.6125
# Epoch 21/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 1.1946 - accuracy: 0.6160
# Epoch 22/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 1.1816 - accuracy: 0.6192
# Epoch 23/50
# 4888/4888 [==============================] - 22s 4ms/step - loss: 1.1702 - accuracy: 0.6213
# Epoch 24/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 1.1577 - accuracy: 0.6279
# Epoch 25/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 1.1493 - accuracy: 0.6273
# Epoch 26/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 1.1391 - accuracy: 0.6331
# Epoch 27/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 1.1311 - accuracy: 0.6347
# Epoch 28/50
# 4888/4888 [==============================] - 22s 4ms/step - loss: 1.1222 - accuracy: 0.6364
# Epoch 29/50
# 4888/4888 [==============================] - 22s 4ms/step - loss: 1.1119 - accuracy: 0.6412
# Epoch 30/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 1.1063 - accuracy: 0.6411
# Epoch 31/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 1.0979 - accuracy: 0.6438
# Epoch 32/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 1.0891 - accuracy: 0.6483
# Epoch 33/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 1.0829 - accuracy: 0.6495
# Epoch 34/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 1.0769 - accuracy: 0.6505
# Epoch 35/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 1.0697 - accuracy: 0.6537
# Epoch 36/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 1.0636 - accuracy: 0.6552
# Epoch 37/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 1.0571 - accuracy: 0.6574
# Epoch 38/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 1.0507 - accuracy: 0.6608
# Epoch 39/50
# 4888/4888 [==============================] - 22s 4ms/step - loss: 1.0445 - accuracy: 0.6618
# Epoch 40/50
# 4888/4888 [==============================] - 22s 5ms/step - loss: 1.0391 - accuracy: 0.6628
# Epoch 41/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 1.0339 - accuracy: 0.6636
# Epoch 42/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 1.0288 - accuracy: 0.6651
# Epoch 43/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 1.0244 - accuracy: 0.6662
# Epoch 44/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 1.0186 - accuracy: 0.6692
# Epoch 45/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 1.0135 - accuracy: 0.6695
# Epoch 46/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 1.0110 - accuracy: 0.6707
# Epoch 47/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 1.0031 - accuracy: 0.6728
# Epoch 48/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 1.0018 - accuracy: 0.6740
# Epoch 49/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.9971 - accuracy: 0.6756
# Epoch 50/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.9912 - accuracy: 0.6763

# %%
# CNN for center quadrant

# Define the input shape for each quadrant
input_shape = (14, 14, 1)

# Create a sequential model for the top left quadrant
model_c = Sequential()

# Add a convolutional layer with 16 filters, 3x3 kernel size, and sigmoid activation
model_c.add(Conv2D(16, kernel_size=(3, 3), activation='sigmoid', input_shape=input_shape))

# Add a max pooling layer with 2x2 pool size
model_c.add(MaxPooling2D(pool_size=(2, 2)))

# Add a convolutional layer with 32 filters, 3x3 kernel size, and sigmoid activation
model_c.add(Conv2D(32, kernel_size=(3, 3), activation='sigmoid'))

# Add a max pooling layer with 2x2 pool size
model_c.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output of the previous layer
model_c.add(Flatten())

# Add a dense layer with 512 units and relu activation
model_c.add(Dense(512, activation='relu'))

# Add the output layer with 46 units and softmax activation
model_c.add(Dense(46, activation='softmax'))

# Compile the model with categorical crossentropy loss and Adam optimizer
model_c.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model_c.summary()

# Train the model on the top left quadrant dataset
model_c.fit(x_train_c, train_labels_onehot, batch_size=16, epochs=50)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 12, 12, 16)        160
#
#  max_pooling2d_8 (MaxPooling  (None, 6, 6, 16)         0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 4, 4, 32)          4640
#
#  max_pooling2d_9 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  flatten_4 (Flatten)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 512)               66048
#
#  dense_9 (Dense)             (None, 46)                23598
#
# =================================================================
# Total params: 94,446
# Trainable params: 94,446
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 4888/4888 [==============================] - 14s 3ms/step - loss: 2.8562 - accuracy: 0.2320
# Epoch 2/50
# 4888/4888 [==============================] - 16s 3ms/step - loss: 1.8135 - accuracy: 0.4730
# Epoch 3/50
# 4888/4888 [==============================] - 18s 4ms/step - loss: 1.4329 - accuracy: 0.5739
# Epoch 4/50
# 4888/4888 [==============================] - 19s 4ms/step - loss: 1.2212 - accuracy: 0.6292
# Epoch 5/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 1.0847 - accuracy: 0.6659
# Epoch 6/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.9905 - accuracy: 0.6910
# Epoch 7/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.9198 - accuracy: 0.7131
# Epoch 8/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 0.8648 - accuracy: 0.7283
# Epoch 9/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 0.8213 - accuracy: 0.7400
# Epoch 10/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 0.7848 - accuracy: 0.7510
# Epoch 11/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 0.7538 - accuracy: 0.7597
# Epoch 12/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.7249 - accuracy: 0.7666
# Epoch 13/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.7007 - accuracy: 0.7733
# Epoch 14/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.6781 - accuracy: 0.7810
# Epoch 15/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.6591 - accuracy: 0.7859
# Epoch 16/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 0.6415 - accuracy: 0.7921
# Epoch 17/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.6235 - accuracy: 0.7974
# Epoch 18/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.6095 - accuracy: 0.8015
# Epoch 19/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.5962 - accuracy: 0.8052
# Epoch 20/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 0.5832 - accuracy: 0.8096
# Epoch 21/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.5698 - accuracy: 0.8135
# Epoch 22/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 0.5604 - accuracy: 0.8156
# Epoch 23/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 0.5510 - accuracy: 0.8180
# Epoch 24/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.5384 - accuracy: 0.8223
# Epoch 25/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.5288 - accuracy: 0.8243
# Epoch 26/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 0.5195 - accuracy: 0.8276
# Epoch 27/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.5132 - accuracy: 0.8291
# Epoch 28/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.5031 - accuracy: 0.8315
# Epoch 29/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 0.4961 - accuracy: 0.8346
# Epoch 30/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.4887 - accuracy: 0.8380
# Epoch 31/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.4827 - accuracy: 0.8386
# Epoch 32/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.4730 - accuracy: 0.8416
# Epoch 33/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.4697 - accuracy: 0.8416
# Epoch 34/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.4612 - accuracy: 0.8448
# Epoch 35/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 0.4543 - accuracy: 0.8467
# Epoch 36/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.4488 - accuracy: 0.8486
# Epoch 37/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.4426 - accuracy: 0.8499
# Epoch 38/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.4389 - accuracy: 0.8507
# Epoch 39/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.4319 - accuracy: 0.8539
# Epoch 40/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.4285 - accuracy: 0.8553
# Epoch 41/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 0.4238 - accuracy: 0.8558
# Epoch 42/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 0.4185 - accuracy: 0.8578
# Epoch 43/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 0.4123 - accuracy: 0.8603
# Epoch 44/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.4102 - accuracy: 0.8576
# Epoch 45/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 0.4042 - accuracy: 0.8627
# Epoch 46/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.4008 - accuracy: 0.8617
# Epoch 47/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 0.3962 - accuracy: 0.8644
# Epoch 48/50
# 4888/4888 [==============================] - 20s 4ms/step - loss: 0.3923 - accuracy: 0.8647
# Epoch 49/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 0.3894 - accuracy: 0.8648
# Epoch 50/50
# 4888/4888 [==============================] - 21s 4ms/step - loss: 0.3843 - accuracy: 0.8685

# %%
from tensorflow.keras.models import Model

# create new models to extract features from the last dense layer
model_tl_features = Model(inputs=model_tl.input, outputs=model_tl.get_layer('dense').output)
model_tr_features = Model(inputs=model_tr.input, outputs=model_tr.get_layer('dense_2').output)
model_bl_features = Model(inputs=model_bl.input, outputs=model_bl.get_layer('dense_4').output)
model_br_features = Model(inputs=model_br.input, outputs=model_br.get_layer('dense_6').output)
model_c_features = Model(inputs=model_c.input, outputs=model_c.get_layer('dense_8').output)

# extract features from the last dense layer for each quadrant
tl_features = model_tl_features.predict(x_train_tl)
tr_features = model_tr_features.predict(x_train_tr)
bl_features = model_bl_features.predict(x_train_bl)
br_features = model_br_features.predict(x_train_br)
center_features = model_c_features.predict(x_train_c)

# concatenate the features from all 5 quadrants into a single input
features = np.concatenate((tl_features, tr_features, bl_features, br_features, center_features), axis=1)
# Out:
# 2444/2444 [==============================] - 3s 1ms/step
# 2444/2444 [==============================] - 5s 2ms/step
# 2444/2444 [==============================] - 6s 2ms/step
# 2444/2444 [==============================] - 6s 2ms/step
# 2444/2444 [==============================] - 5s 2ms/step

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# define the DNN classifier model
classifier = Sequential()
classifier.add(Dense(1000, activation='relu', input_shape=(features.shape[1],)))
classifier.add(Dense(1000, activation='relu'))
classifier.add(Dense(1000, activation='relu'))
classifier.add(Dense(46, activation='softmax'))

# compile the model
classifier.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Print model summary
classifier.summary()

history = classifier.fit(features, train_labels_onehot, batch_size=16, epochs=10)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 1000)              2561000
#
#  dense_11 (Dense)            (None, 1000)              1001000
#
#  dense_12 (Dense)            (None, 1000)              1001000
#
#  dense_13 (Dense)            (None, 46)                46046
#
# =================================================================
# Total params: 4,609,046
# Trainable params: 4,609,046
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 4888/4888 [==============================] - 280s 57ms/step - loss: 0.2794 - accuracy: 0.9234
# Epoch 2/10
# 4888/4888 [==============================] - 275s 56ms/step - loss: 0.1296 - accuracy: 0.9696
# Epoch 3/10
# 4888/4888 [==============================] - 271s 55ms/step - loss: 0.1053 - accuracy: 0.9778
# Epoch 4/10
# 4888/4888 [==============================] - 271s 55ms/step - loss: 0.0875 - accuracy: 0.9821
# Epoch 5/10
# 4888/4888 [==============================] - 274s 56ms/step - loss: 0.0815 - accuracy: 0.9855
# Epoch 6/10
# 4888/4888 [==============================] - 276s 56ms/step - loss: 0.0795 - accuracy: 0.9869
# Epoch 7/10
# 4888/4888 [==============================] - 274s 56ms/step - loss: 0.0837 - accuracy: 0.9872
# Epoch 8/10
# 4888/4888 [==============================] - 275s 56ms/step - loss: 0.0657 - accuracy: 0.9901
# Epoch 9/10
# 4888/4888 [==============================] - 277s 57ms/step - loss: 0.0596 - accuracy: 0.9907
# Epoch 10/10
# 4888/4888 [==============================] - 276s 57ms/step - loss: 0.0632 - accuracy: 0.9913

# %% [markdown]
# # Preprocessing the test data for prediction and testing

# %%
test_labels_int = label_encoder.fit_transform(test_labels)

# %%
# Convert the integer labels to one-hot encoding
test_labels_onehot = to_categorical(test_labels_int, num_classes=46)

# Split the data into the five quadrants
x_test_tl = test_images[:,:14,:14].reshape(-1, 14, 14, 1)
x_test_tr = test_images[:,:14,14:].reshape(-1, 14, 14, 1)
x_test_bl = test_images[:,14:,:14].reshape(-1, 14, 14, 1)
x_test_br = test_images[:,14:,14:].reshape(-1, 14, 14, 1)
x_test_c = test_images[:,7:21,7:21].reshape(-1, 14, 14, 1)

# %%
# extract features from the last dense layer for each quadrant
tl_features_test = model_tl_features.predict(x_test_tl)
tr_features_test = model_tr_features.predict(x_test_tr)
bl_features_test = model_bl_features.predict(x_test_bl)
br_features_test = model_br_features.predict(x_test_br)
center_features_test = model_c_features.predict(x_test_c)

# concatenate the features from all 5 quadrants into a single input
features_test = np.concatenate((tl_features_test, tr_features_test, bl_features_test, br_features_test, center_features_test), axis=1)
# Out:
# 432/432 [==============================] - 1s 1ms/step
# 432/432 [==============================] - 1s 2ms/step
# 432/432 [==============================] - 1s 1ms/step
# 432/432 [==============================] - 1s 1ms/step
# 432/432 [==============================] - 1s 1ms/step

# %%
# Save the model to disk
classifier.save("f512x5_b16e50_b16e10_1000-1000-1000-46.h5")

# %%
test_predictions = classifier.predict(features_test)
# Out:
# 432/432 [==============================] - 3s 6ms/step

# %%
# Evaluate the model
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
accuracy = accuracy_score(test_labels_int, test_predictions.argmax(axis=1))
precision = precision_score(test_labels_int, test_predictions.argmax(axis=1), average='weighted')
recall = recall_score(test_labels_int, test_predictions.argmax(axis=1), average='weighted')
f1 = f1_score(test_labels_int, test_predictions.argmax(axis=1), average='weighted')

# %%
print('Accuracy:', accuracy)
print('Precision:', precision)
print('Recall:', recall)
print('F1 Score:', f1)
# Out:
# Accuracy: 0.9660144927536232
# Precision: 0.9674351143766132
# Recall: 0.9660144927536232
# F1 Score: 0.9661931136775347
