# %%
import os
import numpy as np
import cv2
from PIL import Image
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# %%
# Define the path to the train and test folders
train_path = 'C:/A/code/VSC/python/test/cropped_DevanagariHandwrittenCharacterDataset/Train/'
test_path = 'C:/A/code/VSC/python/test/cropped_DevanagariHandwrittenCharacterDataset/Test/'

# Define a function to load and preprocess the images
def load_images(path):
    # Create empty lists to store the images and labels
    images = []
    labels = []

    # Loop through each folder (which represents a class) in the path
    for folder in os.listdir(path):
        # Get the path to the folder
        folder_path = os.path.join(path, folder)
        # Loop through each image in the folder
        for file in os.listdir(folder_path):
            # Get the path to the image file
            img_path = os.path.join(folder_path, file)
            # Load the image using OpenCV
            img = cv2.imread(img_path)
            # Convert the image to grayscale
            img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            # Normalize the pixel values of the images
            img = img.astype('float32') / 255.0
            # Append the image to the images list
            images.append(img)
            # Append the label to the labels list
            labels.append(folder)

    # Convert the images and labels lists to NumPy arrays
    images = np.array(images)
    labels = np.array(labels)
    
    # Return the images and labels arrays
    return images, labels

# Load the train images and labels
train_images, train_labels = load_images(train_path)

# Load the test images and labels
test_images, test_labels = load_images(test_path)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.utils import to_categorical

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

# Convert the string labels to integer labels
label_encoder = LabelEncoder()
train_labels_int = label_encoder.fit_transform(train_labels)

# %%
# Convert the integer labels to one-hot encoding
train_labels_onehot = to_categorical(train_labels_int, num_classes=46)

# Split the data into the five quadrants
x_train_tl = train_images[:,:14,:14].reshape(-1, 14, 14, 1)
x_train_tr = train_images[:,:14,14:].reshape(-1, 14, 14, 1)
x_train_bl = train_images[:,14:,:14].reshape(-1, 14, 14, 1)
x_train_br = train_images[:,14:,14:].reshape(-1, 14, 14, 1)
x_train_c = train_images[:,7:21,7:21].reshape(-1, 14, 14, 1)
x_train_tm = train_images[:,:14,7:21].reshape(-1, 14, 14, 1)
x_train_bm = train_images[:,14:,7:21].reshape(-1, 14, 14, 1)
x_train_lm = train_images[:,7:21,:14].reshape(-1, 14, 14, 1)
x_train_rm = train_images[:,7:21,14:].reshape(-1, 14, 14, 1)

# %%
# CNN for top left quadrant

# Define the input shape for each quadrant
input_shape = (14, 14, 1)

# Create a sequential model for the top left quadrant
model_tl = Sequential()

# Add a convolutional layer with 16 filters, 3x3 kernel size, and sigmoid activation
model_tl.add(Conv2D(16, kernel_size=(3, 3), activation='sigmoid', input_shape=input_shape))

# Add a max pooling layer with 2x2 pool size
model_tl.add(MaxPooling2D(pool_size=(2, 2)))

# Add a convolutional layer with 32 filters, 3x3 kernel size, and sigmoid activation
model_tl.add(Conv2D(32, kernel_size=(3, 3), activation='sigmoid'))

# Add a max pooling layer with 2x2 pool size
model_tl.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output of the previous layer
model_tl.add(Flatten())

# Add the output layer with 46 units and softmax activation
model_tl.add(Dense(46, activation='softmax'))

# Compile the model with categorical crossentropy loss and Adam optimizer
model_tl.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model_tl.summary()

# Train the model on the top left quadrant dataset
model_tl.fit(x_train_tl, train_labels_onehot, batch_size=32, epochs=50)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 12, 12, 16)        160
#
#  max_pooling2d (MaxPooling2D  (None, 6, 6, 16)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 4, 4, 32)          4640
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 46)                5934
#
# =================================================================
# Total params: 10,734
# Trainable params: 10,734
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 3.2990 - accuracy: 0.1381
# Epoch 2/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 2.5255 - accuracy: 0.3039
# Epoch 3/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 2.2466 - accuracy: 0.3697
# Epoch 4/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 2.0986 - accuracy: 0.4046
# Epoch 5/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 2.0001 - accuracy: 0.4297
# Epoch 6/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 1.9298 - accuracy: 0.4471
# Epoch 7/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 1.8729 - accuracy: 0.4601
# Epoch 8/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.8263 - accuracy: 0.4717
# Epoch 9/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 1.7871 - accuracy: 0.4829
# Epoch 10/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 1.7511 - accuracy: 0.4910
# Epoch 11/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.7194 - accuracy: 0.4975
# Epoch 12/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.6913 - accuracy: 0.5055
# Epoch 13/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 1.6642 - accuracy: 0.5119
# Epoch 14/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.6405 - accuracy: 0.5182
# Epoch 15/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.6184 - accuracy: 0.5243
# Epoch 16/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.5977 - accuracy: 0.5291
# Epoch 17/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.5789 - accuracy: 0.5332
# Epoch 18/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.5613 - accuracy: 0.5383
# Epoch 19/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.5421 - accuracy: 0.5427
# Epoch 20/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.5269 - accuracy: 0.5467
# Epoch 21/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.5122 - accuracy: 0.5502
# Epoch 22/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.4986 - accuracy: 0.5532
# Epoch 23/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.4862 - accuracy: 0.5565
# Epoch 24/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.4732 - accuracy: 0.5605
# Epoch 25/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.4622 - accuracy: 0.5638
# Epoch 26/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.4515 - accuracy: 0.5649
# Epoch 27/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.4410 - accuracy: 0.5686
# Epoch 28/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.4317 - accuracy: 0.5719
# Epoch 29/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.4226 - accuracy: 0.5727
# Epoch 30/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.4139 - accuracy: 0.5756
# Epoch 31/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.4057 - accuracy: 0.5777
# Epoch 32/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.3978 - accuracy: 0.5797
# Epoch 33/50
# 2444/2444 [==============================] - 9s 3ms/step - loss: 1.3912 - accuracy: 0.5808
# Epoch 34/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.3838 - accuracy: 0.5845
# Epoch 35/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.3770 - accuracy: 0.5853
# Epoch 36/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.3714 - accuracy: 0.5878
# Epoch 37/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.3648 - accuracy: 0.5893
# Epoch 38/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.3592 - accuracy: 0.5901
# Epoch 39/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.3540 - accuracy: 0.5919
# Epoch 40/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.3481 - accuracy: 0.5927
# Epoch 41/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.3422 - accuracy: 0.5952
# Epoch 42/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.3378 - accuracy: 0.5975
# Epoch 43/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.3338 - accuracy: 0.5987
# Epoch 44/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.3282 - accuracy: 0.5983
# Epoch 45/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.3237 - accuracy: 0.6001
# Epoch 46/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.3192 - accuracy: 0.6016
# Epoch 47/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.3165 - accuracy: 0.6035
# Epoch 48/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.3122 - accuracy: 0.6047
# Epoch 49/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.3081 - accuracy: 0.6046
# Epoch 50/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.3043 - accuracy: 0.6067

# %%
# CNN for top right quadrant

# Define the input shape for each quadrant
input_shape = (14, 14, 1)

# Create a sequential model for the top left quadrant
model_tr = Sequential()

# Add a convolutional layer with 16 filters, 3x3 kernel size, and sigmoid activation
model_tr.add(Conv2D(16, kernel_size=(3, 3), activation='sigmoid', input_shape=input_shape))

# Add a max pooling layer with 2x2 pool size
model_tr.add(MaxPooling2D(pool_size=(2, 2)))

# Add a convolutional layer with 32 filters, 3x3 kernel size, and sigmoid activation
model_tr.add(Conv2D(32, kernel_size=(3, 3), activation='sigmoid'))

# Add a max pooling layer with 2x2 pool size
model_tr.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output of the previous layer
model_tr.add(Flatten())

# Add the output layer with 46 units and softmax activation
model_tr.add(Dense(46, activation='softmax'))

# Compile the model with categorical crossentropy loss and Adam optimizer
model_tr.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model_tr.summary()

# Train the model on the top left quadrant dataset
model_tr.fit(x_train_tr, train_labels_onehot, batch_size=32, epochs=50)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 12, 12, 16)        160
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 16)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 32)          4640
#
#  max_pooling2d_3 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 46)                5934
#
# =================================================================
# Total params: 10,734
# Trainable params: 10,734
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 3.5120 - accuracy: 0.1033
# Epoch 2/50
# 2444/2444 [==============================] - 6s 3ms/step - loss: 2.8660 - accuracy: 0.2320
# Epoch 3/50
# 2444/2444 [==============================] - 6s 3ms/step - loss: 2.5828 - accuracy: 0.2909
# Epoch 4/50
# 2444/2444 [==============================] - 6s 3ms/step - loss: 2.4220 - accuracy: 0.3260
# Epoch 5/50
# 2444/2444 [==============================] - 6s 3ms/step - loss: 2.3152 - accuracy: 0.3484
# Epoch 6/50
# 2444/2444 [==============================] - 6s 3ms/step - loss: 2.2393 - accuracy: 0.3643
# Epoch 7/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 2.1812 - accuracy: 0.3803
# Epoch 8/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 2.1322 - accuracy: 0.3920
# Epoch 9/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 2.0925 - accuracy: 0.4005
# Epoch 10/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 2.0576 - accuracy: 0.4097
# Epoch 11/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 2.0274 - accuracy: 0.4166
# Epoch 12/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 2.0011 - accuracy: 0.4228
# Epoch 13/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 1.9783 - accuracy: 0.4276
# Epoch 14/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 1.9575 - accuracy: 0.4334
# Epoch 15/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 1.9382 - accuracy: 0.4365
# Epoch 16/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.9217 - accuracy: 0.4425
# Epoch 17/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.9054 - accuracy: 0.4452
# Epoch 18/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.8907 - accuracy: 0.4495
# Epoch 19/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.8767 - accuracy: 0.4524
# Epoch 20/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.8646 - accuracy: 0.4559
# Epoch 21/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.8525 - accuracy: 0.4578
# Epoch 22/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.8418 - accuracy: 0.4625
# Epoch 23/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.8330 - accuracy: 0.4636
# Epoch 24/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.8220 - accuracy: 0.4660
# Epoch 25/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.8142 - accuracy: 0.4681
# Epoch 26/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.8056 - accuracy: 0.4697
# Epoch 27/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.7975 - accuracy: 0.4716
# Epoch 28/50
# 2444/2444 [==============================] - 9s 3ms/step - loss: 1.7890 - accuracy: 0.4732
# Epoch 29/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.7823 - accuracy: 0.4773
# Epoch 30/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.7752 - accuracy: 0.4771
# Epoch 31/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.7684 - accuracy: 0.4788
# Epoch 32/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.7615 - accuracy: 0.4803
# Epoch 33/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.7572 - accuracy: 0.4829
# Epoch 34/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.7510 - accuracy: 0.4852
# Epoch 35/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.7448 - accuracy: 0.4858
# Epoch 36/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.7398 - accuracy: 0.4872
# Epoch 37/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.7343 - accuracy: 0.4873
# Epoch 38/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.7285 - accuracy: 0.4902
# Epoch 39/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.7248 - accuracy: 0.4913
# Epoch 40/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.7202 - accuracy: 0.4921
# Epoch 41/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.7155 - accuracy: 0.4937
# Epoch 42/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.7107 - accuracy: 0.4950
# Epoch 43/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.7067 - accuracy: 0.4952
# Epoch 44/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.7027 - accuracy: 0.4968
# Epoch 45/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.6985 - accuracy: 0.4967
# Epoch 46/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.6956 - accuracy: 0.4974
# Epoch 47/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.6922 - accuracy: 0.4993
# Epoch 48/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.6881 - accuracy: 0.5013
# Epoch 49/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.6846 - accuracy: 0.5009
# Epoch 50/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.6803 - accuracy: 0.5024

# %%
# CNN for bottom left quadrant

# Define the input shape for each quadrant
input_shape = (14, 14, 1)

# Create a sequential model for the top left quadrant
model_bl = Sequential()

# Add a convolutional layer with 16 filters, 3x3 kernel size, and sigmoid activation
model_bl.add(Conv2D(16, kernel_size=(3, 3), activation='sigmoid', input_shape=input_shape))

# Add a max pooling layer with 2x2 pool size
model_bl.add(MaxPooling2D(pool_size=(2, 2)))

# Add a convolutional layer with 32 filters, 3x3 kernel size, and sigmoid activation
model_bl.add(Conv2D(32, kernel_size=(3, 3), activation='sigmoid'))

# Add a max pooling layer with 2x2 pool size
model_bl.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output of the previous layer
model_bl.add(Flatten())

# Add the output layer with 46 units and softmax activation
model_bl.add(Dense(46, activation='softmax'))

# Compile the model with categorical crossentropy loss and Adam optimizer
model_bl.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model_bl.summary()

# Train the model on the top left quadrant dataset
model_bl.fit(x_train_bl, train_labels_onehot, batch_size=32, epochs=50)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 12, 12, 16)        160
#
#  max_pooling2d_4 (MaxPooling  (None, 6, 6, 16)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 32)          4640
#
#  max_pooling2d_5 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 46)                5934
#
# =================================================================
# Total params: 10,734
# Trainable params: 10,734
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 3.2503 - accuracy: 0.1525
# Epoch 2/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 2.3509 - accuracy: 0.3599
# Epoch 3/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 2.0171 - accuracy: 0.4394
# Epoch 4/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.8372 - accuracy: 0.4806
# Epoch 5/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.7256 - accuracy: 0.5072
# Epoch 6/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 1.6460 - accuracy: 0.5264
# Epoch 7/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 1.5844 - accuracy: 0.5398
# Epoch 8/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 1.5344 - accuracy: 0.5521
# Epoch 9/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 1.4920 - accuracy: 0.5615
# Epoch 10/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 1.4559 - accuracy: 0.5706
# Epoch 11/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.4241 - accuracy: 0.5778
# Epoch 12/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.3950 - accuracy: 0.5842
# Epoch 13/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.3696 - accuracy: 0.5908
# Epoch 14/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.3458 - accuracy: 0.5970
# Epoch 15/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.3249 - accuracy: 0.6031
# Epoch 16/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.3052 - accuracy: 0.6083
# Epoch 17/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.2877 - accuracy: 0.6125
# Epoch 18/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.2713 - accuracy: 0.6160
# Epoch 19/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.2572 - accuracy: 0.6208
# Epoch 20/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.2427 - accuracy: 0.6254
# Epoch 21/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.2298 - accuracy: 0.6267
# Epoch 22/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.2171 - accuracy: 0.6305
# Epoch 23/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.2069 - accuracy: 0.6340
# Epoch 24/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.1962 - accuracy: 0.6365
# Epoch 25/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.1869 - accuracy: 0.6381
# Epoch 26/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.1775 - accuracy: 0.6416
# Epoch 27/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.1685 - accuracy: 0.6439
# Epoch 28/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.1604 - accuracy: 0.6463
# Epoch 29/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.1527 - accuracy: 0.6480
# Epoch 30/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.1449 - accuracy: 0.6510
# Epoch 31/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.1376 - accuracy: 0.6531
# Epoch 32/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.1313 - accuracy: 0.6539
# Epoch 33/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.1251 - accuracy: 0.6553
# Epoch 34/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.1187 - accuracy: 0.6569
# Epoch 35/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.1128 - accuracy: 0.6578
# Epoch 36/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.1080 - accuracy: 0.6591
# Epoch 37/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.1032 - accuracy: 0.6604
# Epoch 38/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.0967 - accuracy: 0.6641
# Epoch 39/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.0922 - accuracy: 0.6650
# Epoch 40/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.0875 - accuracy: 0.6647
# Epoch 41/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.0825 - accuracy: 0.6663
# Epoch 42/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.0785 - accuracy: 0.6684
# Epoch 43/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.0735 - accuracy: 0.6702
# Epoch 44/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.0700 - accuracy: 0.6694
# Epoch 45/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.0660 - accuracy: 0.6713
# Epoch 46/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.0619 - accuracy: 0.6730
# Epoch 47/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.0573 - accuracy: 0.6734
# Epoch 48/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.0538 - accuracy: 0.6744
# Epoch 49/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.0509 - accuracy: 0.6762
# Epoch 50/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.0471 - accuracy: 0.6754

# %%
# CNN for bottom right quadrant

# Define the input shape for each quadrant
input_shape = (14, 14, 1)

# Create a sequential model for the top left quadrant
model_br = Sequential()

# Add a convolutional layer with 16 filters, 3x3 kernel size, and sigmoid activation
model_br.add(Conv2D(16, kernel_size=(3, 3), activation='sigmoid', input_shape=input_shape))

# Add a max pooling layer with 2x2 pool size
model_br.add(MaxPooling2D(pool_size=(2, 2)))

# Add a convolutional layer with 32 filters, 3x3 kernel size, and sigmoid activation
model_br.add(Conv2D(32, kernel_size=(3, 3), activation='sigmoid'))

# Add a max pooling layer with 2x2 pool size
model_br.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output of the previous layer
model_br.add(Flatten())

# Add the output layer with 46 units and softmax activation
model_br.add(Dense(46, activation='softmax'))

# Compile the model with categorical crossentropy loss and Adam optimizer
model_br.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model_br.summary()

# Train the model on the top left quadrant dataset
model_br.fit(x_train_br, train_labels_onehot, batch_size=32, epochs=50)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 12, 12, 16)        160
#
#  max_pooling2d_6 (MaxPooling  (None, 6, 6, 16)         0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 4, 4, 32)          4640
#
#  max_pooling2d_7 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  flatten_3 (Flatten)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 46)                5934
#
# =================================================================
# Total params: 10,734
# Trainable params: 10,734
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 3.2886 - accuracy: 0.1448
# Epoch 2/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 2.5137 - accuracy: 0.2973
# Epoch 3/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 2.2692 - accuracy: 0.3495
# Epoch 4/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 2.1374 - accuracy: 0.3801
# Epoch 5/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 2.0481 - accuracy: 0.4004
# Epoch 6/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.9807 - accuracy: 0.4158
# Epoch 7/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.9256 - accuracy: 0.4296
# Epoch 8/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.8795 - accuracy: 0.4391
# Epoch 9/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.8408 - accuracy: 0.4496
# Epoch 10/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.8073 - accuracy: 0.4575
# Epoch 11/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.7771 - accuracy: 0.4652
# Epoch 12/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.7511 - accuracy: 0.4719
# Epoch 13/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.7271 - accuracy: 0.4780
# Epoch 14/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.7053 - accuracy: 0.4847
# Epoch 15/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.6867 - accuracy: 0.4885
# Epoch 16/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.6695 - accuracy: 0.4911
# Epoch 17/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.6529 - accuracy: 0.4971
# Epoch 18/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.6386 - accuracy: 0.5002
# Epoch 19/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.6253 - accuracy: 0.5036
# Epoch 20/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.6132 - accuracy: 0.5061
# Epoch 21/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.6019 - accuracy: 0.5088
# Epoch 22/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.5909 - accuracy: 0.5119
# Epoch 23/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.5803 - accuracy: 0.5151
# Epoch 24/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.5699 - accuracy: 0.5173
# Epoch 25/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.5621 - accuracy: 0.5188
# Epoch 26/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.5526 - accuracy: 0.5214
# Epoch 27/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.5445 - accuracy: 0.5232
# Epoch 28/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.5371 - accuracy: 0.5267
# Epoch 29/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.5289 - accuracy: 0.5283
# Epoch 30/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.5225 - accuracy: 0.5289
# Epoch 31/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.5141 - accuracy: 0.5318
# Epoch 32/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.5076 - accuracy: 0.5323
# Epoch 33/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.5004 - accuracy: 0.5358
# Epoch 34/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.4952 - accuracy: 0.5369
# Epoch 35/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4898 - accuracy: 0.5385
# Epoch 36/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.4837 - accuracy: 0.5396
# Epoch 37/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.4771 - accuracy: 0.5408
# Epoch 38/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.4719 - accuracy: 0.5435
# Epoch 39/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.4667 - accuracy: 0.5439
# Epoch 40/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.4614 - accuracy: 0.5463
# Epoch 41/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.4561 - accuracy: 0.5473
# Epoch 42/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.4522 - accuracy: 0.5474
# Epoch 43/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4472 - accuracy: 0.5483
# Epoch 44/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4429 - accuracy: 0.5491
# Epoch 45/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.4380 - accuracy: 0.5517
# Epoch 46/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4324 - accuracy: 0.5538
# Epoch 47/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4297 - accuracy: 0.5545
# Epoch 48/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4258 - accuracy: 0.5554
# Epoch 49/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4212 - accuracy: 0.5576
# Epoch 50/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4176 - accuracy: 0.5569

# %%
# CNN for center quadrant

# Define the input shape for each quadrant
input_shape = (14, 14, 1)

# Create a sequential model for the top left quadrant
model_c = Sequential()

# Add a convolutional layer with 16 filters, 3x3 kernel size, and sigmoid activation
model_c.add(Conv2D(16, kernel_size=(3, 3), activation='sigmoid', input_shape=input_shape))

# Add a max pooling layer with 2x2 pool size
model_c.add(MaxPooling2D(pool_size=(2, 2)))

# Add a convolutional layer with 32 filters, 3x3 kernel size, and sigmoid activation
model_c.add(Conv2D(32, kernel_size=(3, 3), activation='sigmoid'))

# Add a max pooling layer with 2x2 pool size
model_c.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output of the previous layer
model_c.add(Flatten())

# Add the output layer with 46 units and softmax activation
model_c.add(Dense(46, activation='softmax'))

# Compile the model with categorical crossentropy loss and Adam optimizer
model_c.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model_c.summary()

# Train the model on the top left quadrant dataset
model_c.fit(x_train_c, train_labels_onehot, batch_size=32, epochs=50)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 12, 12, 16)        160
#
#  max_pooling2d_8 (MaxPooling  (None, 6, 6, 16)         0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 4, 4, 32)          4640
#
#  max_pooling2d_9 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  flatten_4 (Flatten)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 46)                5934
#
# =================================================================
# Total params: 10,734
# Trainable params: 10,734
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 3.2618 - accuracy: 0.1609
# Epoch 2/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 2.3456 - accuracy: 0.3723
# Epoch 3/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 2.0191 - accuracy: 0.4481
# Epoch 4/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.8384 - accuracy: 0.4933
# Epoch 5/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.7185 - accuracy: 0.5227
# Epoch 6/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.6297 - accuracy: 0.5446
# Epoch 7/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.5580 - accuracy: 0.5625
# Epoch 8/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.4981 - accuracy: 0.5759
# Epoch 9/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4463 - accuracy: 0.5887
# Epoch 10/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.4026 - accuracy: 0.5987
# Epoch 11/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.3629 - accuracy: 0.6076
# Epoch 12/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.3261 - accuracy: 0.6186
# Epoch 13/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.2942 - accuracy: 0.6255
# Epoch 14/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.2646 - accuracy: 0.6337
# Epoch 15/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.2380 - accuracy: 0.6400
# Epoch 16/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.2116 - accuracy: 0.6482
# Epoch 17/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.1890 - accuracy: 0.6542
# Epoch 18/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.1679 - accuracy: 0.6592
# Epoch 19/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.1486 - accuracy: 0.6625
# Epoch 20/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.1298 - accuracy: 0.6683
# Epoch 21/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.1124 - accuracy: 0.6716
# Epoch 22/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 1.0972 - accuracy: 0.6764
# Epoch 23/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.0812 - accuracy: 0.6805
# Epoch 24/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.0671 - accuracy: 0.6843
# Epoch 25/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 1.0539 - accuracy: 0.6869
# Epoch 26/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.0414 - accuracy: 0.6910
# Epoch 27/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.0299 - accuracy: 0.6939
# Epoch 28/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.0183 - accuracy: 0.6965
# Epoch 29/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.0075 - accuracy: 0.6998
# Epoch 30/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9985 - accuracy: 0.7013
# Epoch 31/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9892 - accuracy: 0.7049
# Epoch 32/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9790 - accuracy: 0.7070
# Epoch 33/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 0.9704 - accuracy: 0.7103
# Epoch 34/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9628 - accuracy: 0.7114
# Epoch 35/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9550 - accuracy: 0.7125
# Epoch 36/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9481 - accuracy: 0.7161
# Epoch 37/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.9402 - accuracy: 0.7187
# Epoch 38/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.9331 - accuracy: 0.7203
# Epoch 39/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.9271 - accuracy: 0.7218
# Epoch 40/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 0.9199 - accuracy: 0.7229
# Epoch 41/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9143 - accuracy: 0.7255
# Epoch 42/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.9094 - accuracy: 0.7263
# Epoch 43/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.9038 - accuracy: 0.7275
# Epoch 44/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.8983 - accuracy: 0.7291
# Epoch 45/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.8931 - accuracy: 0.7293
# Epoch 46/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.8885 - accuracy: 0.7328
# Epoch 47/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.8835 - accuracy: 0.7337
# Epoch 48/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.8793 - accuracy: 0.7343
# Epoch 49/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.8752 - accuracy: 0.7343
# Epoch 50/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.8717 - accuracy: 0.7358

# %%
# CNN for top-middle quadrant

# Define the input shape for each quadrant
input_shape = (14, 14, 1)

# Create a sequential model for the top left quadrant
model_tm = Sequential()

# Add a convolutional layer with 16 filters, 3x3 kernel size, and sigmoid activation
model_tm.add(Conv2D(16, kernel_size=(3, 3), activation='sigmoid', input_shape=input_shape))

# Add a max pooling layer with 2x2 pool size
model_tm.add(MaxPooling2D(pool_size=(2, 2)))

# Add a convolutional layer with 32 filters, 3x3 kernel size, and sigmoid activation
model_tm.add(Conv2D(32, kernel_size=(3, 3), activation='sigmoid'))

# Add a max pooling layer with 2x2 pool size
model_tm.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output of the previous layer
model_tm.add(Flatten())

# Add the output layer with 46 units and softmax activation
model_tm.add(Dense(46, activation='softmax'))

# Compile the model with categorical crossentropy loss and Adam optimizer
model_tm.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model_tm.summary()

# Train the model on the top left quadrant dataset
model_tm.fit(x_train_tm, train_labels_onehot, batch_size=32, epochs=50)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 12, 12, 16)        160
#
#  max_pooling2d_10 (MaxPoolin  (None, 6, 6, 16)         0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 4, 4, 32)          4640
#
#  max_pooling2d_11 (MaxPoolin  (None, 2, 2, 32)         0
#  g2D)
#
#  flatten_5 (Flatten)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 46)                5934
#
# =================================================================
# Total params: 10,734
# Trainable params: 10,734
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 3.3677 - accuracy: 0.1295
# Epoch 2/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 2.6158 - accuracy: 0.2930
# Epoch 3/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 2.3152 - accuracy: 0.3655
# Epoch 4/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 2.1328 - accuracy: 0.4099
# Epoch 5/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 2.0063 - accuracy: 0.4412
# Epoch 6/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.9121 - accuracy: 0.4633
# Epoch 7/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.8367 - accuracy: 0.4811
# Epoch 8/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.7729 - accuracy: 0.4965
# Epoch 9/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.7202 - accuracy: 0.5115
# Epoch 10/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 1.6733 - accuracy: 0.5222
# Epoch 11/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 1.6354 - accuracy: 0.5312
# Epoch 12/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.6006 - accuracy: 0.5401
# Epoch 13/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.5700 - accuracy: 0.5482
# Epoch 14/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.5429 - accuracy: 0.5539
# Epoch 15/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.5187 - accuracy: 0.5605
# Epoch 16/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.4963 - accuracy: 0.5668
# Epoch 17/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.4765 - accuracy: 0.5710
# Epoch 18/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.4583 - accuracy: 0.5761
# Epoch 19/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 1.4424 - accuracy: 0.5802
# Epoch 20/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 1.4276 - accuracy: 0.5837
# Epoch 21/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.4132 - accuracy: 0.5863
# Epoch 22/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.4010 - accuracy: 0.5907
# Epoch 23/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.3874 - accuracy: 0.5932
# Epoch 24/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.3779 - accuracy: 0.5971
# Epoch 25/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.3660 - accuracy: 0.5996
# Epoch 26/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.3575 - accuracy: 0.6013
# Epoch 27/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.3478 - accuracy: 0.6031
# Epoch 28/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.3395 - accuracy: 0.6065
# Epoch 29/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.3306 - accuracy: 0.6087
# Epoch 30/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.3224 - accuracy: 0.6102
# Epoch 31/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.3160 - accuracy: 0.6120
# Epoch 32/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 1.3084 - accuracy: 0.6152
# Epoch 33/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 1.3031 - accuracy: 0.6165
# Epoch 34/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.2960 - accuracy: 0.6176
# Epoch 35/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.2897 - accuracy: 0.6203
# Epoch 36/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.2842 - accuracy: 0.6218
# Epoch 37/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.2778 - accuracy: 0.6228
# Epoch 38/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.2741 - accuracy: 0.6242
# Epoch 39/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.2684 - accuracy: 0.6261
# Epoch 40/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.2633 - accuracy: 0.6267
# Epoch 41/50
# 2444/2444 [==============================] - 16s 7ms/step - loss: 1.2584 - accuracy: 0.6285
# Epoch 42/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.2542 - accuracy: 0.6300
# Epoch 43/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.2491 - accuracy: 0.6310
# Epoch 44/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 1.2456 - accuracy: 0.6317
# Epoch 45/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.2412 - accuracy: 0.6335
# Epoch 46/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.2376 - accuracy: 0.6349
# Epoch 47/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.2334 - accuracy: 0.6358
# Epoch 48/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.2298 - accuracy: 0.6364
# Epoch 49/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.2260 - accuracy: 0.6368
# Epoch 50/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.2233 - accuracy: 0.6385

# %%
# CNN for bottom-middle quadrant

# Define the input shape for each quadrant
input_shape = (14, 14, 1)

# Create a sequential model for the top left quadrant
model_bm = Sequential()

# Add a convolutional layer with 16 filters, 3x3 kernel size, and sigmoid activation
model_bm.add(Conv2D(16, kernel_size=(3, 3), activation='sigmoid', input_shape=input_shape))

# Add a max pooling layer with 2x2 pool size
model_bm.add(MaxPooling2D(pool_size=(2, 2)))

# Add a convolutional layer with 32 filters, 3x3 kernel size, and sigmoid activation
model_bm.add(Conv2D(32, kernel_size=(3, 3), activation='sigmoid'))

# Add a max pooling layer with 2x2 pool size
model_bm.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output of the previous layer
model_bm.add(Flatten())

# Add the output layer with 46 units and softmax activation
model_bm.add(Dense(46, activation='softmax'))

# Compile the model with categorical crossentropy loss and Adam optimizer
model_bm.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model_bm.summary()

# Train the model on the top left quadrant dataset
model_bm.fit(x_train_bm, train_labels_onehot, batch_size=32, epochs=50)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 12, 12, 16)        160
#
#  max_pooling2d_12 (MaxPoolin  (None, 6, 6, 16)         0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 4, 4, 32)          4640
#
#  max_pooling2d_13 (MaxPoolin  (None, 2, 2, 32)         0
#  g2D)
#
#  flatten_6 (Flatten)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 46)                5934
#
# =================================================================
# Total params: 10,734
# Trainable params: 10,734
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 3.2348 - accuracy: 0.1573
# Epoch 2/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 2.2887 - accuracy: 0.3680
# Epoch 3/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.9804 - accuracy: 0.4386
# Epoch 4/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.8199 - accuracy: 0.4778
# Epoch 5/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.7102 - accuracy: 0.5071
# Epoch 6/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 1.6248 - accuracy: 0.5288
# Epoch 7/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.5550 - accuracy: 0.5480
# Epoch 8/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.4984 - accuracy: 0.5620
# Epoch 9/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.4525 - accuracy: 0.5728
# Epoch 10/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.4123 - accuracy: 0.5842
# Epoch 11/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.3779 - accuracy: 0.5919
# Epoch 12/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.3480 - accuracy: 0.5992
# Epoch 13/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.3206 - accuracy: 0.6084
# Epoch 14/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.2978 - accuracy: 0.6128
# Epoch 15/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.2771 - accuracy: 0.6193
# Epoch 16/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.2575 - accuracy: 0.6237
# Epoch 17/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 1.2381 - accuracy: 0.6283
# Epoch 18/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.2220 - accuracy: 0.6336
# Epoch 19/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.2060 - accuracy: 0.6365
# Epoch 20/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 1.1913 - accuracy: 0.6409
# Epoch 21/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.1777 - accuracy: 0.6453
# Epoch 22/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.1658 - accuracy: 0.6483
# Epoch 23/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.1535 - accuracy: 0.6511
# Epoch 24/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 1.1412 - accuracy: 0.6543
# Epoch 25/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.1308 - accuracy: 0.6578
# Epoch 26/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 1.1214 - accuracy: 0.6601
# Epoch 27/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.1102 - accuracy: 0.6622
# Epoch 28/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.1023 - accuracy: 0.6633
# Epoch 29/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.0926 - accuracy: 0.6683
# Epoch 30/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.0850 - accuracy: 0.6692
# Epoch 31/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.0774 - accuracy: 0.6717
# Epoch 32/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.0694 - accuracy: 0.6723
# Epoch 33/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.0625 - accuracy: 0.6755
# Epoch 34/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 1.0550 - accuracy: 0.6768
# Epoch 35/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 1.0494 - accuracy: 0.6790
# Epoch 36/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.0433 - accuracy: 0.6799
# Epoch 37/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.0377 - accuracy: 0.6813
# Epoch 38/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.0307 - accuracy: 0.6835
# Epoch 39/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.0256 - accuracy: 0.6851
# Epoch 40/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.0208 - accuracy: 0.6869
# Epoch 41/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.0153 - accuracy: 0.6887
# Epoch 42/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.0098 - accuracy: 0.6901
# Epoch 43/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.0054 - accuracy: 0.6891
# Epoch 44/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.0006 - accuracy: 0.6917
# Epoch 45/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9968 - accuracy: 0.6921
# Epoch 46/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9924 - accuracy: 0.6933
# Epoch 47/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9889 - accuracy: 0.6949
# Epoch 48/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9852 - accuracy: 0.6957
# Epoch 49/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9818 - accuracy: 0.6969
# Epoch 50/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9774 - accuracy: 0.6987

# %%
# CNN for left-middle quadrant

# Define the input shape for each quadrant
input_shape = (14, 14, 1)

# Create a sequential model for the top left quadrant
model_lm = Sequential()

# Add a convolutional layer with 16 filters, 3x3 kernel size, and sigmoid activation
model_lm.add(Conv2D(16, kernel_size=(3, 3), activation='sigmoid', input_shape=input_shape))

# Add a max pooling layer with 2x2 pool size
model_lm.add(MaxPooling2D(pool_size=(2, 2)))

# Add a convolutional layer with 32 filters, 3x3 kernel size, and sigmoid activation
model_lm.add(Conv2D(32, kernel_size=(3, 3), activation='sigmoid'))

# Add a max pooling layer with 2x2 pool size
model_lm.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output of the previous layer
model_lm.add(Flatten())

# Add the output layer with 46 units and softmax activation
model_lm.add(Dense(46, activation='softmax'))

# Compile the model with categorical crossentropy loss and Adam optimizer
model_lm.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model_lm.summary()

# Train the model on the top left quadrant dataset
model_lm.fit(x_train_lm, train_labels_onehot, batch_size=32, epochs=50)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_14 (Conv2D)          (None, 12, 12, 16)        160
#
#  max_pooling2d_14 (MaxPoolin  (None, 6, 6, 16)         0
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 4, 4, 32)          4640
#
#  max_pooling2d_15 (MaxPoolin  (None, 2, 2, 32)         0
#  g2D)
#
#  flatten_7 (Flatten)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 46)                5934
#
# =================================================================
# Total params: 10,734
# Trainable params: 10,734
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 3.0632 - accuracy: 0.2075
# Epoch 2/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 2.1487 - accuracy: 0.4141
# Epoch 3/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.8719 - accuracy: 0.4769
# Epoch 4/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.7073 - accuracy: 0.5181
# Epoch 5/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.5894 - accuracy: 0.5483
# Epoch 6/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 1.5009 - accuracy: 0.5706
# Epoch 7/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.4316 - accuracy: 0.5870
# Epoch 8/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.3755 - accuracy: 0.6025
# Epoch 9/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.3287 - accuracy: 0.6139
# Epoch 10/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.2900 - accuracy: 0.6242
# Epoch 11/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.2566 - accuracy: 0.6324
# Epoch 12/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 1.2278 - accuracy: 0.6393
# Epoch 13/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.2028 - accuracy: 0.6466
# Epoch 14/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.1801 - accuracy: 0.6515
# Epoch 15/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 1.1600 - accuracy: 0.6573
# Epoch 16/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.1419 - accuracy: 0.6613
# Epoch 17/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.1247 - accuracy: 0.6671
# Epoch 18/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.1098 - accuracy: 0.6703
# Epoch 19/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.0948 - accuracy: 0.6744
# Epoch 20/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.0813 - accuracy: 0.6773
# Epoch 21/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.0688 - accuracy: 0.6794
# Epoch 22/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.0570 - accuracy: 0.6842
# Epoch 23/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.0454 - accuracy: 0.6865
# Epoch 24/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.0345 - accuracy: 0.6899
# Epoch 25/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.0247 - accuracy: 0.6916
# Epoch 26/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.0153 - accuracy: 0.6938
# Epoch 27/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.0058 - accuracy: 0.6969
# Epoch 28/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9961 - accuracy: 0.7003
# Epoch 29/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9889 - accuracy: 0.7013
# Epoch 30/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9806 - accuracy: 0.7035
# Epoch 31/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9738 - accuracy: 0.7044
# Epoch 32/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9667 - accuracy: 0.7069
# Epoch 33/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9598 - accuracy: 0.7077
# Epoch 34/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9535 - accuracy: 0.7108
# Epoch 35/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9467 - accuracy: 0.7114
# Epoch 36/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9411 - accuracy: 0.7123
# Epoch 37/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9350 - accuracy: 0.7142
# Epoch 38/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9296 - accuracy: 0.7157
# Epoch 39/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9244 - accuracy: 0.7178
# Epoch 40/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9191 - accuracy: 0.7195
# Epoch 41/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9142 - accuracy: 0.7204
# Epoch 42/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9097 - accuracy: 0.7217
# Epoch 43/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9044 - accuracy: 0.7221
# Epoch 44/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.9013 - accuracy: 0.7238
# Epoch 45/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.8969 - accuracy: 0.7243
# Epoch 46/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.8928 - accuracy: 0.7251
# Epoch 47/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.8884 - accuracy: 0.7255
# Epoch 48/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.8843 - accuracy: 0.7276
# Epoch 49/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.8818 - accuracy: 0.7273
# Epoch 50/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.8775 - accuracy: 0.7285

# %%
# CNN for right-middle quadrant

# Define the input shape for each quadrant
input_shape = (14, 14, 1)

# Create a sequential model for the top left quadrant
model_rm = Sequential()

# Add a convolutional layer with 16 filters, 3x3 kernel size, and sigmoid activation
model_rm.add(Conv2D(16, kernel_size=(3, 3), activation='sigmoid', input_shape=input_shape))

# Add a max pooling layer with 2x2 pool size
model_rm.add(MaxPooling2D(pool_size=(2, 2)))

# Add a convolutional layer with 32 filters, 3x3 kernel size, and sigmoid activation
model_rm.add(Conv2D(32, kernel_size=(3, 3), activation='sigmoid'))

# Add a max pooling layer with 2x2 pool size
model_rm.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output of the previous layer
model_rm.add(Flatten())

# Add the output layer with 46 units and softmax activation
model_rm.add(Dense(46, activation='softmax'))

# Compile the model with categorical crossentropy loss and Adam optimizer
model_rm.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model_rm.summary()

# Train the model on the top left quadrant dataset
model_rm.fit(x_train_rm, train_labels_onehot, batch_size=32, epochs=50)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_16 (Conv2D)          (None, 12, 12, 16)        160
#
#  max_pooling2d_16 (MaxPoolin  (None, 6, 6, 16)         0
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, 4, 4, 32)          4640
#
#  max_pooling2d_17 (MaxPoolin  (None, 2, 2, 32)         0
#  g2D)
#
#  flatten_8 (Flatten)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 46)                5934
#
# =================================================================
# Total params: 10,734
# Trainable params: 10,734
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2444/2444 [==============================] - 14s 5ms/step - loss: 3.3425 - accuracy: 0.1375
# Epoch 2/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 2.6369 - accuracy: 0.2705
# Epoch 3/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 2.3856 - accuracy: 0.3255
# Epoch 4/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 2.2386 - accuracy: 0.3607
# Epoch 5/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 2.1367 - accuracy: 0.3836
# Epoch 6/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 2.0598 - accuracy: 0.4022
# Epoch 7/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.9961 - accuracy: 0.4175
# Epoch 8/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.9427 - accuracy: 0.4302
# Epoch 9/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.8957 - accuracy: 0.4420
# Epoch 10/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 1.8558 - accuracy: 0.4530
# Epoch 11/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.8203 - accuracy: 0.4604
# Epoch 12/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.7891 - accuracy: 0.4700
# Epoch 13/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.7615 - accuracy: 0.4757
# Epoch 14/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.7376 - accuracy: 0.4832
# Epoch 15/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.7148 - accuracy: 0.4881
# Epoch 16/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.6960 - accuracy: 0.4927
# Epoch 17/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.6786 - accuracy: 0.4971
# Epoch 18/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 1.6615 - accuracy: 0.5028
# Epoch 19/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.6452 - accuracy: 0.5048
# Epoch 20/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.6325 - accuracy: 0.5095
# Epoch 21/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.6186 - accuracy: 0.5129
# Epoch 22/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.6068 - accuracy: 0.5160
# Epoch 23/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.5957 - accuracy: 0.5177
# Epoch 24/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.5852 - accuracy: 0.5219
# Epoch 25/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.5748 - accuracy: 0.5241
# Epoch 26/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.5664 - accuracy: 0.5273
# Epoch 27/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.5578 - accuracy: 0.5285
# Epoch 28/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.5491 - accuracy: 0.5300
# Epoch 29/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.5417 - accuracy: 0.5333
# Epoch 30/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.5340 - accuracy: 0.5344
# Epoch 31/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.5262 - accuracy: 0.5373
# Epoch 32/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.5201 - accuracy: 0.5395
# Epoch 33/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.5134 - accuracy: 0.5400
# Epoch 34/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.5079 - accuracy: 0.5420
# Epoch 35/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.5016 - accuracy: 0.5433
# Epoch 36/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.4970 - accuracy: 0.5452
# Epoch 37/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 1.4914 - accuracy: 0.5459
# Epoch 38/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.4866 - accuracy: 0.5479
# Epoch 39/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.4808 - accuracy: 0.5489
# Epoch 40/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.4763 - accuracy: 0.5490
# Epoch 41/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.4717 - accuracy: 0.5525
# Epoch 42/50
# 2444/2444 [==============================] - 13s 6ms/step - loss: 1.4674 - accuracy: 0.5530
# Epoch 43/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.4642 - accuracy: 0.5532
# Epoch 44/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.4595 - accuracy: 0.5550
# Epoch 45/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.4550 - accuracy: 0.5559
# Epoch 46/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.4525 - accuracy: 0.5569
# Epoch 47/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.4483 - accuracy: 0.5579
# Epoch 48/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.4450 - accuracy: 0.5592
# Epoch 49/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.4409 - accuracy: 0.5595
# Epoch 50/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.4390 - accuracy: 0.5608

# %%
from tensorflow.keras.models import Model

# create new models to extract features from the last dense layer
model_tl_features = Model(inputs=model_tl.input, outputs=model_tl.get_layer('flatten').output)
model_tr_features = Model(inputs=model_tr.input, outputs=model_tr.get_layer('flatten_1').output)
model_bl_features = Model(inputs=model_bl.input, outputs=model_bl.get_layer('flatten_2').output)
model_br_features = Model(inputs=model_br.input, outputs=model_br.get_layer('flatten_3').output)
model_c_features = Model(inputs=model_c.input, outputs=model_c.get_layer('flatten_4').output)
model_tm_features = Model(inputs=model_tm.input, outputs=model_tm.get_layer('flatten_5').output)
model_bm_features = Model(inputs=model_bm.input, outputs=model_bm.get_layer('flatten_6').output)
model_lm_features = Model(inputs=model_lm.input, outputs=model_lm.get_layer('flatten_7').output)
model_rm_features = Model(inputs=model_rm.input, outputs=model_rm.get_layer('flatten_8').output)

# extract features from the last dense layer for each quadrant
tl_features = model_tl_features.predict(x_train_tl)
tr_features = model_tr_features.predict(x_train_tr)
bl_features = model_bl_features.predict(x_train_bl)
br_features = model_br_features.predict(x_train_br)
center_features = model_c_features.predict(x_train_c)
tm_features = model_tm_features.predict(x_train_tm)
bm_features = model_bm_features.predict(x_train_bm)
lm_features = model_lm_features.predict(x_train_lm)
rm_features = model_rm_features.predict(x_train_rm)

# concatenate the features from all 9 quadrants into a single input
features = np.concatenate((tl_features, tr_features, bl_features, br_features, center_features, tm_features, bm_features, lm_features, rm_features), axis=1)
# Out:
# 2444/2444 [==============================] - 7s 3ms/step
# 2444/2444 [==============================] - 7s 3ms/step
# 2444/2444 [==============================] - 7s 3ms/step
# 2444/2444 [==============================] - 7s 3ms/step
# 2444/2444 [==============================] - 7s 3ms/step
# 2444/2444 [==============================] - 7s 3ms/step
# 2444/2444 [==============================] - 7s 3ms/step
# 2444/2444 [==============================] - 6s 3ms/step
# 2444/2444 [==============================] - 6s 3ms/step

# %%
print(features.shape)
# Out:
# (78200, 1152)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# define the DNN classifier model
classifier = Sequential()
classifier.add(Dense(1152, activation='relu', input_shape=(features.shape[1],)))
classifier.add(Dense(512, activation='relu'))
classifier.add(Dense(256, activation='relu'))
classifier.add(Dense(128, activation='relu'))
classifier.add(Dense(46, activation='softmax'))

# compile the model
classifier.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# print model summary
classifier.summary()

history = classifier.fit(features, train_labels_onehot, batch_size=32, epochs=10)
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 1152)              1328256
#
#  dense_10 (Dense)            (None, 512)               590336
#
#  dense_11 (Dense)            (None, 256)               131328
#
#  dense_12 (Dense)            (None, 128)               32896
#
#  dense_13 (Dense)            (None, 46)                5934
#
# =================================================================
# Total params: 2,088,750
# Trainable params: 2,088,750
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2444/2444 [==============================] - 78s 31ms/step - loss: 0.4778 - accuracy: 0.8554
# Epoch 2/10
# 2444/2444 [==============================] - 78s 32ms/step - loss: 0.1862 - accuracy: 0.9427
# Epoch 3/10
# 2444/2444 [==============================] - 79s 32ms/step - loss: 0.1439 - accuracy: 0.9553
# Epoch 4/10
# 2444/2444 [==============================] - 77s 31ms/step - loss: 0.1168 - accuracy: 0.9648
# Epoch 5/10
# 2444/2444 [==============================] - 78s 32ms/step - loss: 0.1018 - accuracy: 0.9696
# Epoch 6/10
# 2444/2444 [==============================] - 77s 31ms/step - loss: 0.0877 - accuracy: 0.9743
# Epoch 7/10
# 2444/2444 [==============================] - 79s 32ms/step - loss: 0.0814 - accuracy: 0.9763
# Epoch 8/10
# 2444/2444 [==============================] - 79s 32ms/step - loss: 0.0784 - accuracy: 0.9780
# Epoch 9/10
# 2444/2444 [==============================] - 74s 30ms/step - loss: 0.0697 - accuracy: 0.9802
# Epoch 10/10
# 2444/2444 [==============================] - 76s 31ms/step - loss: 0.0666 - accuracy: 0.9819

# %% [markdown]
# # Preprocessing the test data for prediction and testing

# %%
test_labels_int = label_encoder.fit_transform(test_labels)

# %%
# Convert the integer labels to one-hot encoding
test_labels_onehot = to_categorical(test_labels_int, num_classes=46)

# Split the data into the five quadrants
x_test_tl = test_images[:,:14,:14].reshape(-1, 14, 14, 1)
x_test_tr = test_images[:,:14,14:].reshape(-1, 14, 14, 1)
x_test_bl = test_images[:,14:,:14].reshape(-1, 14, 14, 1)
x_test_br = test_images[:,14:,14:].reshape(-1, 14, 14, 1)
x_test_c = test_images[:,7:21,7:21].reshape(-1, 14, 14, 1)
x_test_tm = test_images[:,:14,7:21].reshape(-1, 14, 14, 1)
x_test_bm = test_images[:,14:,7:21].reshape(-1, 14, 14, 1)
x_test_lm = test_images[:,7:21,:14].reshape(-1, 14, 14, 1)
x_test_rm = test_images[:,7:21,14:].reshape(-1, 14, 14, 1)

# %%
# extract features from the last dense layer for each quadrant
tl_features_test = model_tl_features.predict(x_test_tl)
tr_features_test = model_tr_features.predict(x_test_tr)
bl_features_test = model_bl_features.predict(x_test_bl)
br_features_test = model_br_features.predict(x_test_br)
center_features_test = model_c_features.predict(x_test_c)
tm_features_test = model_tm_features.predict(x_test_tm)
bm_features_test = model_bm_features.predict(x_test_bm)
lm_features_test = model_lm_features.predict(x_test_lm)
rm_features_test = model_rm_features.predict(x_test_rm)

# concatenate the features from all 9 quadrants into a single input
features_test = np.concatenate((tl_features_test, tr_features_test, bl_features_test, br_features_test, center_features_test, tm_features_test, bm_features_test, lm_features_test, rm_features_test), axis=1)
# Out:
# 432/432 [==============================] - 1s 3ms/step
# 432/432 [==============================] - 1s 3ms/step
# 432/432 [==============================] - 1s 3ms/step
# 432/432 [==============================] - 1s 3ms/step
# 432/432 [==============================] - 1s 3ms/step
# 432/432 [==============================] - 1s 3ms/step
# 432/432 [==============================] - 1s 3ms/step
# 432/432 [==============================] - 1s 3ms/step
# 432/432 [==============================] - 1s 3ms/step

# %%
# Save the model to disk
classifier.save("model_f128x9_b32e50_b32e10.h5")

# %%
print(features_test.shape)
# Out:
# (13800, 1152)

# %%
test_predictions = classifier.predict(features_test)
# Out:
# 432/432 [==============================] - 3s 6ms/step

# %%
# Evaluate the model
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
accuracy = accuracy_score(test_labels_int, test_predictions.argmax(axis=1))
precision = precision_score(test_labels_int, test_predictions.argmax(axis=1), average='weighted')
recall = recall_score(test_labels_int, test_predictions.argmax(axis=1), average='weighted')
f1 = f1_score(test_labels_int, test_predictions.argmax(axis=1), average='weighted')

# %%
print('Accuracy:', accuracy)
print('Precision:', precision)
print('Recall:', recall)
print('F1 Score:', f1)
# Out:
# Accuracy: 0.9698550724637681
# Precision: 0.9707546923543702
# Recall: 0.9698550724637681
# F1 Score: 0.9698169489886536
