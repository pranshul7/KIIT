# %%
import os
import numpy as np
import cv2
from PIL import Image
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# %%
# Define the path to the train and test folders
train_path = 'C:/A/code/VSC/python/test/cropped_DevanagariHandwrittenCharacterDataset/Train/'
test_path = 'C:/A/code/VSC/python/test/cropped_DevanagariHandwrittenCharacterDataset/Test/'

# Define a function to load and preprocess the images
def load_images(path):
    # Create empty lists to store the images and labels
    images = []
    labels = []

    # Loop through each folder (which represents a class) in the path
    for folder in os.listdir(path):
        # Get the path to the folder
        folder_path = os.path.join(path, folder)
        # Loop through each image in the folder
        for file in os.listdir(folder_path):
            # Get the path to the image file
            img_path = os.path.join(folder_path, file)
            # Load the image using OpenCV
            img = cv2.imread(img_path)
            # Convert the image to grayscale
            img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            # Normalize the pixel values of the images
            img = img.astype('float32') / 255.0
            # Append the image to the images list
            images.append(img)
            # Append the label to the labels list
            labels.append(folder)

    # Convert the images and labels lists to NumPy arrays
    images = np.array(images)
    labels = np.array(labels)
    
    # Return the images and labels arrays
    return images, labels

# Load the train images and labels
train_images, train_labels = load_images(train_path)

# Load the test images and labels
test_images, test_labels = load_images(test_path)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.utils import to_categorical

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

# Convert the string labels to integer labels
label_encoder = LabelEncoder()
train_labels_int = label_encoder.fit_transform(train_labels)

# %%
# Convert the integer labels to one-hot encoding
train_labels_onehot = to_categorical(train_labels_int, num_classes=46)

# Split the data into the five quadrants
x_train_tl = train_images[:,:14,:14].reshape(-1, 14, 14, 1)
x_train_tr = train_images[:,:14,14:].reshape(-1, 14, 14, 1)
x_train_bl = train_images[:,14:,:14].reshape(-1, 14, 14, 1)
x_train_br = train_images[:,14:,14:].reshape(-1, 14, 14, 1)
x_train_c = train_images[:,7:21,7:21].reshape(-1, 14, 14, 1)

# %%
# CNN for top left quadrant

# Define the input shape for each quadrant
input_shape = (14, 14, 1)

# Create a sequential model for the top left quadrant
model_tl = Sequential()

# Add a convolutional layer with 16 filters, 3x3 kernel size, and sigmoid activation
model_tl.add(Conv2D(16, kernel_size=(3, 3), activation='sigmoid', input_shape=input_shape))

# Add a max pooling layer with 2x2 pool size
model_tl.add(MaxPooling2D(pool_size=(2, 2)))

# Add a convolutional layer with 32 filters, 3x3 kernel size, and sigmoid activation
model_tl.add(Conv2D(32, kernel_size=(3, 3), activation='sigmoid'))

# Add a max pooling layer with 2x2 pool size
model_tl.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output of the previous layer
model_tl.add(Flatten())

# Add the output layer with 46 units and softmax activation
model_tl.add(Dense(46, activation='softmax'))

# Compile the model with categorical crossentropy loss and Adam optimizer
model_tl.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model_tl.summary()

# Train the model on the top left quadrant dataset
model_tl.fit(x_train_tl, train_labels_onehot, batch_size=32, epochs=50)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 12, 12, 16)        160
#
#  max_pooling2d (MaxPooling2D  (None, 6, 6, 16)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 4, 4, 32)          4640
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 46)                5934
#
# =================================================================
# Total params: 10,734
# Trainable params: 10,734
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 3.2953 - accuracy: 0.1390
# Epoch 2/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 2.5076 - accuracy: 0.3060
# Epoch 3/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 2.2515 - accuracy: 0.3652
# Epoch 4/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 2.1122 - accuracy: 0.4014
# Epoch 5/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 2.0143 - accuracy: 0.4264
# Epoch 6/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.9389 - accuracy: 0.4458
# Epoch 7/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.8787 - accuracy: 0.4596
# Epoch 8/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.8290 - accuracy: 0.4715
# Epoch 9/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.7865 - accuracy: 0.4820
# Epoch 10/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.7501 - accuracy: 0.4913
# Epoch 11/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.7186 - accuracy: 0.4988
# Epoch 12/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.6898 - accuracy: 0.5062
# Epoch 13/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.6652 - accuracy: 0.5099
# Epoch 14/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.6405 - accuracy: 0.5157
# Epoch 15/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 1.6201 - accuracy: 0.5229
# Epoch 16/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.6007 - accuracy: 0.5267
# Epoch 17/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.5837 - accuracy: 0.5311
# Epoch 18/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.5666 - accuracy: 0.5359
# Epoch 19/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.5523 - accuracy: 0.5379
# Epoch 20/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.5381 - accuracy: 0.5430
# Epoch 21/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.5245 - accuracy: 0.5446
# Epoch 22/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.5134 - accuracy: 0.5485
# Epoch 23/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.5020 - accuracy: 0.5512
# Epoch 24/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.4919 - accuracy: 0.5547
# Epoch 25/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.4817 - accuracy: 0.5561
# Epoch 26/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.4731 - accuracy: 0.5599
# Epoch 27/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.4635 - accuracy: 0.5620
# Epoch 28/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.4553 - accuracy: 0.5636
# Epoch 29/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.4480 - accuracy: 0.5651
# Epoch 30/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.4398 - accuracy: 0.5659
# Epoch 31/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.4335 - accuracy: 0.5702
# Epoch 32/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.4261 - accuracy: 0.5709
# Epoch 33/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.4202 - accuracy: 0.5732
# Epoch 34/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4141 - accuracy: 0.5737
# Epoch 35/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.4078 - accuracy: 0.5765
# Epoch 36/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4019 - accuracy: 0.5784
# Epoch 37/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.3965 - accuracy: 0.5796
# Epoch 38/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.3915 - accuracy: 0.5806
# Epoch 39/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.3854 - accuracy: 0.5819
# Epoch 40/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.3804 - accuracy: 0.5849
# Epoch 41/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.3753 - accuracy: 0.5852
# Epoch 42/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.3709 - accuracy: 0.5866
# Epoch 43/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.3669 - accuracy: 0.5879
# Epoch 44/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.3614 - accuracy: 0.5898
# Epoch 45/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.3586 - accuracy: 0.5878
# Epoch 46/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.3539 - accuracy: 0.5907
# Epoch 47/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.3488 - accuracy: 0.5925
# Epoch 48/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.3459 - accuracy: 0.5933
# Epoch 49/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.3415 - accuracy: 0.5947
# Epoch 50/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.3374 - accuracy: 0.5943

# %%
# CNN for top right quadrant

# Define the input shape for each quadrant
input_shape = (14, 14, 1)

# Create a sequential model for the top left quadrant
model_tr = Sequential()

# Add a convolutional layer with 16 filters, 3x3 kernel size, and sigmoid activation
model_tr.add(Conv2D(16, kernel_size=(3, 3), activation='sigmoid', input_shape=input_shape))

# Add a max pooling layer with 2x2 pool size
model_tr.add(MaxPooling2D(pool_size=(2, 2)))

# Add a convolutional layer with 32 filters, 3x3 kernel size, and sigmoid activation
model_tr.add(Conv2D(32, kernel_size=(3, 3), activation='sigmoid'))

# Add a max pooling layer with 2x2 pool size
model_tr.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output of the previous layer
model_tr.add(Flatten())

# Add the output layer with 46 units and softmax activation
model_tr.add(Dense(46, activation='softmax'))

# Compile the model with categorical crossentropy loss and Adam optimizer
model_tr.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model_tr.summary()

# Train the model on the top left quadrant dataset
model_tr.fit(x_train_tr, train_labels_onehot, batch_size=32, epochs=50)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 12, 12, 16)        160
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 16)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 32)          4640
#
#  max_pooling2d_3 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 46)                5934
#
# =================================================================
# Total params: 10,734
# Trainable params: 10,734
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 3.5599 - accuracy: 0.0923
# Epoch 2/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 2.8785 - accuracy: 0.2225
# Epoch 3/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 2.5963 - accuracy: 0.2824
# Epoch 4/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 2.4358 - accuracy: 0.3211
# Epoch 5/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 2.3244 - accuracy: 0.3446
# Epoch 6/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 2.2459 - accuracy: 0.3646
# Epoch 7/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 2.1852 - accuracy: 0.3804
# Epoch 8/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 2.1362 - accuracy: 0.3902
# Epoch 9/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 2.0960 - accuracy: 0.3994
# Epoch 10/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 2.0610 - accuracy: 0.4088
# Epoch 11/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 2.0308 - accuracy: 0.4168
# Epoch 12/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 2.0046 - accuracy: 0.4223
# Epoch 13/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.9808 - accuracy: 0.4281
# Epoch 14/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.9608 - accuracy: 0.4340
# Epoch 15/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.9400 - accuracy: 0.4403
# Epoch 16/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.9248 - accuracy: 0.4427
# Epoch 17/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.9086 - accuracy: 0.4471
# Epoch 18/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.8948 - accuracy: 0.4510
# Epoch 19/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.8812 - accuracy: 0.4529
# Epoch 20/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.8674 - accuracy: 0.4551
# Epoch 21/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.8564 - accuracy: 0.4608
# Epoch 22/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.8449 - accuracy: 0.4650
# Epoch 23/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.8340 - accuracy: 0.4658
# Epoch 24/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.8241 - accuracy: 0.4697
# Epoch 25/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.8149 - accuracy: 0.4710
# Epoch 26/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.8062 - accuracy: 0.4726
# Epoch 27/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.7979 - accuracy: 0.4753
# Epoch 28/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.7894 - accuracy: 0.4774
# Epoch 29/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.7824 - accuracy: 0.4789
# Epoch 30/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.7744 - accuracy: 0.4817
# Epoch 31/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.7674 - accuracy: 0.4824
# Epoch 32/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.7611 - accuracy: 0.4839
# Epoch 33/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.7536 - accuracy: 0.4873
# Epoch 34/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.7472 - accuracy: 0.4877
# Epoch 35/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.7416 - accuracy: 0.4899
# Epoch 36/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.7357 - accuracy: 0.4928
# Epoch 37/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.7311 - accuracy: 0.4925
# Epoch 38/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.7246 - accuracy: 0.4929
# Epoch 39/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.7201 - accuracy: 0.4955
# Epoch 40/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.7139 - accuracy: 0.4962
# Epoch 41/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.7100 - accuracy: 0.4969
# Epoch 42/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.7055 - accuracy: 0.4976
# Epoch 43/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.7004 - accuracy: 0.4983
# Epoch 44/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.6966 - accuracy: 0.5015
# Epoch 45/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.6929 - accuracy: 0.5009
# Epoch 46/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.6886 - accuracy: 0.5036
# Epoch 47/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.6844 - accuracy: 0.5037
# Epoch 48/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.6809 - accuracy: 0.5048
# Epoch 49/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.6761 - accuracy: 0.5064
# Epoch 50/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.6721 - accuracy: 0.5064

# %%
# CNN for bottom left quadrant

# Define the input shape for each quadrant
input_shape = (14, 14, 1)

# Create a sequential model for the top left quadrant
model_bl = Sequential()

# Add a convolutional layer with 16 filters, 3x3 kernel size, and sigmoid activation
model_bl.add(Conv2D(16, kernel_size=(3, 3), activation='sigmoid', input_shape=input_shape))

# Add a max pooling layer with 2x2 pool size
model_bl.add(MaxPooling2D(pool_size=(2, 2)))

# Add a convolutional layer with 32 filters, 3x3 kernel size, and sigmoid activation
model_bl.add(Conv2D(32, kernel_size=(3, 3), activation='sigmoid'))

# Add a max pooling layer with 2x2 pool size
model_bl.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output of the previous layer
model_bl.add(Flatten())

# Add the output layer with 46 units and softmax activation
model_bl.add(Dense(46, activation='softmax'))

# Compile the model with categorical crossentropy loss and Adam optimizer
model_bl.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model_bl.summary()

# Train the model on the top left quadrant dataset
model_bl.fit(x_train_bl, train_labels_onehot, batch_size=32, epochs=50)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 12, 12, 16)        160
#
#  max_pooling2d_4 (MaxPooling  (None, 6, 6, 16)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 32)          4640
#
#  max_pooling2d_5 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 46)                5934
#
# =================================================================
# Total params: 10,734
# Trainable params: 10,734
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 3.1395 - accuracy: 0.1826
# Epoch 2/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 2.3372 - accuracy: 0.3663
# Epoch 3/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 2.0155 - accuracy: 0.4408
# Epoch 4/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.8402 - accuracy: 0.4804
# Epoch 5/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.7316 - accuracy: 0.5067
# Epoch 6/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.6528 - accuracy: 0.5254
# Epoch 7/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.5910 - accuracy: 0.5405
# Epoch 8/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.5416 - accuracy: 0.5515
# Epoch 9/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4985 - accuracy: 0.5633
# Epoch 10/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4616 - accuracy: 0.5709
# Epoch 11/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4293 - accuracy: 0.5802
# Epoch 12/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.4006 - accuracy: 0.5868
# Epoch 13/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.3754 - accuracy: 0.5914
# Epoch 14/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.3524 - accuracy: 0.5982
# Epoch 15/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.3329 - accuracy: 0.6005
# Epoch 16/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.3144 - accuracy: 0.6074
# Epoch 17/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.2972 - accuracy: 0.6134
# Epoch 18/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.2815 - accuracy: 0.6146
# Epoch 19/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.2664 - accuracy: 0.6210
# Epoch 20/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.2536 - accuracy: 0.6240
# Epoch 21/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.2394 - accuracy: 0.6289
# Epoch 22/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.2280 - accuracy: 0.6310
# Epoch 23/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.2157 - accuracy: 0.6331
# Epoch 24/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.2064 - accuracy: 0.6359
# Epoch 25/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.1962 - accuracy: 0.6383
# Epoch 26/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.1867 - accuracy: 0.6415
# Epoch 27/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.1778 - accuracy: 0.6414
# Epoch 28/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.1697 - accuracy: 0.6444
# Epoch 29/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.1615 - accuracy: 0.6459
# Epoch 30/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.1543 - accuracy: 0.6482
# Epoch 31/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.1469 - accuracy: 0.6518
# Epoch 32/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.1400 - accuracy: 0.6527
# Epoch 33/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.1328 - accuracy: 0.6539
# Epoch 34/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.1264 - accuracy: 0.6553
# Epoch 35/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.1206 - accuracy: 0.6573
# Epoch 36/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.1139 - accuracy: 0.6582
# Epoch 37/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.1085 - accuracy: 0.6601
# Epoch 38/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.1031 - accuracy: 0.6612
# Epoch 39/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0980 - accuracy: 0.6627
# Epoch 40/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0930 - accuracy: 0.6644
# Epoch 41/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0883 - accuracy: 0.6638
# Epoch 42/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0828 - accuracy: 0.6663
# Epoch 43/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0783 - accuracy: 0.6676
# Epoch 44/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0741 - accuracy: 0.6680
# Epoch 45/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0697 - accuracy: 0.6688
# Epoch 46/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0657 - accuracy: 0.6694
# Epoch 47/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0609 - accuracy: 0.6725
# Epoch 48/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0565 - accuracy: 0.6729
# Epoch 49/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0529 - accuracy: 0.6732
# Epoch 50/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0494 - accuracy: 0.6741

# %%
# CNN for bottom right quadrant

# Define the input shape for each quadrant
input_shape = (14, 14, 1)

# Create a sequential model for the top left quadrant
model_br = Sequential()

# Add a convolutional layer with 16 filters, 3x3 kernel size, and sigmoid activation
model_br.add(Conv2D(16, kernel_size=(3, 3), activation='sigmoid', input_shape=input_shape))

# Add a max pooling layer with 2x2 pool size
model_br.add(MaxPooling2D(pool_size=(2, 2)))

# Add a convolutional layer with 32 filters, 3x3 kernel size, and sigmoid activation
model_br.add(Conv2D(32, kernel_size=(3, 3), activation='sigmoid'))

# Add a max pooling layer with 2x2 pool size
model_br.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output of the previous layer
model_br.add(Flatten())

# Add the output layer with 46 units and softmax activation
model_br.add(Dense(46, activation='softmax'))

# Compile the model with categorical crossentropy loss and Adam optimizer
model_br.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model_br.summary()

# Train the model on the top left quadrant dataset
model_br.fit(x_train_br, train_labels_onehot, batch_size=32, epochs=50)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 12, 12, 16)        160
#
#  max_pooling2d_6 (MaxPooling  (None, 6, 6, 16)         0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 4, 4, 32)          4640
#
#  max_pooling2d_7 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  flatten_3 (Flatten)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 46)                5934
#
# =================================================================
# Total params: 10,734
# Trainable params: 10,734
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 3.3353 - accuracy: 0.1360
# Epoch 2/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 2.5425 - accuracy: 0.2901
# Epoch 3/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 2.2822 - accuracy: 0.3449
# Epoch 4/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 2.1368 - accuracy: 0.3754
# Epoch 5/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 2.0366 - accuracy: 0.3980
# Epoch 6/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.9628 - accuracy: 0.4166
# Epoch 7/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.9042 - accuracy: 0.4338
# Epoch 8/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.8561 - accuracy: 0.4428
# Epoch 9/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.8157 - accuracy: 0.4543
# Epoch 10/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.7798 - accuracy: 0.4633
# Epoch 11/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.7494 - accuracy: 0.4719
# Epoch 12/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.7221 - accuracy: 0.4789
# Epoch 13/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.6977 - accuracy: 0.4857
# Epoch 14/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.6765 - accuracy: 0.4899
# Epoch 15/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.6564 - accuracy: 0.4962
# Epoch 16/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.6397 - accuracy: 0.4995
# Epoch 17/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.6219 - accuracy: 0.5044
# Epoch 18/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.6068 - accuracy: 0.5086
# Epoch 19/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.5918 - accuracy: 0.5127
# Epoch 20/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.5778 - accuracy: 0.5158
# Epoch 21/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.5655 - accuracy: 0.5194
# Epoch 22/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.5545 - accuracy: 0.5217
# Epoch 23/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.5434 - accuracy: 0.5255
# Epoch 24/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.5338 - accuracy: 0.5282
# Epoch 25/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.5236 - accuracy: 0.5309
# Epoch 26/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.5154 - accuracy: 0.5315
# Epoch 27/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.5050 - accuracy: 0.5340
# Epoch 28/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4979 - accuracy: 0.5359
# Epoch 29/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4896 - accuracy: 0.5381
# Epoch 30/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4818 - accuracy: 0.5410
# Epoch 31/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4752 - accuracy: 0.5430
# Epoch 32/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4678 - accuracy: 0.5435
# Epoch 33/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4624 - accuracy: 0.5451
# Epoch 34/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4566 - accuracy: 0.5469
# Epoch 35/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.4500 - accuracy: 0.5494
# Epoch 36/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.4445 - accuracy: 0.5521
# Epoch 37/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4385 - accuracy: 0.5531
# Epoch 38/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.4337 - accuracy: 0.5549
# Epoch 39/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.4282 - accuracy: 0.5550
# Epoch 40/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4241 - accuracy: 0.5560
# Epoch 41/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.4198 - accuracy: 0.5578
# Epoch 42/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4154 - accuracy: 0.5582
# Epoch 43/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.4107 - accuracy: 0.5595
# Epoch 44/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.4071 - accuracy: 0.5616
# Epoch 45/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.4033 - accuracy: 0.5610
# Epoch 46/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.3991 - accuracy: 0.5618
# Epoch 47/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.3952 - accuracy: 0.5634
# Epoch 48/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.3920 - accuracy: 0.5649
# Epoch 49/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.3894 - accuracy: 0.5655
# Epoch 50/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.3852 - accuracy: 0.5669

# %%
# CNN for center quadrant

# Define the input shape for each quadrant
input_shape = (14, 14, 1)

# Create a sequential model for the top left quadrant
model_c = Sequential()

# Add a convolutional layer with 16 filters, 3x3 kernel size, and sigmoid activation
model_c.add(Conv2D(16, kernel_size=(3, 3), activation='sigmoid', input_shape=input_shape))

# Add a max pooling layer with 2x2 pool size
model_c.add(MaxPooling2D(pool_size=(2, 2)))

# Add a convolutional layer with 32 filters, 3x3 kernel size, and sigmoid activation
model_c.add(Conv2D(32, kernel_size=(3, 3), activation='sigmoid'))

# Add a max pooling layer with 2x2 pool size
model_c.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output of the previous layer
model_c.add(Flatten())

# Add the output layer with 46 units and softmax activation
model_c.add(Dense(46, activation='softmax'))

# Compile the model with categorical crossentropy loss and Adam optimizer
model_c.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model_c.summary()

# Train the model on the top left quadrant dataset
model_c.fit(x_train_c, train_labels_onehot, batch_size=32, epochs=50)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 12, 12, 16)        160
#
#  max_pooling2d_8 (MaxPooling  (None, 6, 6, 16)         0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 4, 4, 32)          4640
#
#  max_pooling2d_9 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  flatten_4 (Flatten)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 46)                5934
#
# =================================================================
# Total params: 10,734
# Trainable params: 10,734
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 3.2246 - accuracy: 0.1658
# Epoch 2/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 2.3478 - accuracy: 0.3655
# Epoch 3/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 2.0175 - accuracy: 0.4486
# Epoch 4/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.8266 - accuracy: 0.4972
# Epoch 5/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.6961 - accuracy: 0.5291
# Epoch 6/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.5990 - accuracy: 0.5531
# Epoch 7/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.5201 - accuracy: 0.5711
# Epoch 8/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4576 - accuracy: 0.5872
# Epoch 9/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.4036 - accuracy: 0.6020
# Epoch 10/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.3594 - accuracy: 0.6128
# Epoch 11/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.3193 - accuracy: 0.6214
# Epoch 12/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.2866 - accuracy: 0.6307
# Epoch 13/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.2568 - accuracy: 0.6386
# Epoch 14/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.2305 - accuracy: 0.6451
# Epoch 15/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.2075 - accuracy: 0.6497
# Epoch 16/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.1862 - accuracy: 0.6560
# Epoch 17/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.1656 - accuracy: 0.6623
# Epoch 18/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.1484 - accuracy: 0.6653
# Epoch 19/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.1322 - accuracy: 0.6688
# Epoch 20/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.1158 - accuracy: 0.6737
# Epoch 21/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.1015 - accuracy: 0.6782
# Epoch 22/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0889 - accuracy: 0.6814
# Epoch 23/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0761 - accuracy: 0.6840
# Epoch 24/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0635 - accuracy: 0.6877
# Epoch 25/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.0528 - accuracy: 0.6910
# Epoch 26/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.0411 - accuracy: 0.6930
# Epoch 27/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0310 - accuracy: 0.6954
# Epoch 28/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0212 - accuracy: 0.6979
# Epoch 29/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0118 - accuracy: 0.6998
# Epoch 30/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0036 - accuracy: 0.7031
# Epoch 31/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.9954 - accuracy: 0.7048
# Epoch 32/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.9869 - accuracy: 0.7065
# Epoch 33/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.9787 - accuracy: 0.7092
# Epoch 34/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.9714 - accuracy: 0.7110
# Epoch 35/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 0.9646 - accuracy: 0.7150
# Epoch 36/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.9572 - accuracy: 0.7152
# Epoch 37/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.9504 - accuracy: 0.7165
# Epoch 38/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.9449 - accuracy: 0.7183
# Epoch 39/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.9389 - accuracy: 0.7206
# Epoch 40/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.9331 - accuracy: 0.7216
# Epoch 41/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.9276 - accuracy: 0.7229
# Epoch 42/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.9214 - accuracy: 0.7250
# Epoch 43/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 0.9173 - accuracy: 0.7255
# Epoch 44/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.9125 - accuracy: 0.7265
# Epoch 45/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.9080 - accuracy: 0.7281
# Epoch 46/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.9030 - accuracy: 0.7297
# Epoch 47/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.8991 - accuracy: 0.7298
# Epoch 48/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.8944 - accuracy: 0.7320
# Epoch 49/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.8899 - accuracy: 0.7324
# Epoch 50/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.8867 - accuracy: 0.7333

# %%
from tensorflow.keras.models import Model

# create new models to extract features from the last dense layer
model_tl_features = Model(inputs=model_tl.input, outputs=model_tl.get_layer('flatten').output)
model_tr_features = Model(inputs=model_tr.input, outputs=model_tr.get_layer('flatten_1').output)
model_bl_features = Model(inputs=model_bl.input, outputs=model_bl.get_layer('flatten_2').output)
model_br_features = Model(inputs=model_br.input, outputs=model_br.get_layer('flatten_3').output)
model_c_features = Model(inputs=model_c.input, outputs=model_c.get_layer('flatten_4').output)

# extract features from the last dense layer for each quadrant
tl_features = model_tl_features.predict(x_train_tl)
tr_features = model_tr_features.predict(x_train_tr)
bl_features = model_bl_features.predict(x_train_bl)
br_features = model_br_features.predict(x_train_br)
center_features = model_c_features.predict(x_train_c)

# concatenate the features from all 5 quadrants into a single input
features = np.concatenate((tl_features, tr_features, bl_features, br_features, center_features), axis=1)
# Out:
# 2444/2444 [==============================] - 3s 1ms/step
# 2444/2444 [==============================] - 4s 2ms/step
# 2444/2444 [==============================] - 5s 2ms/step
# 2444/2444 [==============================] - 4s 2ms/step
# 2444/2444 [==============================] - 4s 2ms/step

# %%
print(features.shape)
# Out:
# (78200, 640)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# define the DNN classifier model
classifier = Sequential()
classifier.add(Dense(640, activation='relu', input_shape=(features.shape[1],)))
classifier.add(Dense(512, activation='relu'))
classifier.add(Dense(256, activation='relu'))
classifier.add(Dense(128, activation='relu'))
classifier.add(Dense(46, activation='softmax'))

# compile the model
classifier.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history = classifier.fit(features, train_labels_onehot, batch_size=32, epochs=10)
# Out:
# Epoch 1/10
# 2444/2444 [==============================] - 38s 15ms/step - loss: 0.4756 - accuracy: 0.8552
# Epoch 2/10
# 2444/2444 [==============================] - 40s 17ms/step - loss: 0.1878 - accuracy: 0.9420
# Epoch 3/10
# 2444/2444 [==============================] - 41s 17ms/step - loss: 0.1441 - accuracy: 0.9558
# Epoch 4/10
# 2444/2444 [==============================] - 41s 17ms/step - loss: 0.1182 - accuracy: 0.9639
# Epoch 5/10
# 2444/2444 [==============================] - 41s 17ms/step - loss: 0.0985 - accuracy: 0.9701
# Epoch 6/10
# 2444/2444 [==============================] - 42s 17ms/step - loss: 0.0892 - accuracy: 0.9733
# Epoch 7/10
# 2444/2444 [==============================] - 42s 17ms/step - loss: 0.0819 - accuracy: 0.9751
# Epoch 8/10
# 2444/2444 [==============================] - 41s 17ms/step - loss: 0.0783 - accuracy: 0.9765
# Epoch 9/10
# 2444/2444 [==============================] - 41s 17ms/step - loss: 0.0703 - accuracy: 0.9800
# Epoch 10/10
# 2444/2444 [==============================] - 41s 17ms/step - loss: 0.0672 - accuracy: 0.9812

# %% [markdown]
# # Preprocessing the test data for prediction and testing

# %%
test_labels_int = label_encoder.fit_transform(test_labels)

# %%
# Convert the integer labels to one-hot encoding
test_labels_onehot = to_categorical(test_labels_int, num_classes=46)

# Split the data into the five quadrants
x_test_tl = test_images[:,:14,:14].reshape(-1, 14, 14, 1)
x_test_tr = test_images[:,:14,14:].reshape(-1, 14, 14, 1)
x_test_bl = test_images[:,14:,:14].reshape(-1, 14, 14, 1)
x_test_br = test_images[:,14:,14:].reshape(-1, 14, 14, 1)
x_test_c = test_images[:,7:21,7:21].reshape(-1, 14, 14, 1)

# %%
# extract features from the last dense layer for each quadrant
tl_features_test = model_tl_features.predict(x_test_tl)
tr_features_test = model_tr_features.predict(x_test_tr)
bl_features_test = model_bl_features.predict(x_test_bl)
br_features_test = model_br_features.predict(x_test_br)
center_features_test = model_c_features.predict(x_test_c)

# concatenate the features from all 5 quadrants into a single input
features_test = np.concatenate((tl_features_test, tr_features_test, bl_features_test, br_features_test, center_features_test), axis=1)
# Out:
# 432/432 [==============================] - 1s 1ms/step
# 432/432 [==============================] - 1s 1ms/step
# 432/432 [==============================] - 1s 1ms/step
# 432/432 [==============================] - 1s 1ms/step
# 432/432 [==============================] - 1s 1ms/step

# %%
# Save the model to disk
classifier.save("model_f128x5_b32e50_b32e10.h5")

# %%
test_predictions = classifier.predict(features_test)
# Out:
# 432/432 [==============================] - 1s 3ms/step

# %%
# Evaluate the model
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
accuracy = accuracy_score(test_labels_int, test_predictions.argmax(axis=1))
precision = precision_score(test_labels_int, test_predictions.argmax(axis=1), average='weighted')
recall = recall_score(test_labels_int, test_predictions.argmax(axis=1), average='weighted')
f1 = f1_score(test_labels_int, test_predictions.argmax(axis=1), average='weighted')

# %%
print('Accuracy:', accuracy)
print('Precision:', precision)
print('Recall:', recall)
print('F1 Score:', f1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print('Accuracy:', accuracy)
#       2 print('Precision:', precision)
#       3 print('Recall:', recall)
#
# NameError: name 'accuracy' is not defined
