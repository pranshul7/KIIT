# %%
import os
import numpy as np
import cv2
from PIL import Image
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# %%
# Define the path to the train and test folders
train_path = 'C:/A/code/VSC/python/test/cropped_DevanagariHandwrittenCharacterDataset/Train/'
test_path = 'C:/A/code/VSC/python/test/cropped_DevanagariHandwrittenCharacterDataset/Test/'

# Define a function to load and preprocess the images
def load_images(path):
    # Create empty lists to store the images and labels
    images = []
    labels = []

    # Loop through each folder (which represents a class) in the path
    for folder in os.listdir(path):
        # Get the path to the folder
        folder_path = os.path.join(path, folder)
        # Loop through each image in the folder
        for file in os.listdir(folder_path):
            # Get the path to the image file
            img_path = os.path.join(folder_path, file)
            # Load the image using OpenCV
            img = cv2.imread(img_path)
            # Convert the image to grayscale
            img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            # Normalize the pixel values of the images
            img = img.astype('float32') / 255.0
            # Append the image to the images list
            images.append(img)
            # Append the label to the labels list
            labels.append(folder)

    # Convert the images and labels lists to NumPy arrays
    images = np.array(images)
    labels = np.array(labels)
    
    # Return the images and labels arrays
    return images, labels

# Load the train images and labels
train_images, train_labels = load_images(train_path)

# Load the test images and labels
test_images, test_labels = load_images(test_path)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.utils import to_categorical

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

# Convert the string labels to integer labels
label_encoder = LabelEncoder()
train_labels_int = label_encoder.fit_transform(train_labels)

# %%
# Convert the integer labels to one-hot encoding
train_labels_onehot = to_categorical(train_labels_int, num_classes=46)

# Split the data into the five quadrants
x_train_tl = train_images[:,:14,:14].reshape(-1, 14, 14, 1)
x_train_tr = train_images[:,:14,14:].reshape(-1, 14, 14, 1)
x_train_bl = train_images[:,14:,:14].reshape(-1, 14, 14, 1)
x_train_br = train_images[:,14:,14:].reshape(-1, 14, 14, 1)
x_train_c = train_images[:,7:21,7:21].reshape(-1, 14, 14, 1)

# %%
# CNN for top left quadrant

# Define the input shape for each quadrant
input_shape = (14, 14, 1)

# Create a sequential model for the top left quadrant
model_tl = Sequential()

# Add a convolutional layer with 16 filters, 3x3 kernel size, and sigmoid activation
model_tl.add(Conv2D(16, kernel_size=(3, 3), activation='sigmoid', input_shape=input_shape))

# Add a max pooling layer with 2x2 pool size
model_tl.add(MaxPooling2D(pool_size=(2, 2)))

# Add a convolutional layer with 32 filters, 3x3 kernel size, and sigmoid activation
model_tl.add(Conv2D(32, kernel_size=(3, 3), activation='sigmoid'))

# Add a max pooling layer with 2x2 pool size
model_tl.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output of the previous layer
model_tl.add(Flatten())

# Add a dense layer with 512 units and relu activation
model_tl.add(Dense(512, activation='relu'))

# Add the output layer with 46 units and softmax activation
model_tl.add(Dense(46, activation='softmax'))

# Compile the model with categorical crossentropy loss and Adam optimizer
model_tl.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model_tl.summary()

# Train the model on the top left quadrant dataset
model_tl.fit(x_train_tl, train_labels_onehot, batch_size=32, epochs=50)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 12, 12, 16)        160
#
#  max_pooling2d (MaxPooling2D  (None, 6, 6, 16)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 4, 4, 32)          4640
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 512)               66048
#
#  dense_1 (Dense)             (None, 46)                23598
#
# =================================================================
# Total params: 94,446
# Trainable params: 94,446
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 2.9310 - accuracy: 0.2013
# Epoch 2/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 2.1097 - accuracy: 0.3795
# Epoch 3/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.8678 - accuracy: 0.4429
# Epoch 4/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.7142 - accuracy: 0.4820
# Epoch 5/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.6006 - accuracy: 0.5138
# Epoch 6/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.5153 - accuracy: 0.5360
# Epoch 7/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.4438 - accuracy: 0.5560
# Epoch 8/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.3861 - accuracy: 0.5716
# Epoch 9/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.3388 - accuracy: 0.5831
# Epoch 10/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.2985 - accuracy: 0.5948
# Epoch 11/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.2594 - accuracy: 0.6053
# Epoch 12/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.2271 - accuracy: 0.6145
# Epoch 13/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.1986 - accuracy: 0.6230
# Epoch 14/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.1732 - accuracy: 0.6288
# Epoch 15/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.1487 - accuracy: 0.6362
# Epoch 16/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.1271 - accuracy: 0.6437
# Epoch 17/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.1064 - accuracy: 0.6491
# Epoch 18/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.0877 - accuracy: 0.6539
# Epoch 19/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.0689 - accuracy: 0.6587
# Epoch 20/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0533 - accuracy: 0.6649
# Epoch 21/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0364 - accuracy: 0.6692
# Epoch 22/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0213 - accuracy: 0.6718
# Epoch 23/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0076 - accuracy: 0.6763
# Epoch 24/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.9956 - accuracy: 0.6794
# Epoch 25/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 0.9821 - accuracy: 0.6828
# Epoch 26/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 0.9698 - accuracy: 0.6886
# Epoch 27/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 0.9599 - accuracy: 0.6883
# Epoch 28/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.9482 - accuracy: 0.6940
# Epoch 29/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 0.9375 - accuracy: 0.6962
# Epoch 30/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 0.9291 - accuracy: 0.6977
# Epoch 31/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.9187 - accuracy: 0.7016
# Epoch 32/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.9111 - accuracy: 0.7044
# Epoch 33/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 0.9033 - accuracy: 0.7066
# Epoch 34/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.8927 - accuracy: 0.7112
# Epoch 35/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.8846 - accuracy: 0.7111
# Epoch 36/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.8764 - accuracy: 0.7146
# Epoch 37/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.8690 - accuracy: 0.7179
# Epoch 38/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.8629 - accuracy: 0.7184
# Epoch 39/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.8543 - accuracy: 0.7225
# Epoch 40/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.8489 - accuracy: 0.7224
# Epoch 41/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.8414 - accuracy: 0.7256
# Epoch 42/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.8341 - accuracy: 0.7264
# Epoch 43/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.8281 - accuracy: 0.7286
# Epoch 44/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.8221 - accuracy: 0.7309
# Epoch 45/50
# 2444/2444 [==============================] - 14s 6ms/step - loss: 0.8168 - accuracy: 0.7323
# Epoch 46/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.8121 - accuracy: 0.7337
# Epoch 47/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.8056 - accuracy: 0.7367
# Epoch 48/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.7998 - accuracy: 0.7365
# Epoch 49/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.7940 - accuracy: 0.7392
# Epoch 50/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.7904 - accuracy: 0.7387

# %%
# CNN for top right quadrant

# Define the input shape for each quadrant
input_shape = (14, 14, 1)

# Create a sequential model for the top left quadrant
model_tr = Sequential()

# Add a convolutional layer with 16 filters, 3x3 kernel size, and sigmoid activation
model_tr.add(Conv2D(16, kernel_size=(3, 3), activation='sigmoid', input_shape=input_shape))

# Add a max pooling layer with 2x2 pool size
model_tr.add(MaxPooling2D(pool_size=(2, 2)))

# Add a convolutional layer with 32 filters, 3x3 kernel size, and sigmoid activation
model_tr.add(Conv2D(32, kernel_size=(3, 3), activation='sigmoid'))

# Add a max pooling layer with 2x2 pool size
model_tr.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output of the previous layer
model_tr.add(Flatten())

# Add a dense layer with 512 units and relu activation
model_tr.add(Dense(512, activation='relu'))

# Add the output layer with 46 units and softmax activation
model_tr.add(Dense(46, activation='softmax'))

# Compile the model with categorical crossentropy loss and Adam optimizer
model_tr.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model_tr.summary()

# Train the model on the top left quadrant dataset
model_tr.fit(x_train_tr, train_labels_onehot, batch_size=32, epochs=50)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 12, 12, 16)        160
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 16)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 32)          4640
#
#  max_pooling2d_3 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 512)               66048
#
#  dense_3 (Dense)             (None, 46)                23598
#
# =================================================================
# Total params: 94,446
# Trainable params: 94,446
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 3.2236 - accuracy: 0.1453
# Epoch 2/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 2.5270 - accuracy: 0.2830
# Epoch 3/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 2.2853 - accuracy: 0.3421
# Epoch 4/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 2.1203 - accuracy: 0.3828
# Epoch 5/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.9990 - accuracy: 0.4155
# Epoch 6/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.9036 - accuracy: 0.4392
# Epoch 7/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.8266 - accuracy: 0.4596
# Epoch 8/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.7634 - accuracy: 0.4743
# Epoch 9/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.7084 - accuracy: 0.4900
# Epoch 10/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.6648 - accuracy: 0.4990
# Epoch 11/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.6234 - accuracy: 0.5106
# Epoch 12/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.5886 - accuracy: 0.5199
# Epoch 13/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.5583 - accuracy: 0.5293
# Epoch 14/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.5310 - accuracy: 0.5374
# Epoch 15/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.5061 - accuracy: 0.5428
# Epoch 16/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.4825 - accuracy: 0.5493
# Epoch 17/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.4613 - accuracy: 0.5549
# Epoch 18/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.4420 - accuracy: 0.5594
# Epoch 19/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.4202 - accuracy: 0.5662
# Epoch 20/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.4051 - accuracy: 0.5713
# Epoch 21/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.3868 - accuracy: 0.5759
# Epoch 22/50
# 2444/2444 [==============================] - 18s 7ms/step - loss: 1.3725 - accuracy: 0.5794
# Epoch 23/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.3563 - accuracy: 0.5845
# Epoch 24/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.3426 - accuracy: 0.5885
# Epoch 25/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.3276 - accuracy: 0.5925
# Epoch 26/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.3165 - accuracy: 0.5946
# Epoch 27/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.3036 - accuracy: 0.5978
# Epoch 28/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.2921 - accuracy: 0.6023
# Epoch 29/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.2796 - accuracy: 0.6050
# Epoch 30/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.2681 - accuracy: 0.6077
# Epoch 31/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.2593 - accuracy: 0.6107
# Epoch 32/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.2477 - accuracy: 0.6131
# Epoch 33/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.2399 - accuracy: 0.6162
# Epoch 34/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.2307 - accuracy: 0.6191
# Epoch 35/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.2196 - accuracy: 0.6227
# Epoch 36/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.2121 - accuracy: 0.6232
# Epoch 37/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.2046 - accuracy: 0.6270
# Epoch 38/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.1958 - accuracy: 0.6276
# Epoch 39/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.1872 - accuracy: 0.6314
# Epoch 40/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.1821 - accuracy: 0.6323
# Epoch 41/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.1734 - accuracy: 0.6340
# Epoch 42/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.1634 - accuracy: 0.6387
# Epoch 43/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.1586 - accuracy: 0.6396
# Epoch 44/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.1547 - accuracy: 0.6406
# Epoch 45/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.1452 - accuracy: 0.6438
# Epoch 46/50
# 2444/2444 [==============================] - 19s 8ms/step - loss: 1.1383 - accuracy: 0.6467
# Epoch 47/50
# 2444/2444 [==============================] - 21s 9ms/step - loss: 1.1309 - accuracy: 0.6475
# Epoch 48/50
# 2444/2444 [==============================] - 19s 8ms/step - loss: 1.1259 - accuracy: 0.6495
# Epoch 49/50
# 2444/2444 [==============================] - 18s 7ms/step - loss: 1.1199 - accuracy: 0.6510
# Epoch 50/50
# 2444/2444 [==============================] - 18s 8ms/step - loss: 1.1167 - accuracy: 0.6515

# %%
# CNN for bottom left quadrant

# Define the input shape for each quadrant
input_shape = (14, 14, 1)

# Create a sequential model for the top left quadrant
model_bl = Sequential()

# Add a convolutional layer with 16 filters, 3x3 kernel size, and sigmoid activation
model_bl.add(Conv2D(16, kernel_size=(3, 3), activation='sigmoid', input_shape=input_shape))

# Add a max pooling layer with 2x2 pool size
model_bl.add(MaxPooling2D(pool_size=(2, 2)))

# Add a convolutional layer with 32 filters, 3x3 kernel size, and sigmoid activation
model_bl.add(Conv2D(32, kernel_size=(3, 3), activation='sigmoid'))

# Add a max pooling layer with 2x2 pool size
model_bl.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output of the previous layer
model_bl.add(Flatten())

# Add a dense layer with 512 units and relu activation
model_bl.add(Dense(512, activation='relu'))

# Add the output layer with 46 units and softmax activation
model_bl.add(Dense(46, activation='softmax'))

# Compile the model with categorical crossentropy loss and Adam optimizer
model_bl.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model_bl.summary()

# Train the model on the top left quadrant dataset
model_bl.fit(x_train_bl, train_labels_onehot, batch_size=32, epochs=50)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 12, 12, 16)        160
#
#  max_pooling2d_4 (MaxPooling  (None, 6, 6, 16)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 32)          4640
#
#  max_pooling2d_5 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 512)               66048
#
#  dense_5 (Dense)             (None, 46)                23598
#
# =================================================================
# Total params: 94,446
# Trainable params: 94,446
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2444/2444 [==============================] - 17s 6ms/step - loss: 2.8178 - accuracy: 0.2354
# Epoch 2/50
# 2444/2444 [==============================] - 16s 7ms/step - loss: 1.8445 - accuracy: 0.4487
# Epoch 3/50
# 2444/2444 [==============================] - 16s 7ms/step - loss: 1.5929 - accuracy: 0.5131
# Epoch 4/50
# 2444/2444 [==============================] - 16s 7ms/step - loss: 1.4392 - accuracy: 0.5554
# Epoch 5/50
# 2444/2444 [==============================] - 16s 7ms/step - loss: 1.3315 - accuracy: 0.5849
# Epoch 6/50
# 2444/2444 [==============================] - 16s 6ms/step - loss: 1.2495 - accuracy: 0.6094
# Epoch 7/50
# 2444/2444 [==============================] - 16s 7ms/step - loss: 1.1845 - accuracy: 0.6255
# Epoch 8/50
# 2444/2444 [==============================] - 16s 7ms/step - loss: 1.1303 - accuracy: 0.6408
# Epoch 9/50
# 2444/2444 [==============================] - 16s 7ms/step - loss: 1.0841 - accuracy: 0.6543
# Epoch 10/50
# 2444/2444 [==============================] - 16s 7ms/step - loss: 1.0447 - accuracy: 0.6660
# Epoch 11/50
# 2444/2444 [==============================] - 16s 7ms/step - loss: 1.0082 - accuracy: 0.6768
# Epoch 12/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.9788 - accuracy: 0.6859
# Epoch 13/50
# 2444/2444 [==============================] - 16s 7ms/step - loss: 0.9510 - accuracy: 0.6923
# Epoch 14/50
# 2444/2444 [==============================] - 16s 7ms/step - loss: 0.9262 - accuracy: 0.7000
# Epoch 15/50
# 2444/2444 [==============================] - 16s 7ms/step - loss: 0.9035 - accuracy: 0.7068
# Epoch 16/50
# 2444/2444 [==============================] - 16s 6ms/step - loss: 0.8823 - accuracy: 0.7136
# Epoch 17/50
# 2444/2444 [==============================] - 16s 6ms/step - loss: 0.8642 - accuracy: 0.7186
# Epoch 18/50
# 2444/2444 [==============================] - 16s 7ms/step - loss: 0.8472 - accuracy: 0.7238
# Epoch 19/50
# 2444/2444 [==============================] - 16s 7ms/step - loss: 0.8312 - accuracy: 0.7284
# Epoch 20/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.8149 - accuracy: 0.7351
# Epoch 21/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.8012 - accuracy: 0.7381
# Epoch 22/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.7892 - accuracy: 0.7407
# Epoch 23/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.7778 - accuracy: 0.7436
# Epoch 24/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.7677 - accuracy: 0.7476
# Epoch 25/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.7554 - accuracy: 0.7522
# Epoch 26/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.7440 - accuracy: 0.7525
# Epoch 27/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.7333 - accuracy: 0.7579
# Epoch 28/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.7245 - accuracy: 0.7602
# Epoch 29/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.7139 - accuracy: 0.7643
# Epoch 30/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.7079 - accuracy: 0.7652
# Epoch 31/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.6983 - accuracy: 0.7669
# Epoch 32/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.6916 - accuracy: 0.7683
# Epoch 33/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.6838 - accuracy: 0.7706
# Epoch 34/50
# 2444/2444 [==============================] - 20s 8ms/step - loss: 0.6752 - accuracy: 0.7745
# Epoch 35/50
# 2444/2444 [==============================] - 20s 8ms/step - loss: 0.6692 - accuracy: 0.7758
# Epoch 36/50
# 2444/2444 [==============================] - 20s 8ms/step - loss: 0.6628 - accuracy: 0.7775
# Epoch 37/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.6572 - accuracy: 0.7807
# Epoch 38/50
# 2444/2444 [==============================] - 18s 7ms/step - loss: 0.6516 - accuracy: 0.7821
# Epoch 39/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.6424 - accuracy: 0.7850
# Epoch 40/50
# 2444/2444 [==============================] - 18s 7ms/step - loss: 0.6375 - accuracy: 0.7855
# Epoch 41/50
# 2444/2444 [==============================] - 18s 7ms/step - loss: 0.6319 - accuracy: 0.7852
# Epoch 42/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.6278 - accuracy: 0.7878
# Epoch 43/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.6201 - accuracy: 0.7916
# Epoch 44/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.6149 - accuracy: 0.7923
# Epoch 45/50
# 2444/2444 [==============================] - 18s 7ms/step - loss: 0.6106 - accuracy: 0.7932
# Epoch 46/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.6050 - accuracy: 0.7958
# Epoch 47/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.5996 - accuracy: 0.7977
# Epoch 48/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.5980 - accuracy: 0.7980
# Epoch 49/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.5905 - accuracy: 0.8000
# Epoch 50/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.5863 - accuracy: 0.8014

# %%
# CNN for bottom right quadrant

# Define the input shape for each quadrant
input_shape = (14, 14, 1)

# Create a sequential model for the top left quadrant
model_br = Sequential()

# Add a convolutional layer with 16 filters, 3x3 kernel size, and sigmoid activation
model_br.add(Conv2D(16, kernel_size=(3, 3), activation='sigmoid', input_shape=input_shape))

# Add a max pooling layer with 2x2 pool size
model_br.add(MaxPooling2D(pool_size=(2, 2)))

# Add a convolutional layer with 32 filters, 3x3 kernel size, and sigmoid activation
model_br.add(Conv2D(32, kernel_size=(3, 3), activation='sigmoid'))

# Add a max pooling layer with 2x2 pool size
model_br.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output of the previous layer
model_br.add(Flatten())

# Add a dense layer with 512 units and relu activation
model_br.add(Dense(512, activation='relu'))

# Add the output layer with 46 units and softmax activation
model_br.add(Dense(46, activation='softmax'))

# Compile the model with categorical crossentropy loss and Adam optimizer
model_br.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model_br.summary()

# Train the model on the top left quadrant dataset
model_br.fit(x_train_br, train_labels_onehot, batch_size=32, epochs=50)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 12, 12, 16)        160
#
#  max_pooling2d_6 (MaxPooling  (None, 6, 6, 16)         0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 4, 4, 32)          4640
#
#  max_pooling2d_7 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  flatten_3 (Flatten)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 512)               66048
#
#  dense_7 (Dense)             (None, 46)                23598
#
# =================================================================
# Total params: 94,446
# Trainable params: 94,446
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2444/2444 [==============================] - 17s 6ms/step - loss: 3.0112 - accuracy: 0.1780
# Epoch 2/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 2.1914 - accuracy: 0.3433
# Epoch 3/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.9383 - accuracy: 0.4047
# Epoch 4/50
# 2444/2444 [==============================] - 16s 7ms/step - loss: 1.7887 - accuracy: 0.4459
# Epoch 5/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.6927 - accuracy: 0.4702
# Epoch 6/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.6228 - accuracy: 0.4908
# Epoch 7/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.5668 - accuracy: 0.5072
# Epoch 8/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.5231 - accuracy: 0.5217
# Epoch 9/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.4832 - accuracy: 0.5301
# Epoch 10/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.4491 - accuracy: 0.5398
# Epoch 11/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.4186 - accuracy: 0.5489
# Epoch 12/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.3865 - accuracy: 0.5586
# Epoch 13/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.3618 - accuracy: 0.5665
# Epoch 14/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.3375 - accuracy: 0.5737
# Epoch 15/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.3149 - accuracy: 0.5805
# Epoch 16/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.2918 - accuracy: 0.5865
# Epoch 17/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.2744 - accuracy: 0.5920
# Epoch 18/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.2578 - accuracy: 0.5982
# Epoch 19/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.2393 - accuracy: 0.6020
# Epoch 20/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.2256 - accuracy: 0.6072
# Epoch 21/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.2109 - accuracy: 0.6117
# Epoch 22/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.1965 - accuracy: 0.6142
# Epoch 23/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.1840 - accuracy: 0.6196
# Epoch 24/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.1723 - accuracy: 0.6218
# Epoch 25/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.1599 - accuracy: 0.6251
# Epoch 26/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.1496 - accuracy: 0.6291
# Epoch 27/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.1384 - accuracy: 0.6340
# Epoch 28/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.1296 - accuracy: 0.6357
# Epoch 29/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.1199 - accuracy: 0.6405
# Epoch 30/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.1105 - accuracy: 0.6408
# Epoch 31/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.1002 - accuracy: 0.6450
# Epoch 32/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.0921 - accuracy: 0.6447
# Epoch 33/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.0860 - accuracy: 0.6478
# Epoch 34/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.0767 - accuracy: 0.6511
# Epoch 35/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.0683 - accuracy: 0.6554
# Epoch 36/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.0628 - accuracy: 0.6547
# Epoch 37/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.0560 - accuracy: 0.6571
# Epoch 38/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.0479 - accuracy: 0.6590
# Epoch 39/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.0401 - accuracy: 0.6614
# Epoch 40/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.0326 - accuracy: 0.6660
# Epoch 41/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.0275 - accuracy: 0.6646
# Epoch 42/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.0213 - accuracy: 0.6680
# Epoch 43/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.0133 - accuracy: 0.6703
# Epoch 44/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.0088 - accuracy: 0.6719
# Epoch 45/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 1.0028 - accuracy: 0.6741
# Epoch 46/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.9981 - accuracy: 0.6747
# Epoch 47/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.9924 - accuracy: 0.6774
# Epoch 48/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.9878 - accuracy: 0.6776
# Epoch 49/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.9809 - accuracy: 0.6802
# Epoch 50/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.9797 - accuracy: 0.6800

# %%
# CNN for center quadrant

# Define the input shape for each quadrant
input_shape = (14, 14, 1)

# Create a sequential model for the top left quadrant
model_c = Sequential()

# Add a convolutional layer with 16 filters, 3x3 kernel size, and sigmoid activation
model_c.add(Conv2D(16, kernel_size=(3, 3), activation='sigmoid', input_shape=input_shape))

# Add a max pooling layer with 2x2 pool size
model_c.add(MaxPooling2D(pool_size=(2, 2)))

# Add a convolutional layer with 32 filters, 3x3 kernel size, and sigmoid activation
model_c.add(Conv2D(32, kernel_size=(3, 3), activation='sigmoid'))

# Add a max pooling layer with 2x2 pool size
model_c.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output of the previous layer
model_c.add(Flatten())

# Add a dense layer with 512 units and relu activation
model_c.add(Dense(512, activation='relu'))

# Add the output layer with 46 units and softmax activation
model_c.add(Dense(46, activation='softmax'))

# Compile the model with categorical crossentropy loss and Adam optimizer
model_c.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model_c.summary()

# Train the model on the top left quadrant dataset
model_c.fit(x_train_c, train_labels_onehot, batch_size=32, epochs=50)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 12, 12, 16)        160
#
#  max_pooling2d_8 (MaxPooling  (None, 6, 6, 16)         0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 4, 4, 32)          4640
#
#  max_pooling2d_9 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  flatten_4 (Flatten)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 512)               66048
#
#  dense_9 (Dense)             (None, 46)                23598
#
# =================================================================
# Total params: 94,446
# Trainable params: 94,446
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2444/2444 [==============================] - 17s 6ms/step - loss: 2.9682 - accuracy: 0.2091
# Epoch 2/50
# 2444/2444 [==============================] - 16s 6ms/step - loss: 1.9354 - accuracy: 0.4405
# Epoch 3/50
# 2444/2444 [==============================] - 16s 6ms/step - loss: 1.5739 - accuracy: 0.5363
# Epoch 4/50
# 2444/2444 [==============================] - 16s 7ms/step - loss: 1.3586 - accuracy: 0.5933
# Epoch 5/50
# 2444/2444 [==============================] - 16s 7ms/step - loss: 1.2095 - accuracy: 0.6327
# Epoch 6/50
# 2444/2444 [==============================] - 16s 7ms/step - loss: 1.1053 - accuracy: 0.6604
# Epoch 7/50
# 2444/2444 [==============================] - 16s 7ms/step - loss: 1.0209 - accuracy: 0.6854
# Epoch 8/50
# 2444/2444 [==============================] - 16s 7ms/step - loss: 0.9572 - accuracy: 0.7014
# Epoch 9/50
# 2444/2444 [==============================] - 16s 7ms/step - loss: 0.9047 - accuracy: 0.7159
# Epoch 10/50
# 2444/2444 [==============================] - 16s 7ms/step - loss: 0.8602 - accuracy: 0.7284
# Epoch 11/50
# 2444/2444 [==============================] - 16s 7ms/step - loss: 0.8229 - accuracy: 0.7395
# Epoch 12/50
# 2444/2444 [==============================] - 16s 7ms/step - loss: 0.7899 - accuracy: 0.7488
# Epoch 13/50
# 2444/2444 [==============================] - 16s 6ms/step - loss: 0.7632 - accuracy: 0.7569
# Epoch 14/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 0.7364 - accuracy: 0.7655
# Epoch 15/50
# 2444/2444 [==============================] - 16s 7ms/step - loss: 0.7147 - accuracy: 0.7717
# Epoch 16/50
# 2444/2444 [==============================] - 16s 7ms/step - loss: 0.6923 - accuracy: 0.7782
# Epoch 17/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.6759 - accuracy: 0.7833
# Epoch 18/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.6577 - accuracy: 0.7883
# Epoch 19/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.6417 - accuracy: 0.7931
# Epoch 20/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.6260 - accuracy: 0.7969
# Epoch 21/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.6108 - accuracy: 0.8024
# Epoch 22/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.5982 - accuracy: 0.8062
# Epoch 23/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.5870 - accuracy: 0.8093
# Epoch 24/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.5752 - accuracy: 0.8130
# Epoch 25/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.5630 - accuracy: 0.8162
# Epoch 26/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.5539 - accuracy: 0.8187
# Epoch 27/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.5428 - accuracy: 0.8230
# Epoch 28/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.5339 - accuracy: 0.8270
# Epoch 29/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.5256 - accuracy: 0.8269
# Epoch 30/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.5160 - accuracy: 0.8296
# Epoch 31/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.5066 - accuracy: 0.8329
# Epoch 32/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.4998 - accuracy: 0.8342
# Epoch 33/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.4930 - accuracy: 0.8364
# Epoch 34/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.4854 - accuracy: 0.8387
# Epoch 35/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.4785 - accuracy: 0.8419
# Epoch 36/50
# 2444/2444 [==============================] - 18s 7ms/step - loss: 0.4721 - accuracy: 0.8427
# Epoch 37/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.4659 - accuracy: 0.8435
# Epoch 38/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.4595 - accuracy: 0.8460
# Epoch 39/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.4537 - accuracy: 0.8481
# Epoch 40/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.4476 - accuracy: 0.8487
# Epoch 41/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.4408 - accuracy: 0.8517
# Epoch 42/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.4362 - accuracy: 0.8524
# Epoch 43/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.4310 - accuracy: 0.8554
# Epoch 44/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.4256 - accuracy: 0.8565
# Epoch 45/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.4205 - accuracy: 0.8577
# Epoch 46/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.4165 - accuracy: 0.8576
# Epoch 47/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.4112 - accuracy: 0.8607
# Epoch 48/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.4054 - accuracy: 0.8614
# Epoch 49/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.4041 - accuracy: 0.8617
# Epoch 50/50
# 2444/2444 [==============================] - 17s 7ms/step - loss: 0.3998 - accuracy: 0.8620

# %%
from tensorflow.keras.models import Model

# create new models to extract features from the last dense layer
model_tl_features = Model(inputs=model_tl.input, outputs=model_tl.get_layer('dense').output)
model_tr_features = Model(inputs=model_tr.input, outputs=model_tr.get_layer('dense_2').output)
model_bl_features = Model(inputs=model_bl.input, outputs=model_bl.get_layer('dense_4').output)
model_br_features = Model(inputs=model_br.input, outputs=model_br.get_layer('dense_6').output)
model_c_features = Model(inputs=model_c.input, outputs=model_c.get_layer('dense_8').output)

# extract features from the last dense layer for each quadrant
tl_features = model_tl_features.predict(x_train_tl)
tr_features = model_tr_features.predict(x_train_tr)
bl_features = model_bl_features.predict(x_train_bl)
br_features = model_br_features.predict(x_train_br)
center_features = model_c_features.predict(x_train_c)

# concatenate the features from all 5 quadrants into a single input
features = np.concatenate((tl_features, tr_features, bl_features, br_features, center_features), axis=1)
# Out:
# 2444/2444 [==============================] - 8s 3ms/step
# 2444/2444 [==============================] - 8s 3ms/step
# 2444/2444 [==============================] - 8s 3ms/step
# 2444/2444 [==============================] - 8s 3ms/step
# 2444/2444 [==============================] - 8s 3ms/step

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# define the DNN classifier model
classifier = Sequential()
classifier.add(Dense(2560, activation='relu', input_shape=(features.shape[1],)))
classifier.add(Dense(1000, activation='relu'))
classifier.add(Dense(1000, activation='relu'))
classifier.add(Dense(1000, activation='relu'))
classifier.add(Dense(46, activation='softmax'))

# compile the model
classifier.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history = classifier.fit(features, train_labels_onehot, batch_size=32, epochs=10)
# Out:
# Epoch 1/10
# 2444/2444 [==============================] - 376s 154ms/step - loss: 0.3223 - accuracy: 0.9119
# Epoch 2/10
# 2444/2444 [==============================] - 383s 157ms/step - loss: 0.1503 - accuracy: 0.9652
# Epoch 3/10
# 2444/2444 [==============================] - 381s 156ms/step - loss: 0.1231 - accuracy: 0.9745
# Epoch 4/10
# 2444/2444 [==============================] - 381s 156ms/step - loss: 0.0919 - accuracy: 0.9801
# Epoch 5/10
# 2444/2444 [==============================] - 380s 156ms/step - loss: 0.0913 - accuracy: 0.9825
# Epoch 6/10
# 2444/2444 [==============================] - 382s 156ms/step - loss: 0.0739 - accuracy: 0.9855
# Epoch 7/10
# 2444/2444 [==============================] - 383s 157ms/step - loss: 0.0748 - accuracy: 0.9861
# Epoch 8/10
# 2444/2444 [==============================] - 389s 159ms/step - loss: 0.0683 - accuracy: 0.9871
# Epoch 9/10
# 2444/2444 [==============================] - 395s 162ms/step - loss: 0.0638 - accuracy: 0.9896
# Epoch 10/10
# 2444/2444 [==============================] - 395s 162ms/step - loss: 0.0655 - accuracy: 0.9904

# %% [markdown]
# # Preprocessing the test data for prediction and testing

# %%
test_labels_int = label_encoder.fit_transform(test_labels)

# %%
# Convert the integer labels to one-hot encoding
test_labels_onehot = to_categorical(test_labels_int, num_classes=46)

# Split the data into the five quadrants
x_test_tl = test_images[:,:14,:14].reshape(-1, 14, 14, 1)
x_test_tr = test_images[:,:14,14:].reshape(-1, 14, 14, 1)
x_test_bl = test_images[:,14:,:14].reshape(-1, 14, 14, 1)
x_test_br = test_images[:,14:,14:].reshape(-1, 14, 14, 1)
x_test_c = test_images[:,7:21,7:21].reshape(-1, 14, 14, 1)

# %%
# extract features from the last dense layer for each quadrant
tl_features_test = model_tl_features.predict(x_test_tl)
tr_features_test = model_tr_features.predict(x_test_tr)
bl_features_test = model_bl_features.predict(x_test_bl)
br_features_test = model_br_features.predict(x_test_br)
center_features_test = model_c_features.predict(x_test_c)

# concatenate the features from all 5 quadrants into a single input
features_test = np.concatenate((tl_features_test, tr_features_test, bl_features_test, br_features_test, center_features_test), axis=1)
# Out:
# 432/432 [==============================] - 1s 2ms/step
# 432/432 [==============================] - 1s 1ms/step
# 432/432 [==============================] - 1s 1ms/step
# 432/432 [==============================] - 1s 2ms/step
# 432/432 [==============================] - 1s 1ms/step

# %%
# Save the model to disk
classifier.save("model_f512_b32e50_b32e10.h5")

# %%
test_predictions = classifier.predict(features_test)
# Out:
# 432/432 [==============================] - 7s 15ms/step

# %%
# Evaluate the model
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
accuracy = accuracy_score(test_labels_int, test_predictions.argmax(axis=1))
precision = precision_score(test_labels_int, test_predictions.argmax(axis=1), average='weighted')
recall = recall_score(test_labels_int, test_predictions.argmax(axis=1), average='weighted')
f1 = f1_score(test_labels_int, test_predictions.argmax(axis=1), average='weighted')

# %%
print('Accuracy:', accuracy)
print('Precision:', precision)
print('Recall:', recall)
print('F1 Score:', f1)
# Out:
# Accuracy: 0.9771014492753624
# Precision: 0.9776036843140119
# Recall: 0.9771014492753624
# F1 Score: 0.9771484529670016
