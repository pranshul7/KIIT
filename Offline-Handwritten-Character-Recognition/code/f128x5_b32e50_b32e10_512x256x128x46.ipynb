# %%
import os
import numpy as np
import cv2
from PIL import Image
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# %%
# Define the path to the train and test folders
train_path = 'C:/A/code/VSC/python/test/cropped_DevanagariHandwrittenCharacterDataset/Train/'
test_path = 'C:/A/code/VSC/python/test/cropped_DevanagariHandwrittenCharacterDataset/Test/'

# Define a function to load and preprocess the images
def load_images(path):
    # Create empty lists to store the images and labels
    images = []
    labels = []

    # Loop through each folder (which represents a class) in the path
    for folder in os.listdir(path):
        # Get the path to the folder
        folder_path = os.path.join(path, folder)
        # Loop through each image in the folder
        for file in os.listdir(folder_path):
            # Get the path to the image file
            img_path = os.path.join(folder_path, file)
            # Load the image using OpenCV
            img = cv2.imread(img_path)
            # Convert the image to grayscale
            img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            # Normalize the pixel values of the images
            img = img.astype('float32') / 255.0
            # Append the image to the images list
            images.append(img)
            # Append the label to the labels list
            labels.append(folder)

    # Convert the images and labels lists to NumPy arrays
    images = np.array(images)
    labels = np.array(labels)
    
    # Return the images and labels arrays
    return images, labels

# Load the train images and labels
train_images, train_labels = load_images(train_path)

# Load the test images and labels
test_images, test_labels = load_images(test_path)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.utils import to_categorical

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

# Convert the string labels to integer labels
label_encoder = LabelEncoder()
train_labels_int = label_encoder.fit_transform(train_labels)

# %%
# Convert the integer labels to one-hot encoding
train_labels_onehot = to_categorical(train_labels_int, num_classes=46)

# Split the data into the five quadrants
x_train_tl = train_images[:,:14,:14].reshape(-1, 14, 14, 1)
x_train_tr = train_images[:,:14,14:].reshape(-1, 14, 14, 1)
x_train_bl = train_images[:,14:,:14].reshape(-1, 14, 14, 1)
x_train_br = train_images[:,14:,14:].reshape(-1, 14, 14, 1)
x_train_c = train_images[:,7:21,7:21].reshape(-1, 14, 14, 1)

# %%
# CNN for top left quadrant

# Define the input shape for each quadrant
input_shape = (14, 14, 1)

# Create a sequential model for the top left quadrant
model_tl = Sequential()

# Add a convolutional layer with 16 filters, 3x3 kernel size, and sigmoid activation
model_tl.add(Conv2D(16, kernel_size=(3, 3), activation='sigmoid', input_shape=input_shape))

# Add a max pooling layer with 2x2 pool size
model_tl.add(MaxPooling2D(pool_size=(2, 2)))

# Add a convolutional layer with 32 filters, 3x3 kernel size, and sigmoid activation
model_tl.add(Conv2D(32, kernel_size=(3, 3), activation='sigmoid'))

# Add a max pooling layer with 2x2 pool size
model_tl.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output of the previous layer
model_tl.add(Flatten())

# Add the output layer with 46 units and softmax activation
model_tl.add(Dense(46, activation='softmax'))

# Compile the model with categorical crossentropy loss and Adam optimizer
model_tl.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model_tl.summary()

# Train the model on the top left quadrant dataset
model_tl.fit(x_train_tl, train_labels_onehot, batch_size=32, epochs=50)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 12, 12, 16)        160
#
#  max_pooling2d (MaxPooling2D  (None, 6, 6, 16)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 4, 4, 32)          4640
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 46)                5934
#
# =================================================================
# Total params: 10,734
# Trainable params: 10,734
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 3.3208 - accuracy: 0.1336
# Epoch 2/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 2.5661 - accuracy: 0.2943
# Epoch 3/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 2.2644 - accuracy: 0.3638
# Epoch 4/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 2.0935 - accuracy: 0.4040
# Epoch 5/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.9822 - accuracy: 0.4337
# Epoch 6/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.9010 - accuracy: 0.4535
# Epoch 7/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.8397 - accuracy: 0.4679
# Epoch 8/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.7904 - accuracy: 0.4811
# Epoch 9/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.7495 - accuracy: 0.4907
# Epoch 10/50
# 2444/2444 [==============================] - 9s 4ms/step - loss: 1.7153 - accuracy: 0.4986
# Epoch 11/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.6852 - accuracy: 0.5067
# Epoch 12/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.6591 - accuracy: 0.5125
# Epoch 13/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.6370 - accuracy: 0.5189
# Epoch 14/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.6159 - accuracy: 0.5236
# Epoch 15/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.5973 - accuracy: 0.5264
# Epoch 16/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.5798 - accuracy: 0.5323
# Epoch 17/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.5636 - accuracy: 0.5361
# Epoch 18/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.5482 - accuracy: 0.5415
# Epoch 19/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.5340 - accuracy: 0.5440
# Epoch 20/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.5209 - accuracy: 0.5461
# Epoch 21/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.5091 - accuracy: 0.5489
# Epoch 22/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.4980 - accuracy: 0.5503
# Epoch 23/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.4860 - accuracy: 0.5556
# Epoch 24/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.4762 - accuracy: 0.5576
# Epoch 25/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4656 - accuracy: 0.5606
# Epoch 26/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4572 - accuracy: 0.5627
# Epoch 27/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4489 - accuracy: 0.5646
# Epoch 28/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.4397 - accuracy: 0.5670
# Epoch 29/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4329 - accuracy: 0.5675
# Epoch 30/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.4244 - accuracy: 0.5715
# Epoch 31/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4166 - accuracy: 0.5720
# Epoch 32/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4098 - accuracy: 0.5764
# Epoch 33/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4047 - accuracy: 0.5758
# Epoch 34/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.3978 - accuracy: 0.5784
# Epoch 35/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.3924 - accuracy: 0.5790
# Epoch 36/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.3862 - accuracy: 0.5808
# Epoch 37/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.3805 - accuracy: 0.5822
# Epoch 38/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.3753 - accuracy: 0.5837
# Epoch 39/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.3714 - accuracy: 0.5857
# Epoch 40/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.3660 - accuracy: 0.5860
# Epoch 41/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.3616 - accuracy: 0.5885
# Epoch 42/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.3567 - accuracy: 0.5892
# Epoch 43/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.3515 - accuracy: 0.5912
# Epoch 44/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.3488 - accuracy: 0.5908
# Epoch 45/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.3435 - accuracy: 0.5937
# Epoch 46/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.3396 - accuracy: 0.5946
# Epoch 47/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.3364 - accuracy: 0.5948
# Epoch 48/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.3328 - accuracy: 0.5950
# Epoch 49/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.3287 - accuracy: 0.5962
# Epoch 50/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.3250 - accuracy: 0.5974

# %%
# CNN for top right quadrant

# Define the input shape for each quadrant
input_shape = (14, 14, 1)

# Create a sequential model for the top left quadrant
model_tr = Sequential()

# Add a convolutional layer with 16 filters, 3x3 kernel size, and sigmoid activation
model_tr.add(Conv2D(16, kernel_size=(3, 3), activation='sigmoid', input_shape=input_shape))

# Add a max pooling layer with 2x2 pool size
model_tr.add(MaxPooling2D(pool_size=(2, 2)))

# Add a convolutional layer with 32 filters, 3x3 kernel size, and sigmoid activation
model_tr.add(Conv2D(32, kernel_size=(3, 3), activation='sigmoid'))

# Add a max pooling layer with 2x2 pool size
model_tr.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output of the previous layer
model_tr.add(Flatten())

# Add the output layer with 46 units and softmax activation
model_tr.add(Dense(46, activation='softmax'))

# Compile the model with categorical crossentropy loss and Adam optimizer
model_tr.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model_tr.summary()

# Train the model on the top left quadrant dataset
model_tr.fit(x_train_tr, train_labels_onehot, batch_size=32, epochs=50)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 12, 12, 16)        160
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 16)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 32)          4640
#
#  max_pooling2d_3 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 46)                5934
#
# =================================================================
# Total params: 10,734
# Trainable params: 10,734
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 3.5150 - accuracy: 0.1039
# Epoch 2/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 2.9112 - accuracy: 0.2183
# Epoch 3/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 2.6567 - accuracy: 0.2686
# Epoch 4/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 2.5023 - accuracy: 0.3054
# Epoch 5/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 2.3915 - accuracy: 0.3300
# Epoch 6/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 2.3069 - accuracy: 0.3501
# Epoch 7/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 2.2421 - accuracy: 0.3674
# Epoch 8/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 2.1886 - accuracy: 0.3792
# Epoch 9/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 2.1437 - accuracy: 0.3895
# Epoch 10/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 2.1060 - accuracy: 0.3975
# Epoch 11/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 2.0717 - accuracy: 0.4081
# Epoch 12/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 2.0427 - accuracy: 0.4140
# Epoch 13/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 2.0172 - accuracy: 0.4199
# Epoch 14/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.9937 - accuracy: 0.4263
# Epoch 15/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.9727 - accuracy: 0.4306
# Epoch 16/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.9536 - accuracy: 0.4372
# Epoch 17/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.9362 - accuracy: 0.4407
# Epoch 18/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.9199 - accuracy: 0.4447
# Epoch 19/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.9053 - accuracy: 0.4478
# Epoch 20/50
# 2444/2444 [==============================] - 19s 8ms/step - loss: 1.8916 - accuracy: 0.4522
# Epoch 21/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.8779 - accuracy: 0.4557
# Epoch 22/50
# 2444/2444 [==============================] - 18s 7ms/step - loss: 1.8667 - accuracy: 0.4598
# Epoch 23/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.8553 - accuracy: 0.4611
# Epoch 24/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.8446 - accuracy: 0.4639
# Epoch 25/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.8351 - accuracy: 0.4660
# Epoch 26/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.8247 - accuracy: 0.4688
# Epoch 27/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.8163 - accuracy: 0.4702
# Epoch 28/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.8081 - accuracy: 0.4720
# Epoch 29/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.8006 - accuracy: 0.4751
# Epoch 30/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.7924 - accuracy: 0.4765
# Epoch 31/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.7852 - accuracy: 0.4774
# Epoch 32/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.7778 - accuracy: 0.4803
# Epoch 33/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.7710 - accuracy: 0.4821
# Epoch 34/50
# 2444/2444 [==============================] - 15s 6ms/step - loss: 1.7642 - accuracy: 0.4840
# Epoch 35/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.7590 - accuracy: 0.4848
# Epoch 36/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.7530 - accuracy: 0.4862
# Epoch 37/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.7467 - accuracy: 0.4880
# Epoch 38/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.7413 - accuracy: 0.4879
# Epoch 39/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.7356 - accuracy: 0.4905
# Epoch 40/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.7309 - accuracy: 0.4938
# Epoch 41/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.7256 - accuracy: 0.4944
# Epoch 42/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.7211 - accuracy: 0.4955
# Epoch 43/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.7163 - accuracy: 0.4960
# Epoch 44/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.7118 - accuracy: 0.4980
# Epoch 45/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.7083 - accuracy: 0.4988
# Epoch 46/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.7043 - accuracy: 0.4985
# Epoch 47/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.6993 - accuracy: 0.4995
# Epoch 48/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.6956 - accuracy: 0.5005
# Epoch 49/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.6917 - accuracy: 0.5029
# Epoch 50/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.6878 - accuracy: 0.5041

# %%
# CNN for bottom left quadrant

# Define the input shape for each quadrant
input_shape = (14, 14, 1)

# Create a sequential model for the top left quadrant
model_bl = Sequential()

# Add a convolutional layer with 16 filters, 3x3 kernel size, and sigmoid activation
model_bl.add(Conv2D(16, kernel_size=(3, 3), activation='sigmoid', input_shape=input_shape))

# Add a max pooling layer with 2x2 pool size
model_bl.add(MaxPooling2D(pool_size=(2, 2)))

# Add a convolutional layer with 32 filters, 3x3 kernel size, and sigmoid activation
model_bl.add(Conv2D(32, kernel_size=(3, 3), activation='sigmoid'))

# Add a max pooling layer with 2x2 pool size
model_bl.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output of the previous layer
model_bl.add(Flatten())

# Add the output layer with 46 units and softmax activation
model_bl.add(Dense(46, activation='softmax'))

# Compile the model with categorical crossentropy loss and Adam optimizer
model_bl.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model_bl.summary()

# Train the model on the top left quadrant dataset
model_bl.fit(x_train_bl, train_labels_onehot, batch_size=32, epochs=50)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 12, 12, 16)        160
#
#  max_pooling2d_4 (MaxPooling  (None, 6, 6, 16)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 32)          4640
#
#  max_pooling2d_5 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 46)                5934
#
# =================================================================
# Total params: 10,734
# Trainable params: 10,734
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2444/2444 [==============================] - 8s 3ms/step - loss: 3.1228 - accuracy: 0.1847
# Epoch 2/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 2.2806 - accuracy: 0.3765
# Epoch 3/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.9990 - accuracy: 0.4400
# Epoch 4/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.8452 - accuracy: 0.4754
# Epoch 5/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.7391 - accuracy: 0.5011
# Epoch 6/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.6624 - accuracy: 0.5198
# Epoch 7/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.6015 - accuracy: 0.5336
# Epoch 8/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.5526 - accuracy: 0.5472
# Epoch 9/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.5116 - accuracy: 0.5570
# Epoch 10/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4756 - accuracy: 0.5664
# Epoch 11/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4424 - accuracy: 0.5745
# Epoch 12/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4133 - accuracy: 0.5811
# Epoch 13/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.3866 - accuracy: 0.5901
# Epoch 14/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.3623 - accuracy: 0.5955
# Epoch 15/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.3397 - accuracy: 0.6005
# Epoch 16/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.3187 - accuracy: 0.6063
# Epoch 17/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.3012 - accuracy: 0.6100
# Epoch 18/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.2823 - accuracy: 0.6145
# Epoch 19/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.2671 - accuracy: 0.6186
# Epoch 20/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.2528 - accuracy: 0.6227
# Epoch 21/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.2394 - accuracy: 0.6267
# Epoch 22/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.2257 - accuracy: 0.6295
# Epoch 23/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.2143 - accuracy: 0.6321
# Epoch 24/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.2023 - accuracy: 0.6356
# Epoch 25/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.1928 - accuracy: 0.6369
# Epoch 26/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.1821 - accuracy: 0.6400
# Epoch 27/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.1735 - accuracy: 0.6423
# Epoch 28/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.1633 - accuracy: 0.6456
# Epoch 29/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.1560 - accuracy: 0.6467
# Epoch 30/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.1482 - accuracy: 0.6487
# Epoch 31/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.1407 - accuracy: 0.6515
# Epoch 32/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.1341 - accuracy: 0.6532
# Epoch 33/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.1267 - accuracy: 0.6541
# Epoch 34/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.1203 - accuracy: 0.6565
# Epoch 35/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.1138 - accuracy: 0.6577
# Epoch 36/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.1079 - accuracy: 0.6597
# Epoch 37/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.1022 - accuracy: 0.6610
# Epoch 38/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0963 - accuracy: 0.6624
# Epoch 39/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.0911 - accuracy: 0.6640
# Epoch 40/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.0863 - accuracy: 0.6651
# Epoch 41/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.0819 - accuracy: 0.6673
# Epoch 42/50
# 2444/2444 [==============================] - 13s 5ms/step - loss: 1.0761 - accuracy: 0.6687
# Epoch 43/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0710 - accuracy: 0.6703
# Epoch 44/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0678 - accuracy: 0.6698
# Epoch 45/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.0628 - accuracy: 0.6712
# Epoch 46/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.0587 - accuracy: 0.6722
# Epoch 47/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0550 - accuracy: 0.6737
# Epoch 48/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0509 - accuracy: 0.6740
# Epoch 49/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0479 - accuracy: 0.6768
# Epoch 50/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.0438 - accuracy: 0.6757

# %%
# CNN for bottom right quadrant

# Define the input shape for each quadrant
input_shape = (14, 14, 1)

# Create a sequential model for the top left quadrant
model_br = Sequential()

# Add a convolutional layer with 16 filters, 3x3 kernel size, and sigmoid activation
model_br.add(Conv2D(16, kernel_size=(3, 3), activation='sigmoid', input_shape=input_shape))

# Add a max pooling layer with 2x2 pool size
model_br.add(MaxPooling2D(pool_size=(2, 2)))

# Add a convolutional layer with 32 filters, 3x3 kernel size, and sigmoid activation
model_br.add(Conv2D(32, kernel_size=(3, 3), activation='sigmoid'))

# Add a max pooling layer with 2x2 pool size
model_br.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output of the previous layer
model_br.add(Flatten())

# Add the output layer with 46 units and softmax activation
model_br.add(Dense(46, activation='softmax'))

# Compile the model with categorical crossentropy loss and Adam optimizer
model_br.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model_br.summary()

# Train the model on the top left quadrant dataset
model_br.fit(x_train_br, train_labels_onehot, batch_size=32, epochs=50)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 12, 12, 16)        160
#
#  max_pooling2d_6 (MaxPooling  (None, 6, 6, 16)         0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 4, 4, 32)          4640
#
#  max_pooling2d_7 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  flatten_3 (Flatten)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 46)                5934
#
# =================================================================
# Total params: 10,734
# Trainable params: 10,734
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2444/2444 [==============================] - 7s 3ms/step - loss: 3.2913 - accuracy: 0.1436
# Epoch 2/50
# 2444/2444 [==============================] - 6s 3ms/step - loss: 2.5217 - accuracy: 0.2896
# Epoch 3/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 2.2816 - accuracy: 0.3415
# Epoch 4/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 2.1461 - accuracy: 0.3752
# Epoch 5/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 2.0525 - accuracy: 0.3961
# Epoch 6/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.9823 - accuracy: 0.4122
# Epoch 7/50
# 2444/2444 [==============================] - 10s 4ms/step - loss: 1.9264 - accuracy: 0.4259
# Epoch 8/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.8807 - accuracy: 0.4369
# Epoch 9/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.8409 - accuracy: 0.4481
# Epoch 10/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.8058 - accuracy: 0.4571
# Epoch 11/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.7755 - accuracy: 0.4637
# Epoch 12/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.7473 - accuracy: 0.4701
# Epoch 13/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.7226 - accuracy: 0.4760
# Epoch 14/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.6985 - accuracy: 0.4824
# Epoch 15/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.6787 - accuracy: 0.4877
# Epoch 16/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.6588 - accuracy: 0.4934
# Epoch 17/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.6403 - accuracy: 0.4976
# Epoch 18/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.6244 - accuracy: 0.5019
# Epoch 19/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.6086 - accuracy: 0.5059
# Epoch 20/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.5937 - accuracy: 0.5086
# Epoch 21/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.5803 - accuracy: 0.5136
# Epoch 22/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.5676 - accuracy: 0.5174
# Epoch 23/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.5563 - accuracy: 0.5201
# Epoch 24/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.5455 - accuracy: 0.5233
# Epoch 25/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.5342 - accuracy: 0.5256
# Epoch 26/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.5249 - accuracy: 0.5286
# Epoch 27/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.5146 - accuracy: 0.5310
# Epoch 28/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.5060 - accuracy: 0.5329
# Epoch 29/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.4980 - accuracy: 0.5348
# Epoch 30/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.4907 - accuracy: 0.5373
# Epoch 31/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.4821 - accuracy: 0.5398
# Epoch 32/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4748 - accuracy: 0.5405
# Epoch 33/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4684 - accuracy: 0.5449
# Epoch 34/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4622 - accuracy: 0.5454
# Epoch 35/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.4557 - accuracy: 0.5483
# Epoch 36/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4496 - accuracy: 0.5490
# Epoch 37/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4436 - accuracy: 0.5494
# Epoch 38/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4385 - accuracy: 0.5522
# Epoch 39/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.4338 - accuracy: 0.5529
# Epoch 40/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4286 - accuracy: 0.5537
# Epoch 41/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4238 - accuracy: 0.5562
# Epoch 42/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4197 - accuracy: 0.5565
# Epoch 43/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.4150 - accuracy: 0.5582
# Epoch 44/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4096 - accuracy: 0.5605
# Epoch 45/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4060 - accuracy: 0.5612
# Epoch 46/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4015 - accuracy: 0.5627
# Epoch 47/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.3979 - accuracy: 0.5630
# Epoch 48/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.3937 - accuracy: 0.5636
# Epoch 49/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.3899 - accuracy: 0.5656
# Epoch 50/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.3871 - accuracy: 0.5667

# %%
# CNN for center quadrant

# Define the input shape for each quadrant
input_shape = (14, 14, 1)

# Create a sequential model for the top left quadrant
model_c = Sequential()

# Add a convolutional layer with 16 filters, 3x3 kernel size, and sigmoid activation
model_c.add(Conv2D(16, kernel_size=(3, 3), activation='sigmoid', input_shape=input_shape))

# Add a max pooling layer with 2x2 pool size
model_c.add(MaxPooling2D(pool_size=(2, 2)))

# Add a convolutional layer with 32 filters, 3x3 kernel size, and sigmoid activation
model_c.add(Conv2D(32, kernel_size=(3, 3), activation='sigmoid'))

# Add a max pooling layer with 2x2 pool size
model_c.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output of the previous layer
model_c.add(Flatten())

# Add the output layer with 46 units and softmax activation
model_c.add(Dense(46, activation='softmax'))

# Compile the model with categorical crossentropy loss and Adam optimizer
model_c.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model_c.summary()

# Train the model on the top left quadrant dataset
model_c.fit(x_train_c, train_labels_onehot, batch_size=32, epochs=50)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 12, 12, 16)        160
#
#  max_pooling2d_8 (MaxPooling  (None, 6, 6, 16)         0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 4, 4, 32)          4640
#
#  max_pooling2d_9 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  flatten_4 (Flatten)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 46)                5934
#
# =================================================================
# Total params: 10,734
# Trainable params: 10,734
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2444/2444 [==============================] - 9s 3ms/step - loss: 3.1827 - accuracy: 0.1779
# Epoch 2/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 2.3108 - accuracy: 0.3801
# Epoch 3/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.9512 - accuracy: 0.4684
# Epoch 4/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.7638 - accuracy: 0.5176
# Epoch 5/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.6426 - accuracy: 0.5452
# Epoch 6/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.5519 - accuracy: 0.5670
# Epoch 7/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4777 - accuracy: 0.5863
# Epoch 8/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.4171 - accuracy: 0.6015
# Epoch 9/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.3652 - accuracy: 0.6130
# Epoch 10/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.3210 - accuracy: 0.6228
# Epoch 11/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.2851 - accuracy: 0.6330
# Epoch 12/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.2543 - accuracy: 0.6399
# Epoch 13/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.2262 - accuracy: 0.6462
# Epoch 14/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.2024 - accuracy: 0.6519
# Epoch 15/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.1798 - accuracy: 0.6584
# Epoch 16/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.1603 - accuracy: 0.6634
# Epoch 17/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.1428 - accuracy: 0.6667
# Epoch 18/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.1264 - accuracy: 0.6733
# Epoch 19/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.1105 - accuracy: 0.6763
# Epoch 20/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0963 - accuracy: 0.6799
# Epoch 21/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0838 - accuracy: 0.6839
# Epoch 22/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.0704 - accuracy: 0.6871
# Epoch 23/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0592 - accuracy: 0.6914
# Epoch 24/50
# 2444/2444 [==============================] - 11s 4ms/step - loss: 1.0474 - accuracy: 0.6930
# Epoch 25/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.0375 - accuracy: 0.6944
# Epoch 26/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0269 - accuracy: 0.6990
# Epoch 27/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 1.0175 - accuracy: 0.7005
# Epoch 28/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0084 - accuracy: 0.7020
# Epoch 29/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 1.0007 - accuracy: 0.7063
# Epoch 30/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.9921 - accuracy: 0.7080
# Epoch 31/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.9844 - accuracy: 0.7090
# Epoch 32/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.9767 - accuracy: 0.7126
# Epoch 33/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 0.9701 - accuracy: 0.7124
# Epoch 34/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 0.9640 - accuracy: 0.7151
# Epoch 35/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.9573 - accuracy: 0.7158
# Epoch 36/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.9508 - accuracy: 0.7176
# Epoch 37/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.9450 - accuracy: 0.7198
# Epoch 38/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.9393 - accuracy: 0.7212
# Epoch 39/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.9333 - accuracy: 0.7230
# Epoch 40/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.9272 - accuracy: 0.7242
# Epoch 41/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.9235 - accuracy: 0.7236
# Epoch 42/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.9177 - accuracy: 0.7265
# Epoch 43/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.9144 - accuracy: 0.7271
# Epoch 44/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.9087 - accuracy: 0.7287
# Epoch 45/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.9044 - accuracy: 0.7301
# Epoch 46/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.8998 - accuracy: 0.7311
# Epoch 47/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.8960 - accuracy: 0.7313
# Epoch 48/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 0.8919 - accuracy: 0.7329
# Epoch 49/50
# 2444/2444 [==============================] - 12s 5ms/step - loss: 0.8878 - accuracy: 0.7341
# Epoch 50/50
# 2444/2444 [==============================] - 11s 5ms/step - loss: 0.8830 - accuracy: 0.7362

# %%
from tensorflow.keras.models import Model

# create new models to extract features from the last dense layer
model_tl_features = Model(inputs=model_tl.input, outputs=model_tl.get_layer('flatten').output)
model_tr_features = Model(inputs=model_tr.input, outputs=model_tr.get_layer('flatten_1').output)
model_bl_features = Model(inputs=model_bl.input, outputs=model_bl.get_layer('flatten_2').output)
model_br_features = Model(inputs=model_br.input, outputs=model_br.get_layer('flatten_3').output)
model_c_features = Model(inputs=model_c.input, outputs=model_c.get_layer('flatten_4').output)

# extract features from the last dense layer for each quadrant
tl_features = model_tl_features.predict(x_train_tl)
tr_features = model_tr_features.predict(x_train_tr)
bl_features = model_bl_features.predict(x_train_bl)
br_features = model_br_features.predict(x_train_br)
center_features = model_c_features.predict(x_train_c)

# concatenate the features from all 5 quadrants into a single input
features = np.concatenate((tl_features, tr_features, bl_features, br_features, center_features), axis=1)
# Out:
# 2444/2444 [==============================] - 3s 1ms/step
# 2444/2444 [==============================] - 3s 1ms/step
# 2444/2444 [==============================] - 3s 1ms/step
# 2444/2444 [==============================] - 3s 1ms/step
# 2444/2444 [==============================] - 4s 1ms/step

# %%
print(features.shape)
# Out:
# (78200, 640)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# define the DNN classifier model
classifier = Sequential()
classifier.add(Dense(512, activation='relu', input_shape=(features.shape[1],)))
classifier.add(Dense(256, activation='relu'))
classifier.add(Dense(128, activation='relu'))
classifier.add(Dense(46, activation='softmax'))

# compile the model
classifier.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history = classifier.fit(features, train_labels_onehot, batch_size=32, epochs=10)
# Out:
# Epoch 1/10
# 2444/2444 [==============================] - 20s 8ms/step - loss: 0.4573 - accuracy: 0.8643
# Epoch 2/10
# 2444/2444 [==============================] - 23s 9ms/step - loss: 0.1726 - accuracy: 0.9450
# Epoch 3/10
# 2444/2444 [==============================] - 23s 9ms/step - loss: 0.1291 - accuracy: 0.9584
# Epoch 4/10
# 2444/2444 [==============================] - 24s 10ms/step - loss: 0.1046 - accuracy: 0.9663
# Epoch 5/10
# 2444/2444 [==============================] - 24s 10ms/step - loss: 0.0892 - accuracy: 0.9721
# Epoch 6/10
# 2444/2444 [==============================] - 24s 10ms/step - loss: 0.0756 - accuracy: 0.9759
# Epoch 7/10
# 2444/2444 [==============================] - 23s 10ms/step - loss: 0.0699 - accuracy: 0.9775
# Epoch 8/10
# 2444/2444 [==============================] - 23s 10ms/step - loss: 0.0656 - accuracy: 0.9799
# Epoch 9/10
# 2444/2444 [==============================] - 24s 10ms/step - loss: 0.0596 - accuracy: 0.9810
# Epoch 10/10
# 2444/2444 [==============================] - 23s 9ms/step - loss: 0.0532 - accuracy: 0.9831

# %% [markdown]
# # Preprocessing the test data for prediction and testing

# %%
test_labels_int = label_encoder.fit_transform(test_labels)

# %%
# Convert the integer labels to one-hot encoding
test_labels_onehot = to_categorical(test_labels_int, num_classes=46)

# Split the data into the five quadrants
x_test_tl = test_images[:,:14,:14].reshape(-1, 14, 14, 1)
x_test_tr = test_images[:,:14,14:].reshape(-1, 14, 14, 1)
x_test_bl = test_images[:,14:,:14].reshape(-1, 14, 14, 1)
x_test_br = test_images[:,14:,14:].reshape(-1, 14, 14, 1)
x_test_c = test_images[:,7:21,7:21].reshape(-1, 14, 14, 1)

# %%
# extract features from the last dense layer for each quadrant
tl_features_test = model_tl_features.predict(x_test_tl)
tr_features_test = model_tr_features.predict(x_test_tr)
bl_features_test = model_bl_features.predict(x_test_bl)
br_features_test = model_br_features.predict(x_test_br)
center_features_test = model_c_features.predict(x_test_c)

# concatenate the features from all 5 quadrants into a single input
features_test = np.concatenate((tl_features_test, tr_features_test, bl_features_test, br_features_test, center_features_test), axis=1)
# Out:
# 432/432 [==============================] - 1s 1ms/step
# 432/432 [==============================] - 1s 1ms/step
# 432/432 [==============================] - 1s 1ms/step
# 432/432 [==============================] - 1s 1ms/step
# 432/432 [==============================] - 1s 1ms/step

# %%
# Save the model to disk
classifier.save("f128x5_b32e50_b32e10_512x256x128x46.h5")

# %%
test_predictions = classifier.predict(features_test)
# Out:
# 432/432 [==============================] - 1s 2ms/step

# %%
# Evaluate the model
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
accuracy = accuracy_score(test_labels_int, test_predictions.argmax(axis=1))
precision = precision_score(test_labels_int, test_predictions.argmax(axis=1), average='weighted')
recall = recall_score(test_labels_int, test_predictions.argmax(axis=1), average='weighted')
f1 = f1_score(test_labels_int, test_predictions.argmax(axis=1), average='weighted')

# %%
print('Accuracy:', accuracy)
print('Precision:', precision)
print('Recall:', recall)
print('F1 Score:', f1)
# Out:
# Accuracy: 0.9607971014492753
# Precision: 0.9618344935306125
# Recall: 0.9607971014492753
# F1 Score: 0.9608684942431456
